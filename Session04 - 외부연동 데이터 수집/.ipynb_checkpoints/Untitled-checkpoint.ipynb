# %% [markdown]
# # 1. 라이브러리 선언

# %%
import pandas as pd

# %% [markdown]
# # 2. 공공데이터 (파일데이터 불러오기)

# %%
pirLirUrl = "https://www.data.go.kr/cmm/cmm/fileDownload.do?atchFileId=FILE_000000002340074&fileDetailSn=1&dataNm=%ED%95%9C%EA%B5%AD%EC%A3%BC%ED%83%9D%EA%B8%88%EC%9C%B5%EA%B3%B5%EC%82%AC_%EC%A7%80%EC%97%AD%EB%B3%84%20PIR%20%EB%B0%8F%20LIR"

# %%
indata = pd.read_csv(pirLirUrl, encoding="ms949")
indata.tail()
# Out:
#        연도  월  전국PIR  서울PIR  부산PIR  대구PIR  인천PIR  광주PIR  대전PIR  울산PIR  ...  \
# 190  2020  1   4.47   5.44   4.84   5.16   4.39   4.76   4.52   4.11  ...
# 191  2020  2   4.45   5.02   5.04   4.92   4.49   4.52   4.36   3.90  ...
# 192  2020  3   4.76   5.12   5.22   5.20   4.76   5.04   4.74   4.11  ...
# 193  2020  4   4.83   4.95   5.67   5.91   4.78   5.41   5.40   4.44  ...
# 194  2020  5   4.56   4.88   7.01   5.44   4.56   3.16   4.72   5.77  ...
#
#      세종LIR  경기LIR  강원LIR  충북LIR  충남LIR  전북LIR  전남LIR  경북LIR  경남LIR  제주LIR
# 190   2.63   2.39   1.90   1.76   1.87   1.94   1.85   1.80   2.02   2.13
# 191   2.69   2.34   1.96   1.87   1.89   1.83   1.68   1.69   1.91   2.07
# 192   2.22   2.56   2.13   1.98   2.03   1.97   1.89   1.95   2.23   2.27
# 193   1.73   2.54   2.13   2.09   2.14   2.11   1.94   1.97   2.06   1.85
# 194   0.00   2.23   2.44   1.08   1.65   1.04   1.68   1.99   2.17   0.96
#
# [5 rows x 38 columns]

# %% [markdown]
# # 2번에 대한 실습 (공공데이터포털에서 한국감정원 오피스텔 동향조사 현황자료를 검색하여 데이터타입자료를 불러오세요)

# %%
import pandas as pd
#패키지 임포트

url = "https://www.data.go.kr/cmm/cmm/fileDownload.do?atchFileId=FILE_000000002312933&fileDetailSn=1&dataNm=%ED%95%9C%EA%B5%AD%EB%B6%80%EB%8F%99%EC%82%B0%EC%9B%90_%EC%98%A4%ED%94%BC%EC%8A%A4%ED%85%94%20%EC%A0%84%EC%84%B8%EA%B0%80%EA%B2%A9(%EC%9B%94%EB%B3%84)_20201014"
# 다운로드 링크를 url변수에 지정
indata = pd.read_csv(url, encoding="ms949")
# csv파일을 읽어올 링크와 인코딩 형식을 indata변수에 담음
indata
# 출력

# %% [markdown]
# # 국가통계포털 API데이터 불러오기 (횡단면 조회)

# %%
import pandas as pd

url = "https://kosis.kr/openapi/statisticsData.do?method=getList&apiKey=ZDBkZjU4MzlkOWQ3MDAzYTZkZDdhYjBjZDM0ZDE0MTY=&format=json&jsonVD=Y&userStatsId=hdk2006/101/DT_1B040A3/2/1/20210412145641&prdSe=M&newEstPrdCnt=1"
json = pd.DataFrame()
try:
    json = pd.read_json(url)
except Exception as e:
    print(e)
json

# %% [markdown]
# # 국가통계포털 API데이터 불러오기 (시계열 조회, 총인구수 * 서울특별시)

# %%
import pandas as pd
url = "https://kosis.kr/openapi/statisticsData.do?method=getList&apiKey=ZDBkZjU4MzlkOWQ3MDAzYTZkZDdhYjBjZDM0ZDE0MTY=&format=json&jsonVD=Y&userStatsId=hdk2006/101/DT_1B040A3/2/1/20210412150415_1&prdSe=M&newEstPrdCnt=3"
json = pd.DataFrame()
try:
    json = pd.read_json(url)
except Exception as e:
    print(e)
json

# %% [markdown]
# # 1행 82500 2008
# # 2행 72500 2010

# %%
columnList = [] 
rowList = []  # 리스트 선언

# %%
columnList.append("82500")
columnList.append("2008")  # 컬럼 리스트에 값 추가
rowList.append(columnList) # 로우 리스트에 컬럼리스트를 추가

# %%
columnList=[]  # 컬럼리스트 초기화
columnList.append("72500")
columnList.append("2010") #컬럼 리스트 값 추가
rowList.append(columnList)  # 로우 리스트에 컬럼리스트 추가

pd.DataFrame(rowList) # 출력
# Out:
#        0     1
# 0  82500  2008
# 1  72500  2010

# %%
pip install bs4
# Out:
# Collecting bs4
#   Downloading bs4-0.0.1.tar.gz (1.1 kB)
# Requirement already satisfied: beautifulsoup4 in c:\users\smart-20\anaconda3\lib\site-packages (from bs4) (4.9.3)
# Requirement already satisfied: soupsieve>1.2; python_version >= "3.0" in c:\users\smart-20\anaconda3\lib\site-packages (from beautifulsoup4->bs4) (2.0.1)
# Building wheels for collected packages: bs4
#   Building wheel for bs4 (setup.py): started
#   Building wheel for bs4 (setup.py): finished with status 'done'
#   Created wheel for bs4: filename=bs4-0.0.1-py3-none-any.whl size=1277 sha256=c0bc422d357093d8b975776ff47acabc53e7c5f2987206fd96626c8d161c300d
#   Stored in directory: c:\users\smart-20\appdata\local\pip\cache\wheels\75\78\21\68b124549c9bdc94f822c02fb9aa3578a669843f9767776bca
# Successfully built bs4
# Installing collected packages: bs4
# Successfully installed bs4-0.0.1
# Note: you may need to restart the kernel to use updated packages.

# %%
import requests        # API 서비스에 연결
from lxml import html  # parse XML 사용
from bs4 import BeautifulSoup   # 정렬해주는 BeautifulSoup 사용
import pandas as pd

# %%
url="http://openapi.molit.go.kr/OpenAPI_ToolInstallPackage/service/rest/RTMSOBJSvc/getRTMSDataSvcAptTradeDev"
response = requests.get(url+queryParams)
response.encoding="utf-8"


xmlobj = BeautifulSoup(response.text,"lxml-xml") #parser
xmlobj

# %%
import requests        # API 서비스에 연결
from lxml import html  # parse XML 사용
from bs4 import BeautifulSoup   # 정렬해주는 BeautifulSoup 사용
import pandas as pd
from urllib.request import Request, urlopen
from urllib.parse import urlencode, quote_plus,unquote

API_Key = 'AT33s775KYpJOkUBJu0dxkJuUeIfDIOJRzAH084EQS3JN%2BzFjErLHuk%2FGZa9L4gBTSGCzeA69tI9PwLp7B37IQ%3D%3D' # 서비스 키
url="http://openapi.molit.go.kr/OpenAPI_ToolInstallPackage/service/rest/RTMSOBJSvc/getRTMSDataSvcAptTradeDev" # 실질적인 url 주소
queryParams = '?' + urlencode({          # 아래 3가지 요소를 합한 값
    quote_plus('ServiceKey') : API_Key,  # ServiceKey
    quote_plus('LAWD_CD'): '11110',      # LAWD_CD
    quote_plus('DEAL_YMD'):'201512'      # DEAL_YMD
})

response = requests.get("http://openapi.molit.go.kr/OpenAPI_ToolInstallPackage/service/rest/RTMSOBJSvc/getRTMSDataSvcAptTradeDev?serviceKey=AT33s775KYpJOkUBJu0dxkJuUeIfDIOJRzAH084EQS3JN%2BzFjErLHuk%2FGZa9L4gBTSGCzeA69tI9PwLp7B37IQ%3D%3D&pageNo=1&numOfRows=10&LAWD_CD=11110&DEAL_YMD=201512")
#response는 url?ServiceKey&pageNo=1&numOfRows=10(item의 규격)&LAWD_CD&DEAL_YMD 를 합한 값을 가져오는 변수
response.encoding='utf-8'     # response의 인코딩 형식 지정
pageSource = response.text
xmlobj = BeautifulSoup(pageSource,"lxml-xml") #태그와 내용을 모두 보여줌

rowList = []                    # 행 내용을 담을 빈 배열을 생성
columnList = []                 # 열 내용을 담을 빈 배열을 생성
rows = xmlobj.findAll('item')   # "items" 안에 모든 내용을 담을 rows라는 변수를 생성

for i in range(0, len(rows)): 
    columns = rows[i].findAll() # 하나의 "item"의 모든 내용을 담을 columns라는 변수를 생성
    
    for j in range(0, len(columns)):  
        columnValue = columns[j].text    # item의 태그를 제외한 내용만을 담는 columnValue생성
        columnList.append(columnValue)   # 내용들을 columnList에 추가함
    rowList.append(columnList)           # 하나의 "item"이 columnList에 추가가 완료 되면 하나의 행(rows)이 완성됨 
    columnList = []                      # 다음 "item"값들을 넣어주기 위해 columnList를 초기화
    
homePriceSeoul = pd.DataFrame(rowList)  # 만들어진 표를 homePriceSeoul 변수에 담음
homePriceSeoul                          # 출력

columnHead = []               #item의 태그만을 받아 제목으로 쓰기위해 빈 리스트 columnHead를 만들어줌
for i in range(0, len(columns)):
    eachColumns = columns[i]        # item 하나당 받은 태그의 내용을 eachColumns 변수에 넣어줌
    columnHead.append(eachColumns.name)  # eachColumns의 태그이름만을 columnHead에 추가해줌
homePriceSeoul.columns = columnHead # homePriceSeoul테이블의 columns
homePriceSeoul                      # 출력

# %%
# 혁중이 형이 짠 컬럼이름 정해주는 코드
# columnNameList = []
# for i in range(0, len(columns)):
#         eachColumn = columns[i]
#         columnNameList.append(eachColumn.name.strip())  # or text.strip() 공백제거
# housePriceData.columns = columnNameList
# housePriceData

# %% [markdown]
# # 금융 검색 후 “시도별 금융권 대출잔액 수준별 인구＂

# %%
import pandas as pd
#
url = "https://kosis.kr/openapi/statisticsData.do?method=getList&apiKey=ZDBkZjU4MzlkOWQ3MDAzYTZkZDdhYjBjZDM0ZDE0MTY=&format=json&jsonVD=Y&userStatsId=hdk2006/101/DT_1MA0028/2/1/20210412192956&prdSe=Y&newEstPrdCnt=1"
# 시도별 금융권 대출잔액 수준별 인구의 url을 변수로 지정
json = pd.DataFrame()
# DataFrame 형식으로 나타냄
try:
    json = pd.read_json(url)
# url의 자료를 json을 불러와서 나타냄
except Exception as e:
    print(e)
# 오류가 있다면 오류구문 출력
json
# 결과출력
# Out:
#                    TBL_NM  ITM_NM_ENG ITM_ID  ORG_ID  UNIT_NM_ENG C1_OBJ_NM  \
# 0     시도별 금융권 대출잔액 수준별 인구  Population   T001     101  1000Persons       시도별
# 1     시도별 금융권 대출잔액 수준별 인구  Population   T001     101  1000Persons       시도별
# 2     시도별 금융권 대출잔액 수준별 인구  Population   T001     101  1000Persons       시도별
# 3     시도별 금융권 대출잔액 수준별 인구  Population   T001     101  1000Persons       시도별
# 4     시도별 금융권 대출잔액 수준별 인구  Population   T001     101  1000Persons       시도별
# ...                   ...         ...    ...     ...          ...       ...
# 1183  시도별 금융권 대출잔액 수준별 인구  Population   T001     101  1000Persons       시도별
# 1184  시도별 금융권 대출잔액 수준별 인구  Population   T001     101  1000Persons       시도별
# 1185  시도별 금융권 대출잔액 수준별 인구  Population   T001     101  1000Persons       시도별
# 1186  시도별 금융권 대출잔액 수준별 인구  Population   T001     101  1000Persons       시도별
# 1187  시도별 금융권 대출잔액 수준별 인구  Population   T001     101  1000Persons       시도별
#
#      C2_OBJ_NM     C3_OBJ_NM   C2      C1_NM_ENG  ... C1_OBJ_NM_ENG  \
# 0          연령별  금융권 대출잔액 수준별  A10  Whole country  ...   By province
# 1          연령별  금융권 대출잔액 수준별  A10  Whole country  ...   By province
# 2          연령별  금융권 대출잔액 수준별  A10  Whole country  ...   By province
# 3          연령별  금융권 대출잔액 수준별  A10  Whole country  ...   By province
# 4          연령별  금융권 대출잔액 수준별  A10  Whole country  ...   By province
# ...        ...           ...  ...            ...  ...           ...
# 1183       연령별  금융권 대출잔액 수준별  A15           Jeju  ...   By province
# 1184       연령별  금융권 대출잔액 수준별  A15           Jeju  ...   By province
# 1185       연령별  금융권 대출잔액 수준별  A15           Jeju  ...   By province
# 1186       연령별  금융권 대출잔액 수준별  A15           Jeju  ...   By province
# 1187       연령별  금융권 대출잔액 수준별  A15           Jeju  ...   By province
#
#      C2_OBJ_NM_ENG  C3_OBJ_NM_ENG    C3       DT PRD_SE  C1    C1_NM   C2_NM  \
# 0           By age  By depl level  DL00  19979.1      A   0       전국       계
# 1           By age  By depl level  DL10  11252.8      A   0       전국       계
# 2           By age  By depl level  DL11   1853.3      A   0       전국       계
# 3           By age  By depl level  DL12   2471.0      A   0       전국       계
# 4           By age  By depl level  DL13   1369.2      A   0       전국       계
# ...            ...            ...   ...      ...    ...  ..      ...     ...
# 1183        By age  By depl level  DL15      1.6      A  39  제주특별자치도  60-64세
# 1184        By age  By depl level  DL16      2.9      A  39  제주특별자치도  60-64세
# 1185        By age  By depl level  DL17      1.0      A  39  제주특별자치도  60-64세
# 1186        By age  By depl level  DL18      2.3      A  39  제주특별자치도  60-64세
# 1187        By age  By depl level  DL20     22.3      A  39  제주특별자치도  60-64세
#
#             C3_NM
# 0               계
# 1            부채있음
# 2         1천만원 미만
# 3       1-3천만원 미만
# 4       3-5천만원 미만
# ...           ...
# 1183  7천만원-1억원 미만
# 1184     1-2억원 미만
# 1185     2-3억원 미만
# 1186       3억원 이상
# 1187         부채없음
#
# [1188 rows x 26 columns]

# %% [markdown]
# # 리스트에서 데이터프레임 생성하기

# %%
import pandas as pd
rowFirst = ["A01", 202015, 100]
rowSecond = ["A02", 202016, 110]
rowThird = ["A03",202017,120]

# %%
df1 = pd.DataFrame([rowFirst,rowThird,rowSecond])

# %%
df1.columns = ["RegionID" , "YEARWEEK", "QTY"]
columnNameList = df1

# %%
columnFirst = ["A0","A01","A01"]
columnSecond = [202015, 202016, 202017]
columnThird = [100,110,150]

# %%
df2 = pd.DataFrame(zip(columnFirst, columnSecond, columnThird),columns = columnNameList)

# %%
df2.columns = columnNameList

# %%
df2
# Out:
#   (A01, 202015, 100)  (A03, 202017, 120)  (A02, 202016, 110)
# 0                 A0              202015                 100
# 1                A01              202016                 110
# 2                A01              202017                 150

# %% [markdown]
# # 타겟 URL 선언 및 접속

# %%
from bs4 import BeautifulSoup # 태그를 이쁘게 쓰게해준다
import requests # 웹페이지에 접속요청

# %%
targetUrl = "https://sparkkorea.com/%ED%80%B4%EC%A6%88/"

# %%
resp = requests.get(targetUrl)
resp.encoding = 'utf-8'

# %%
html = resp.text

htmlObj = BeautifulSoup(html, "html.parser")

# %%
htmlObj
# Out:
# <!DOCTYPE html>
#
# <html lang="ko-KR">
# <head>
# <meta charset="utf-8"/>
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <link href="http://gmpg.org/xfn/11" rel="profile"/>
# <link href="https://sparkkorea.com/xmlrpc.php" rel="pingback"/>
# <title>퀴즈 – 스파크 코리아</title>
# <meta content="max-image-preview:large" name="robots">
# <meta content="QRZVgHsoL23RuwmgmXNuXfO-mUaxCkdvhP2rRvLT270" name="google-site-verification">
# <!-- Async WordPress.com Remote Login -->
# <script id="wpcom_remote_login_js">
# var wpcom_remote_login_extra_auth = '';
# function wpcom_remote_login_remove_dom_node_id( element_id ) {
# 	var dom_node = document.getElementById( element_id );
# 	if ( dom_node ) { dom_node.parentNode.removeChild( dom_node ); }
# }
# function wpcom_remote_login_remove_dom_node_classes( class_name ) {
# 	var dom_nodes = document.querySelectorAll( '.' + class_name );
# 	for ( var i = 0; i < dom_nodes.length; i++ ) {
# 		dom_nodes[ i ].parentNode.removeChild( dom_nodes[ i ] );
# 	}
# }
# function wpcom_remote_login_final_cleanup() {
# 	wpcom_remote_login_remove_dom_node_classes( "wpcom_remote_login_msg" );
# 	wpcom_remote_login_remove_dom_node_id( "wpcom_remote_login_key" );
# 	wpcom_remote_login_remove_dom_node_id( "wpcom_remote_login_validate" );
# 	wpcom_remote_login_remove_dom_node_id( "wpcom_remote_login_js" );
# 	wpcom_remote_login_remove_dom_node_id( "wpcom_request_access_iframe" );
# 	wpcom_remote_login_remove_dom_node_id( "wpcom_request_access_styles" );
# }
#
# // Watch for messages back from the remote login
# window.addEventListener( "message", function( e ) {
# 	if ( e.origin === "https://r-login.wordpress.com" ) {
# 		var data = {};
# 		try {
# 			data = JSON.parse( e.data );
# 		} catch( e ) {
# 			wpcom_remote_login_final_cleanup();
# 			return;
# 		}
#
# 		if ( data.msg === 'LOGIN' ) {
# 			// Clean up the login check iframe
# 			wpcom_remote_login_remove_dom_node_id( "wpcom_remote_login_key" );
#
# 			var id_regex = new RegExp( /^[0-9]+$/ );
# 			var token_regex = new RegExp( /^.*|.*|.*$/ );
# 			if (
# 				token_regex.test( data.token )
# 				&& id_regex.test( data.wpcomid )
# 			) {
# 				// We have everything we need to ask for a login
# 				var script = document.createElement( "script" );
# 				script.setAttribute( "id", "wpcom_remote_login_validate" );
# 				script.src = '/remote-login.php?wpcom_remote_login=validate'
# 					+ '&wpcomid=' + data.wpcomid
# 					+ '&token=' + encodeURIComponent( data.token )
# 					+ '&host=' + window.location.protocol
# 						+ '//' + window.location.hostname;
# 				document.body.appendChild( script );
# 			}
#
# 			return;
# 		}
#
# 		// Safari ITP, not logged in, so redirect
# 		if ( data.msg === 'LOGIN-REDIRECT' ) {
# 			window.location = 'https://wordpress.com/log-in?redirect_to=' + window.location.href;
# 			return;
# 		}
#
# 		// Safari ITP, storage access failed, remove the request
# 		if ( data.msg === 'LOGIN-REMOVE' ) {
# 			var css_zap = 'html { -webkit-transition: margin-top 1s; transition: margin-top 1s; } /* 9001 */ html { margin-top: 0 !important; } * html body { margin-top: 0 !important; } @media screen and ( max-width: 782px ) { html { margin-top: 0 !important; } * html body { margin-top: 0 !important; } }';
# 			var style_zap = document.createElement( 'style' );
# 			style_zap.type = 'text/css';
# 			style_zap.appendChild( document.createTextNode( css_zap ) );
# 			document.body.appendChild( style_zap );
#
# 			var e = document.getElementById( 'wpcom_request_access_iframe' );
# 			e.parentNode.removeChild( e );
#
# 			document.cookie = 'wordpress_com_login_access=denied; path=/; max-age=31536000';
#
# 			return;
# 		}
#
# 		// Safari ITP
# 		if ( data.msg === 'REQUEST_ACCESS' ) {
# 			console.log( 'request access: safari' );
#
# 			// Check ITP iframe enable/disable knob
# 			if ( wpcom_remote_login_extra_auth !== 'safari_itp_iframe' ) {
# 				return;
# 			}
#
# 			// If we are in a "private window" there is no ITP.
# 			var private_window = false;
# 			try {
# 				var opendb = window.openDatabase( null, null, null, null );
# 			} catch( e ) {
# 				private_window = true;
# 			}
#
# 			if ( private_window ) {
# 				console.log( 'private window' );
# 				return;
# 			}
#
# 			var iframe = document.createElement( 'iframe' );
# 			iframe.id = 'wpcom_request_access_iframe';
# 			iframe.setAttribute( 'scrolling', 'no' );
# 			iframe.setAttribute( 'sandbox', 'allow-storage-access-by-user-activation allow-scripts allow-same-origin allow-top-navigation-by-user-activation' );
# 			iframe.src = 'https://r-login.wordpress.com/remote-login.php?wpcom_remote_login=request_access&origin=' + encodeURIComponent( data.origin ) + '&wpcomid=' + encodeURIComponent( data.wpcomid );
#
# 			var css = 'html { -webkit-transition: margin-top 1s; transition: margin-top 1s; } /* 9001 */ html { margin-top: 46px !important; } * html body { margin-top: 46px !important; } @media screen and ( max-width: 660px ) { html { margin-top: 71px !important; } * html body { margin-top: 71px !important; } #wpcom_request_access_iframe { display: block; height: 71px !important; } } #wpcom_request_access_iframe { border: 0px; height: 46px; position: fixed; top: 0; left: 0; width: 100%; min-width: 100%; z-index: 99999; background: #23282d; } ';
#
# 			var style = document.createElement( 'style' );
# 			style.type = 'text/css';
# 			style.id = 'wpcom_request_access_styles';
# 			style.appendChild( document.createTextNode( css ) );
# 			document.body.appendChild( style );
#
# 			document.body.appendChild( iframe );
# 		}
#
# 		if ( data.msg === 'DONE' ) {
# 			wpcom_remote_login_final_cleanup();
# 		}
# 	}
# }, false );
#
# // Inject the remote login iframe after the page has had a chance to load
# // more critical resources
# window.addEventListener( "DOMContentLoaded", function( e ) {
# 	var iframe = document.createElement( "iframe" );
# 	iframe.style.display = "none";
# 	iframe.setAttribute( "scrolling", "no" );
# 	iframe.setAttribute( "id", "wpcom_remote_login_key" );
# 	iframe.src = "https://r-login.wordpress.com/remote-login.php"
# 		+ "?wpcom_remote_login=key"
# 		+ "&origin=aHR0cHM6Ly9zcGFya2tvcmVhLmNvbQ%3D%3D"
# 		+ "&wpcomid=163927570"
# 		+ "&time=1618297345";
# 	document.body.appendChild( iframe );
# }, false );
# </script>
# <link href="//s2.wp.com" rel="dns-prefetch">
# <link href="//sparkkorea.wordpress.com" rel="dns-prefetch">
# <link href="//s0.wp.com" rel="dns-prefetch"/>
# <link href="//wordpress.com" rel="dns-prefetch"/>
# <link href="//fonts.googleapis.com" rel="dns-prefetch"/>
# <link href="https://sparkkorea.com/feed/" rel="alternate" title="스파크 코리아 » 피드" type="application/rss+xml"/>
# <link href="https://sparkkorea.com/comments/feed/" rel="alternate" title="스파크 코리아 » 댓글 피드" type="application/rss+xml"/>
# <script type="text/javascript">
# 		/* <![CDATA[ */
# 		function addLoadEvent(func) {
# 			var oldonload = window.onload;
# 			if (typeof window.onload != 'function') {
# 				window.onload = func;
# 			} else {
# 				window.onload = function () {
# 					oldonload();
# 					func();
# 				}
# 			}
# 		}
# 		/* ]]> */
# 	</script>
# <script type="text/javascript">
# 			window._wpemojiSettings = {"baseUrl":"https:\/\/
150\uce20 \uc2e0\uace0\ud558\uae30","themeInfo":"\ud14c\ub9c8 \uac00\uc838\uc624\uae30: Dyad 2","shortlink":"\ub2e8\ucd95 \ub9c1\ud06c \ubcf5\uc0ac","copied":"\ubcf5\uc0ac\ub428","followedText":"\uc774 \uc0ac\uc774\ud2b8\uc758 \uc0c8 \uae00\uc774 \uc774\uc81c <a href=\"https:\/\/wordpress.com\/\">\ub274\uc2a4\ud53c\ub4dc<\/a>\uc5d0 \ud45c\uc2dc\ub429\ub2c8\ub2e4.","foldBar":"\uc774 \ud45c\uc2dc\uc904 \ucd95\uc18c","unfoldBar":"\uc774 \ud45c\uc2dc\uc904 \ud655\uc7a5","editSubs":"\uad6c\ub3c5 \uad00\ub9ac","viewReader":"\ub9ac\ub354\uc5d0\uc11c \uc0ac\uc774\ud2b8 \ubcf4\uae30","viewReadPost":"View post in Reader","subscribe":"\uac00\uc785\ud558\uae30","enterEmail":"\uc774\uba54\uc77c \uc8fc\uc18c \uc785\ub825","followers":"","alreadyUser":"\uc774\ubbf8 \uc6cc\ub4dc\ud504\ub808\uc2a4\ub2f7\ucef4 \uacc4\uc815\uc744 \uac16\uace0 \uacc4\uc138\uc694? <a href=\"https:\/\/wordpress.com\/log-in?redirect_to=https%3A%2F%2Fsparkkorea.com%2F%ED%80%B4%EC%A6%88%2F&signup_flow=account&domain=sparkkorea.com\">\uc9c0\uae08 \ub85c\uadf8\uc778\ud558\uc138\uc694.<\/a>","stats":"\ud1b5\uacc4"}};
# </script>
# <script src="https://s2.wp.com/_static/??-eJyFzUEKwkAMheELmQ5DocWFeJZaY8kwyYxJBu3traBQV67e4v/ghUeFuYijeEgWajFnNJsW7JIdwm/lcqGM0Ax1A+JAcitfRzLndkV7w3RvqOtnOib5i4Bp0clxj3fPmh2qlue6tTOf4hDHPvbDeEwvhOVG7A==" type="text/javascript"></script>
# <script type="text/javascript">
# 	window.addEventListener( 'DOMContentLoaded', function() {
# 		rltInitialize( {"token":null,"iframeOrigins":["https:\/\/widgets.wp.com"]} );
# 	} );
# </script>
# <link href="https://sparkkorea.wordpress.com/xmlrpc.php?rsd" rel="EditURI" title="RSD" type="application/rsd+xml"/>
# <link href="https://s1.wp.com/wp-includes/wlwmanifest.xml" rel="wlwmanifest" type="application/wlwmanifest+xml"/>
# <meta content="WordPress.com" name="generator"/>
# <link href="https://sparkkorea.com/%ed%80%b4%ec%a6%88/" rel="canonical"/>
# <link href="https://wp.me/Pb5P34-1E" rel="shortlink"/>
# <link href="https://public-api.wordpress.com/oembed/?format=json&amp;url=https%3A%2F%2Fsparkkorea.com%2F%25ed%2580%25b4%25ec%25a6%2588%2F&amp;for=wpcom-auto-discovery" rel="alternate" type="application/json+oembed"/><link href="https://public-api.wordpress.com/oembed/?format=xml&amp;url=https%3A%2F%2Fsparkkorea.com%2F%25ed%2580%25b4%25ec%25a6%2588%2F&amp;for=wpcom-auto-discovery" rel="alternate" type="application/xml+oembed"/>
# <!-- Jetpack Open Graph Tags -->
# <meta content="article" property="og:type"/>
# <meta content="퀴즈" property="og:title"/>
# <meta content="https://sparkkorea.com/%ed%80%b4%ec%a6%88/" property="og:url"/>
# <meta content="메인 설문 준비중 Spark 퀴즈 6/13 Spark 심화과정 6/13 Spark 기본과정 6/18 Spark [MAP_FILTER] 6/18 Spark GroupBy 심화 6/25 Spark RDD 실전 분석 6/27 Spark RDD 실전 분석2" property="og:description"/>
# <meta content="2019-07-08T09:35:27+00:00" property="article:published_time"/>
# <meta content="2020-03-20T09:42:15+00:00" property="article:modified_time"/>
# <meta content="스파크 코리아" property="og:site_name"/>
# <meta content="https://s0.wp.com/i/blank.jpg" property="og:image"/>
# <meta content="ko_KR" property="og:locale"/>
# <meta content="@wordpressdotcom" name="twitter:site"/>
# <meta content="퀴즈" name="twitter:text:title"/>
# <meta content="summary" name="twitter:card"/>
# <meta content="https://www.facebook.com/WordPresscom" property="article:publisher"/>
# <!-- End Jetpack Open Graph Tags -->
# <link href="https://s1.wp.com/i/favicon.ico" rel="shortcut icon" sizes="16x16 24x24 32x32 48x48" type="image/x-icon"/>
# <link href="https://s1.wp.com/i/favicon.ico" rel="icon" sizes="16x16 24x24 32x32 48x48" type="image/x-icon"/>
# <link href="https://s2.wp.com/i/webclip.png" rel="apple-touch-icon"/>
# <link href="https://sparkkorea.com/osd.xml" rel="search" title="스파크 코리아" type="application/opensearchdescription+xml"/>
# <link href="https://s1.wp.com/opensearch.xml" rel="search" title="WordPress.com" type="application/opensearchdescription+xml"/>
# <meta content="스파크 코리아" name="application-name"/><meta content="width=device-width;height=device-height" name="msapplication-window"/><meta content="스파크코리아 자료공유" name="msapplication-tooltip"/><meta content="name=구독;action-uri=https://sparkkorea.com/feed/;icon-uri=https://s1.wp.com/i/favicon.ico" name="msapplication-task"/><meta content="name=무료 블로그 등록;action-uri=http://wordpress.com/signup/;icon-uri=https://s1.wp.com/i/favicon.ico" name="msapplication-task"/><meta content="name=WordPress.com 지원;action-uri=http://support.wordpress.com/;icon-uri=https://s1.wp.com/i/favicon.ico" name="msapplication-task"/><meta content="name=WordPress.com 포럼;action-uri=http://forums.wordpress.com/;icon-uri=https://s1.wp.com/i/favicon.ico" name="msapplication-task"/><meta content="메인 설문 준비중 Spark 퀴즈 6/13 Spark 심화과정 6/13 Spark 기본과정 6/18 Spark [MAP_FILTER] 6/18 Spark GroupBy 심화 6/25 Spark RDD 실전 분석 6/27 Spark RDD 실전 분석2" name="description"/>
# </link></link></meta></meta></head>
# <body class="page-template-default page page-id-102 wp-embed-responsive customizer-styles-applied is-singular no-js highlander-enabled highlander-light">
# <div class="hfeed site" id="page">
# <a class="skip-link screen-reader-text" href="#content">컨텐츠로 건너뛰기</a>
# <header class="site-header" id="masthead" role="banner">
# <div class="site-branding">
# <h1 class="site-title">
# <a href="https://sparkkorea.com/" rel="home">
# 					스파크 코리아				</a>
# </h1>
# <p class="site-description">스파크코리아 자료공유</p>
# </div><!-- .site-branding -->
# <nav class="main-navigation" id="site-navigation" role="navigation">
# <button aria-controls="primary-menu" aria-expanded="false" class="menu-toggle">메뉴</button>
# <div class="primary-menu"><ul class="menu" id="primary-menu"><li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-27" id="menu-item-27"><a href="https://sparkkorea.com/%ec%9e%90%eb%a3%8c%ec%8b%a4/">자료실</a></li>
# <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-264" id="menu-item-264"><a href="https://sparkkorea.com/%ec%84%a4%eb%ac%b8-2/">설문s</a></li>
# <li class="menu-item menu-item-type-post_type menu-item-object-page current-menu-item page_item page-item-102 current_page_item menu-item-382" id="menu-item-382"><a aria-current="page" href="https://sparkkorea.com/%ed%80%b4%ec%a6%88/">퀴즈</a></li>
# <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-383" id="menu-item-383"><a href="https://sparkkorea.com/%ed%85%8c%ec%8a%a4%ed%8a%b8/">테스트</a></li>
# <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-397" id="menu-item-397"><a href="https://sparkkorea.com/%ec%84%a4%eb%ac%b8/">학생퀴즈</a></li>
# </ul></div> </nav>
# </header><!-- #masthead -->
# <div class="site-inner">
# <div class="site-content" id="content">
# <main class="content-area" id="primary" role="main">
# <article class="post-102 page type-page status-publish hentry" id="post-102">
# <div class="entry-inner">
# <header class="entry-header">
# <h1 class="entry-title">퀴즈</h1> </header><!-- .entry-header -->
# <div class="entry-content">
# <div class="class_general_main" id="id_general_main">
# <h1> 메인 </h1>
# <a href="#"> 설문 준비중 </a>
# <p></p>
# </div>
# <div class="class_spark_quiz" id="id_spark_quiz">
# <h1>Spark 퀴즈 </h1>
# <a href="https://forms.gle/Fw49w9GhWQChDcZm7"> 6/13 Spark 심화과정 </a>
# <p></p>
# <a href="https://forms.gle/G4TcXm3fKuHLHA6D6"> 6/13 Spark 기본과정 </a>
# <p></p>
# <a href="https://forms.gle/M8gr1kC2ubA3UDVp8"> 6/18 Spark [MAP_FILTER] </a>
# <p></p>
# <a href="https://forms.gle/h8w5mZ4MNaPLCPbi6"> 6/18 Spark GroupBy 심화 </a>
# <p></p>
# <a href="https://forms.gle/q5yL6QHfueDLM5w27"> 6/25 Spark RDD 실전 분석 </a>
# <p></p>
# <a href="https://forms.gle/Gxb4y6LfVYiaLu4M7"> 6/27 Spark RDD 실전 분석2 </a>
# <p></p>
# </div>
# <div class="sharedaddy sd-like-enabled sd-sharing-enabled" id="jp-post-flair"><div class="sharedaddy sd-sharing-enabled"><div class="robots-nocontent sd-block sd-social sd-social-icon-text sd-sharing"><h3 class="sd-title">이 글 공유하기:</h3><div class="sd-content"><ul><li class="share-twitter"><a class="share-twitter sd-button share-icon" data-shared="sharing-twitter-102" href="https://sparkkorea.com/%ed%80%b4%ec%a6%88/?share=twitter" rel="nofollow noopener noreferrer" target="_blank" title="트위터로 공유하기"><span>트위터</span></a></li><li class="share-facebook"><a class="share-facebook sd-button share-icon" data-shared="sharing-facebook-102" href="https://sparkkorea.com/%ed%80%b4%ec%a6%88/?share=facebook" rel="nofollow noopener noreferrer" target="_blank" title="페이스북에 공유하려면 클릭하세요."><span>Facebook</span></a></li><li class="share-end"></li></ul></div></div></div><div class="sharedaddy sd-block sd-like jetpack-likes-widget-wrapper jetpack-likes-widget-unloaded" data-name="like-post-frame-163927570-102-60754201240cd" data-src="//widgets.wp.com/likes/index.html?ver=20210317#blog_id=163927570&amp;post_id=102&amp;origin=sparkkorea.wordpress.com&amp;obj_id=163927570-102-60754201240cd&amp;domain=sparkkorea.com" id="like-post-wrapper-163927570-102-60754201240cd"><h3 class="sd-title">이것이 좋아요:</h3><div class="likes-widget-placeholder post-likes-widget-placeholder" style="height: 55px;"><span class="button"><span>좋아하기</span></span> <span class="loading">가져오는 중...</span></div><span class="sd-text-color"></span><a class="sd-link-color"></a></div></div> </div><!-- .entry-content -->
# </div><!-- .entry-inner -->
# </article><!-- #post-## -->
# </main><!-- #main -->
# </div><!-- #content -->
# <footer class="site-footer" id="colophon" role="contentinfo">
# <div class="footer-bottom-info">
# <div class="site-info">
# <a href="https://wordpress.com/?ref=footer_segment_business" rel="nofollow">A WordPress.com Website.</a>
# </div><!-- .site-info -->
# </div><!-- .footer-bottom-info -->
# </footer><!-- #colophon -->
# </div><!-- .site-inner -->
# </div><!-- #page -->
# <!-- -->
# <script id="grofiles-cards-js" src="//0.gravatar.com/js/gprofiles.js?ver=202115y"></script>
# <script id="wpgroho-js-extra">
# var WPGroHo = {"my_hash":""};
# </script>
# <script src="https://s1.wp.com/wp-content/mu-plugins/gravatar-hovercards/wpgroho.js?m=1610363240h" type="text/javascript"></script>
# <script>
# 		// Initialize and attach hovercards to all gravatars
# 		( function() {
# 			function init() {
# 				if ( typeof Gravatar === 'undefined' ) {
# 					return;
# 				}
#
# 				if ( typeof Gravatar.init !== 'function' ) {
# 					return;
# 				}
#
# 				Gravatar.profile_cb = function ( hash, id ) {
# 					WPGroHo.syncProfileData( hash, id );
# 				};
#
# 				Gravatar.my_hash = WPGroHo.my_hash;
# 				Gravatar.init( 'body', '#wp-admin-bar-my-account' );
# 			}
#
# 			if ( document.readyState !== 'loading' ) {
# 				init();
# 			} else {
# 				document.addEventListener( 'DOMContentLoaded', init );
# 			}
# 		} )();
# 	</script>
# <div style="display:none">
# </div>
# <script>
# window.addEventListener( "load", function( event ) {
# 	var link = document.createElement( "link" );
# 	link.href = "https://s0.wp.com/wp-content/mu-plugins/actionbar/actionbar.css?v=20201002";
# 	link.type = "text/css";
# 	link.rel = "stylesheet";
# 	document.head.appendChild( link );
#
# 	var script = document.createElement( "script" );
# 	script.src = "https://s0.wp.com/wp-content/mu-plugins/actionbar/actionbar.js?v=20201002";
# 	script.defer = true;
# 	document.body.appendChild( script );
# } );
# </script>
# <script type="text/javascript">
# 		window.WPCOM_sharing_counts = {"https:\/\/sparkkorea.com\/%ed%80%b4%ec%a6%88\/":102};
# 	</script>
# <script id="comment-like-js-extra">
# var comment_like_text = {"loading":"\uac00\uc838\uc624\ub294 \uc911..."};
# </script>
# <script id="sharing-js-js-extra">
# var sharing_js_options = {"lang":"en","counts":"1","is_stats_active":"1"};
# </script>
# <script src="https://s2.wp.com/_static/??-" type="text/javascript"></script>
# <script type="text/javascript">
# var windowOpen;
# 			( function () {
# 				function matches( el, sel ) {
# 					return !! (
# 						el.matches && el.matches( sel ) ||
# 						el.msMatchesSelector && el.msMatchesSelector( sel )
# 					);
# 				}
#
# 				document.body.addEventListener( 'click', function ( event ) {
# 					if ( ! event.target ) {
# 						return;
# 					}
#
# 					var el;
# 					if ( matches( event.target, 'a.share-twitter' ) ) {
# 						el = event.target;
# 					} else if ( event.target.parentNode && matches( event.target.parentNode, 'a.share-twitter' ) ) {
# 						el = event.target.parentNode;
# 					}
#
# 					if ( el ) {
# 						event.preventDefault();
#
# 						// If there's another sharing window open, close it.
# 						if ( typeof windowOpen !== 'undefined' ) {
# 							windowOpen.close();
# 						}
# 						windowOpen = window.open( el.getAttribute( 'href' ), 'wpcomtwitter', 'menubar=1,resizable=1,width=600,height=350' );
# 						return false;
# 					}
# 				} );
# 			} )();
# var windowOpen;
# 			( function () {
# 				function matches( el, sel ) {
# 					return !! (
# 						el.matches && el.matches( sel ) ||
# 						el.msMatchesSelector && el.msMatchesSelector( sel )
# 					);
# 				}
#
# 				document.body.addEventListener( 'click', function ( event ) {
# 					if ( ! event.target ) {
# 						return;
# 					}
#
# 					var el;
# 					if ( matches( event.target, 'a.share-facebook' ) ) {
# 						el = event.target;
# 					} else if ( event.target.parentNode && matches( event.target.parentNode, 'a.share-facebook' ) ) {
# 						el = event.target.parentNode;
# 					}
#
# 					if ( el ) {
# 						event.preventDefault();
#
# 						// If there's another sharing window open, close it.
# 						if ( typeof windowOpen !== 'undefined' ) {
# 							windowOpen.close();
# 						}
# 						windowOpen = window.open( el.getAttribute( 'href' ), 'wpcomfacebook', 'menubar=1,resizable=1,width=600,height=400' );
# 						return false;
# 					}
# 				} );
# 			} )();
# </script>
# <script type="text/javascript">
# // <![CDATA[
# (function() {
# try{
#   if ( window.external &&'msIsSiteMode' in window.external) {
#     if (window.external.msIsSiteMode()) {
#       var jl = document.createElement('script');
#       jl.type='text/javascript';
#       jl.async=true;
#       jl.src='/wp-content/plugins/ie-sitemode/custom-jumplist.php';
#       var s = document.getElementsByTagName('script')[0];
#       s.parentNode.insertBefore(jl, s);
#     }
#   }
# }catch(e){}
# })();
# // ]]>
# </script> <iframe id="likes-master" name="likes-master" scrolling="no" src="https://widgets.wp.com/likes/master.html?ver=20210317#ver=20210317&amp;lang=ko&amp;origin=https://sparkkorea.com" style="display:none;"></iframe>
# <div id="likes-other-gravatars"><div class="likes-text"><span>%d</span> 블로거가 이것을 좋아합니다:</div><ul class="wpl-avatars sd-like-gravatars"></ul></div>
# <script defer="" src="//stats.wp.com/w.js?61"></script> <script type="text/javascript">
# _tkq = window._tkq || [];
# _stq = window._stq || [];
# _tkq.push(['storeContext', {'blog_id':'163927570','blog_tz':'9','user_lang':'ko','blog_lang':'ko','user_id':'0'}]);
# _stq.push(['view', {'blog':'163927570','v':'wpcom','tz':'9','user_id':'0','post':'102','subd':'sparkkorea'}]);
# _stq.push(['extra', {'crypt':''}]);
# _stq.push([ 'clickTrackerInit', '163927570', '102' ]);
# 	</script>
# <noscript><img alt="" src="https://pixel.wp.com/b.gif?v=noscript" style="height:1px;width:1px;overflow:hidden;position:absolute;bottom:1px;"/></noscript>
# <script>
# if ( 'object' === typeof wpcom_mobile_user_agent_info ) {
#
# 	wpcom_mobile_user_agent_info.init();
# 	var mobileStatsQueryString = "";
#
# 	if( false !== wpcom_mobile_user_agent_info.matchedPlatformName )
# 		mobileStatsQueryString += "&x_" + 'mobile_platforms' + '=' + wpcom_mobile_user_agent_info.matchedPlatformName;
#
# 	if( false !== wpcom_mobile_user_agent_info.matchedUserAgentName )
# 		mobileStatsQueryString += "&x_" + 'mobile_devices' + '=' + wpcom_mobile_user_agent_info.matchedUserAgentName;
#
# 	if( wpcom_mobile_user_agent_info.isIPad() )
# 		mobileStatsQueryString += "&x_" + 'ipad_views' + '=' + 'views';
#
# 	if( "" != mobileStatsQueryString ) {
# 		new Image().src = document.location.protocol + '//pixel.wp.com/g.gif?v=wpcom-no-pv' + mobileStatsQueryString + '&baba=' + Math.random();
# 	}
#
# }
# </script>
# </body>
# </html>

# %% [markdown]
# # 태그값 접근하기

# %%
targetParent = htmlObj.find(name="div", attrs = {"id":"id_spark_quiz"})
targetParent
# Out:
# <div class="class_spark_quiz" id="id_spark_quiz">
# <h1>Spark 퀴즈 </h1>
# <a href="https://forms.gle/Fw49w9GhWQChDcZm7"> 6/13 Spark 심화과정 </a>
# <p></p>
# <a href="https://forms.gle/G4TcXm3fKuHLHA6D6"> 6/13 Spark 기본과정 </a>
# <p></p>
# <a href="https://forms.gle/M8gr1kC2ubA3UDVp8"> 6/18 Spark [MAP_FILTER] </a>
# <p></p>
# <a href="https://forms.gle/h8w5mZ4MNaPLCPbi6"> 6/18 Spark GroupBy 심화 </a>
# <p></p>
# <a href="https://forms.gle/q5yL6QHfueDLM5w27"> 6/25 Spark RDD 실전 분석 </a>
# <p></p>
# <a href="https://forms.gle/Gxb4y6LfVYiaLu4M7"> 6/27 Spark RDD 실전 분석2 </a>
# <p></p>
# </div>

# %%
value = [] # 타이틀 값을 넣어줄 리스트
link = [] # 링크 값을 넣어줄 리스트
aTags = targetParent.findAll(name="a") # 태그 A로 시작하는 것을 모두 찾아줌


for i in range(0, len(aTags)):
    title = aTags[i].text     # A태그 안의 내용을 Title변수에 담음
    value.append(title)       # title변수를 value리스트에 추가함
    link2 = aTags[i].attrs["href"]  # A태그 안의 링크를 link2변숭 ㅔ담음
    link.append(link2)              # link2 변수를 link변수에 담음
    
pd.DataFrame(zip (value, link), columns=["퀴즈타이틀","링크"])  # zip을 사용하여 2가지 배열을 하나의 데이터프레임 형식으로 출력함
# Out:
#                        퀴즈타이틀                                   링크
# 0           6/13 Spark 심화과정   https://forms.gle/Fw49w9GhWQChDcZm7
# 1           6/13 Spark 기본과정   https://forms.gle/G4TcXm3fKuHLHA6D6
# 2   6/18 Spark [MAP_FILTER]   https://forms.gle/M8gr1kC2ubA3UDVp8
# 3     6/18 Spark GroupBy 심화   https://forms.gle/h8w5mZ4MNaPLCPbi6
# 4      6/25 Spark RDD 실전 분석   https://forms.gle/q5yL6QHfueDLM5w27
# 5     6/27 Spark RDD 실전 분석2   https://forms.gle/Gxb4y6LfVYiaLu4M7

# %%
value = []
link = []
aTags = targetParent.findAll(name="a")
aTags

for i in range(0, len(aTags)):
    aTags[i].text
# Out:
# [<a href="https://forms.gle/Fw49w9GhWQChDcZm7"> 6/13 Spark 심화과정 </a>,
#  <a href="https://forms.gle/G4TcXm3fKuHLHA6D6"> 6/13 Spark 기본과정 </a>,
#  <a href="https://forms.gle/M8gr1kC2ubA3UDVp8"> 6/18 Spark [MAP_FILTER] </a>,
#  <a href="https://forms.gle/h8w5mZ4MNaPLCPbi6"> 6/18 Spark GroupBy 심화 </a>,
#  <a href="https://forms.gle/q5yL6QHfueDLM5w27"> 6/25 Spark RDD 실전 분석 </a>,
#  <a href="https://forms.gle/Gxb4y6LfVYiaLu4M7"> 6/27 Spark RDD 실전 분석2 </a>]

# %% [markdown]
# # 테이블 스크랩

# %%
import requests, bs4
import pandas as pd

#웹페이지 html 소스 가져오기
resp = requests.get("https://sparkkorea.com/테스트/")
resp.encoding='utf-8'
html = resp.text
htmlObj = bs4.BeautifulSoup(html, 'html.parser')
htmlObj
# Out:
# <!DOCTYPE html>
#
# <html lang="ko-KR">
# <head>
# <meta charset="utf-8"/>
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <link href="http://gmpg.org/xfn/11" rel="profile"/>
# <link href="https://sparkkorea.com/xmlrpc.php" rel="pingback"/>
# <title>테스트 – 스파크 코리아</title>
# <meta content="max-image-preview:large" name="robots">
# <meta content="QRZVgHsoL23RuwmgmXNuXfO-mUaxCkdvhP2rRvLT270" name="google-site-verification">
# <!-- Async WordPress.com Remote Login -->
# <script id="wpcom_remote_login_js">
# var wpcom_remote_login_extra_auth = '';
# function wpcom_remote_login_remove_dom_node_id( element_id ) {
# 	var dom_node = document.getElementById( element_id );
# 	if ( dom_node ) { dom_node.parentNode.removeChild( dom_node ); }
# }
# function wpcom_remote_login_remove_dom_node_classes( class_name ) {
# 	var dom_nodes = document.querySelectorAll( '.' + class_name );
# 	for ( var i = 0; i < dom_nodes.length; i++ ) {
# 		dom_nodes[ i ].parentNode.removeChild( dom_nodes[ i ] );
# 	}
# }
# function wpcom_remote_login_final_cleanup() {
# 	wpcom_remote_login_remove_dom_node_classes( "wpcom_remote_login_msg" );
# 	wpcom_remote_login_remove_dom_node_id( "wpcom_remote_login_key" );
# 	wpcom_remote_login_remove_dom_node_id( "wpcom_remote_login_validate" );
# 	wpcom_remote_login_remove_dom_node_id( "wpcom_remote_login_js" );
# 	wpcom_remote_login_remove_dom_node_id( "wpcom_request_access_iframe" );
# 	wpcom_remote_login_remove_dom_node_id( "wpcom_request_access_styles" );
# }
#
# // Watch for messages back from the remote login
# window.addEventListener( "message", function( e ) {
# 	if ( e.origin === "https://r-login.wordpress.com" ) {
# 		var data = {};
# 		try {
# 			data = JSON.parse( e.data );
# 		} catch( e ) {
# 			wpcom_remote_login_final_cleanup();
# 			return;
# 		}
#
# 		if ( data.msg === 'LOGIN' ) {
# 			// Clean up the login check iframe
# 			wpcom_remote_login_remove_dom_node_id( "wpcom_remote_login_key" );
#
# 			var id_regex = new RegExp( /^[0-9]+$/ );
# 			var token_regex = new RegExp( /^.*|.*|.*$/ );
# 			if (
# 				token_regex.test( data.token )
# 				&& id_regex.test( data.wpcomid )
# 			) {
# 				// We have everything we need to ask for a login
# 				var script = document.createElement( "script" );
# 				script.setAttribute( "id", "wpcom_remote_login_validate" );
# 				script.src = '/remote-login.php?wpcom_remote_login=validate'
# 					+ '&wpcomid=' + data.wpcomid
# 					+ '&token=' + encodeURIComponent( data.token )
# 					+ '&host=' + window.location.protocol
# 						+ '//' + window.location.hostname;
# 				document.body.appendChild( script );
# 			}
#
# 			return;
# 		}
#
# 		// Safari ITP, not logged in, so redirect
# 		if ( data.msg === 'LOGIN-REDIRECT' ) {
# 			window.location = 'https://wordpress.com/log-in?redirect_to=' + window.location.href;
# 			return;
# 		}
#
# 		// Safari ITP, storage access failed, remove the request
# 		if ( data.msg === 'LOGIN-REMOVE' ) {
# 			var css_zap = 'html { -webkit-transition: margin-top 1s; transition: margin-top 1s; } /* 9001 */ html { margin-top: 0 !important; } * html body { margin-top: 0 !important; } @media screen and ( max-width: 782px ) { html { margin-top: 0 !important; } * html body { margin-top: 0 !important; } }';
# 			var style_zap = document.createElement( 'style' );
# 			style_zap.type = 'text/css';
# 			style_zap.appendChild( document.createTextNode( css_zap ) );
# 			document.body.appendChild( style_zap );
#
# 			var e = document.getElementById( 'wpcom_request_access_iframe' );
# 			e.parentNode.removeChild( e );
#
# 			document.cookie = 'wordpress_com_login_access=denied; path=/; max-age=31536000';
#
# 			return;
# 		}
#
# 		// Safari ITP
# 		if ( data.msg === 'REQUEST_ACCESS' ) {
# 			console.log( 'request access: safari' );
#
# 			// Check ITP iframe enable/disable knob
# 			if ( wpcom_remote_login_extra_auth !== 'safari_itp_iframe' ) {
# 				return;
# 			}
#
# 			// If we are in a "private window" there is no ITP.
# 			var private_window = false;
# 			try {
# 				var opendb = window.openDatabase( null, null, null, null );
# 			} catch( e ) {
# 				private_window = true;
# 			}
#
# 			if ( private_window ) {
# 				console.log( 'private window' );
# 				return;
# 			}
#
# 			var iframe = document.createElement( 'iframe' );
# 			iframe.id = 'wpcom_request_access_iframe';
# 			iframe.setAttribute( 'scrolling', 'no' );
# 			iframe.setAttribute( 'sandbox', 'allow-storage-access-by-user-activation allow-scripts allow-same-origin allow-top-navigation-by-user-activation' );
# 			iframe.src = 'https://r-login.wordpress.com/remote-login.php?wpcom_remote_login=request_access&origin=' + encodeURIComponent( data.origin ) + '&wpcomid=' + encodeURIComponent( data.wpcomid );
#
# 			var css = 'html { -webkit-transition: margin-top 1s; transition: margin-top 1s; } /* 9001 */ html { margin-top: 46px !important; } * html body { margin-top: 46px !important; } @media screen and ( max-width: 660px ) { html { margin-top: 71px !important; } * html body { margin-top: 71px !important; } #wpcom_request_access_iframe { display: block; height: 71px !important; } } #wpcom_request_access_iframe { border: 0px; height: 46px; position: fixed; top: 0; left: 0; width: 100%; min-width: 100%; z-index: 99999; background: #23282d; } ';
#
# 			var style = document.createElement( 'style' );
# 			style.type = 'text/css';
# 			style.id = 'wpcom_request_access_styles';
# 			style.appendChild( document.createTextNode( css ) );
# 			document.body.appendChild( style );
#
# 			document.body.appendChild( iframe );
# 		}
#
# 		if ( data.msg === 'DONE' ) {
# 			wpcom_remote_login_final_cleanup();
# 		}
# 	}
# }, false );
#
# // Inject the remote login iframe after the page has had a chance to load
# // more critical resources
# window.addEventListener( "DOMContentLoaded", function( e ) {
# 	var iframe = document.createElement( "iframe" );
# 	iframe.style.display = "none";
# 	iframe.setAttribute( "scrolling", "no" );
# 	iframe.setAttribute( "id", "wpcom_remote_login_key" );
# 	iframe.src = "https://r-login.wordpress.com/remote-login.php"
# 		+ "?wpcom_remote_login=key"
# 		+ "&origin=aHR0cHM6Ly9zcGFya2tvcmVhLmNvbQ%3D%3D"
# 		+ "&wpcomid=163927570"
# 		+ "&time=1618303280";
# 	document.body.appendChild( iframe );
# }, false );
# </script>
# <link href="//s2.wp.com" rel="dns-prefetch">
# <link href="//sparkkorea.wordpress.com" rel="dns-prefetch">
# <link href="//s0.wp.com" rel="dns-prefetch"/>
# <link href="//wordpress.com" rel="dns-prefetch"/>
# <link href="//fonts.googleapis.com" rel="dns-prefetch"/>
# <link href="https://sparkkorea.com/feed/" rel="alternate" title="스파크 코리아 » 피드" type="application/rss+xml"/>
# <link href="https://sparkkorea.com/comments/feed/" rel="alternate" title="스파크 코리아 » 댓글 피드" type="application/rss+xml"/>
# <script type="text/javascript">
# 		/* <![CDATA[ */
# 		function addLoadEvent(func) {
# 			var oldonload = window.onload;
# 			if (typeof window.onload != 'function') {
# 				window.onload = func;
# 			} else {
# 				window.onload = function () {
# 					oldonload();
# 					func();
# 				}
# 			}
# 		}
# 		/* ]]> */
# 	</script>
# <script type="text/javascript">
# 			window._wpemojiSettings = {"baseUrl":"https:\/\/s0.wp.com\/wp-content\/mu-plugins\/wpcom-smileys\/twemoji\/2\/72x72\/","ext":".png","svgUrl":"https:\/\/s0.wp.com\/wp-content\/mu-plugins\/wpcom-smileys\/twemoji\/2\/svg\/","svgExt":".svg","source":{"concatemoji":"https:\/\/s0.wp.com\/wp-includes\/js\/wp-emoji-release.min.js?m=1612197847h&ver=5.7.1-RC1-50691"}};
# 			!function(e,a,t){var n,r,o,i=a.createElement("canvas"),p=i.getContext&&i.getContext("2d");function s(e,t){var a=String.fromCharCode;p.clearRect(0,0,i.width,i.height),p.fillText(a.apply(this,e),0,0);e=i.toDataURL();return p.clearRect(0,0,i.width,i.height),p.fillText(a.apply(this,t),0,0),e===i.toDataURL()}function c(e){var t=a.createElement("script");t.src=e,t.defer=t.type="text/javascript",a.getElementsByTagName("head")[0].appendChild(t)}for(o=Array("flag","emoji"),t.supports={everything:!0,everythingExceptFlag:!0},r=0;r<o.length;r++)t.supports[o[r]]=function(e){if(!p||!p.fillText)return!1;switch(p.textBaseline="top",p.font="600 32px Arial",e){case"flag":return s([127987,65039,8205,9895,65039],[127987,65039,8203,9895,65039])?!1:!s([55356,56826,55356,56819],[55356,56826,8203,55356,56819])&&!s([55356,57332,56128,56423,56128,56418,56128,56421,56128,56430,56128,56423,56128,56447],[55356,57332,8203,56128,56423,8203,56128,56418,8203,56128,56421,8203,56128,56430,8203,56128,56423,8203,56128,56447]);case"emoji":return!s([55357,56424,8205,55356,57212],[55357,56424,8203,55356,57212])}return!1}(o[r]),t.supports.everything=t.supports.everything&&t.supports[o[r]],"flag"!==o[r]&&(t.supports.everythingExceptFlag=t.supports.everythingExceptFlag&&t.supports[o[r]]);t.supports.everythingExceptFlag=t.supports.everythingExceptFlag&&!t.supports.flag,t.DOMReady=!1,t.readyCallback=function(){t.DOMReady=!0},t.supports.everything||(n=function(){t.readyCallback()},a.addEventListener?(a.addEventListener("DOMContentLoaded",n,!1),e.addEventListener("load",n,!1)):(e.attachEvent("onload",n),a.attachEvent("onreadystatechange",function(){"complete"===a.readyState&&t.readyCallback()})),(n=t.source||{}).concatemoji?c(n.concatemoji):n.wpemoji&&n.twemoji&&(c(n.twemoji),c(n.wpemoji)))}(window,document,window._wpemojiSettings);
# 		</script>
# <style type="text/css">
# img.wp-smiley,
# img.emoji {
# 	display: inline !important;
# 	border: none !important;
# 	box-shadow: none !important;
# 	height: 1em !important;
# 	width: 1em !important;
# 	margin: 0 .07em !important;
# 	vertical-align: -0.1em !important;
# 	background: none !important;
# 	padding: 0 !important;
# }
# </style>
# <link href="https://s1.wp.com/_static/??-?cssminify=yes" id="all-css-0-1" media="all" rel="stylesheet" type="text/css"/>
# <style id="wp-block-library-inline-css">
# .has-text-align-justify {
# 	text-align:justify;
# }
# </style>
# <link crossorigin="anonymous" href="https://fonts.googleapis.com/css?family=Lato%3A400%2C400italic%2C700%2C700italic%7CNoto+Serif%3A400%2C400italic%2C700%2C700italic&amp;subset=latin%2Clatin-ext" id="dyad-2-fonts-css" media="all" rel="stylesheet"/>
# <link href="https://s0.wp.com/_static/??-eJyNj80OgjAQhF/IdSkkxovxWUpZa7XdNv0J4e2pcFBiNNxmsvNNZnEMoDxn4oyuQLBFG06oiSmaevghjyqlA36w+U6OEobS4zDJAVpMebK0I1cT2FuvnntKDau1GMagvPsiNi94qLUyG88bAzcrTfyHRqqDdJV6Wfe2L+jqLuLUdOIsurZ5zCp8dh4=?cssminify=yes" id="all-css-2-1" media="all" rel="stylesheet" type="text/css"/>
# <link href="https://s2.wp.com/wp-content/mu-plugins/global-print/global-print.css?m=1465851035h&amp;cssminify=yes" id="print-css-3-1" media="print" rel="stylesheet" type="text/css"/>
# <style id="jetpack-global-styles-frontend-style-inline-css">
# :root { --font-headings: unset; --font-base: unset; --font-headings-default: -apple-system,BlinkMacSystemFont,"Segoe UI",Roboto,Oxygen-Sans,Ubuntu,Cantarell,"Helvetica Neue",sans-serif; --font-base-default: -apple-system,BlinkMacSystemFont,"Segoe UI",Roboto,Oxygen-Sans,Ubuntu,Cantarell,"Helvetica Neue",sans-serif;}
# </style>
# <link href="https://s1.wp.com/_static/??-eJxti0EKgCAQAD+ULUaJl+gtJqbG6opr9P3o0CHqNAzMwFmEpdxcbpAOUfDwMTMU4iY2NLECB1Nj9g97y9zB/8Vko0GB5Oktn6kFlxxDGMEjrQbvYEmzVHIclNZy2i9lFDfR?cssminify=yes" id="all-css-6-1" media="all" rel="stylesheet" type="text/css"/>
# <script id="wpcom-actionbar-placeholder-js-extra">
https:\/\/wordpress.com\/log-in?redirect_to=https%3A%2F%2Fsparkkorea.com%2F%ED%85%8C%EC%8A%A4%ED%8A%B8%2F&signup_flow=account&domain=sparkkorea.com\">\uc9c0\uae08 \ub85c\uadf8\uc778\ud558\uc138\uc694.<\/a>","stats":"\ud1b5\uacc4"}};
# </script>
# <script src="https://s2.wp.com/_static/??-eJyFzUEKwkAMheELmQ5DocWFeJZaY8kwyYxJBu3traBQV67e4v/ghUeFuYijeEgWajFnNJsW7JIdwm/lcqGM0Ax1A+JAcitfRzLndkV7w3RvqOtnOib5i4Bp0clxj3fPmh2qlue6tTOf4hDHPvbDeEwvhOVG7A==" type="text/javascript"></script>
# <script type="text/javascript">
# 	window.addEventListener( 'DOMContentLoaded', function() {
# 		rltInitialize( {"token":null,"iframeOrigins":["https:\/\/widgets.wp.com"]} );
# 	} );
# </script>
# <link href="https://sparkkorea.wordpress.com/xmlrpc.php?rsd" rel="EditURI" title="RSD" type="application/rsd+xml"/>
# <link href="https://s1.wp.com/wp-includes/wlwmanifest.xml" rel="wlwmanifest" type="application/wlwmanifest+xml"/>
# <meta content="WordPress.com" name="generator"/>
# <link href="https://sparkkorea.com/%ed%85%8c%ec%8a%a4%ed%8a%b8/" rel="canonical"/>
# <link href="https://wp.me/Pb5P34-1Q" rel="shortlink"/>
# <link href="https://public-api.wordpress.com/oembed/?format=json&amp;url=https%3A%2F%2Fsparkkorea.com%2F%25ed%2585%258c%25ec%258a%25a4%25ed%258a%25b8%2F&amp;for=wpcom-auto-discovery" rel="alternate" type="application/json+oembed"/><link href="https://public-api.wordpress.com/oembed/?format=xml&amp;url=https%3A%2F%2Fsparkkorea.com%2F%25ed%2585%258c%25ec%258a%25a4%25ed%258a%25b8%2F&amp;for=wpcom-auto-discovery" rel="alternate" type="application/xml+oembed"/>
# <!-- Jetpack Open Graph Tags -->
# <meta content="article" property="og:type"/>
# <meta content="테스트" property="og:title"/>
# <meta content="https://sparkkorea.com/%ed%85%8c%ec%8a%a4%ed%8a%b8/" property="og:url"/>
# <meta content="학번 이름 101 김효관 102 이순신 103 김어진" property="og:description"/>
# <meta content="2019-07-11T12:47:37+00:00" property="article:published_time"/>
# <meta content="2019-07-11T13:33:47+00:00" property="article:modified_time"/>
# <meta content="스파크 코리아" property="og:site_name"/>
# <meta content="https://s0.wp.com/i/blank.jpg" property="og:image"/>
# <meta content="ko_KR" property="og:locale"/>
# <meta content="@wordpressdotcom" name="twitter:site"/>
# <meta content="테스트" name="twitter:text:title"/>
# <meta content="summary" name="twitter:card"/>
# <meta content="https://www.facebook.com/WordPresscom" property="article:publisher"/>
# <!-- End Jetpack Open Graph Tags -->
# <link href="https://s1.wp.com/i/favicon.ico" rel="shortcut icon" sizes="16x16 24x24 32x32 48x48" type="image/x-icon"/>
# <link href="https://s1.wp.com/i/favicon.ico" rel="icon" sizes="16x16 24x24 32x32 48x48" type="image/x-icon"/>
# <link href="https://s2.wp.com/i/webclip.png" rel="apple-touch-icon"/>
# <link href="https://sparkkorea.com/osd.xml" rel="search" title="스파크 코리아" type="application/opensearchdescription+xml"/>
# <link href="https://s1.wp.com/opensearch.xml" rel="search" title="WordPress.com" type="application/opensearchdescription+xml"/>
# <meta content="스파크 코리아" name="application-name"/><meta content="width=device-width;height=device-height" name="msapplication-window"/><meta content="스파크코리아 자료공유" name="msapplication-tooltip"/><meta content="name=구독;action-uri=https://sparkkorea.com/feed/;icon-uri=https://s1.wp.com/i/favicon.ico" name="msapplication-task"/><meta content="name=무료 블로그 등록;action-uri=http://wordpress.com/signup/;icon-uri=https://s1.wp.com/i/favicon.ico" name="msapplication-task"/><meta content="name=WordPress.com 지원;action-uri=http://support.wordpress.com/;icon-uri=https://s1.wp.com/i/favicon.ico" name="msapplication-task"/><meta content="name=WordPress.com 포럼;action-uri=http://forums.wordpress.com/;icon-uri=https://s1.wp.com/i/favicon.ico" name="msapplication-task"/><meta content="학번 이름 101 김효관 102 이순신 103 김어진" name="description"/>
# </link></link></meta></meta></head>
# <body class="page-template-default page page-id-114 wp-embed-responsive customizer-styles-applied is-singular no-js highlander-enabled highlander-light">
# <div class="hfeed site" id="page">
# <a class="skip-link screen-reader-text" href="#content">컨텐츠로 건너뛰기</a>
# <header class="site-header" id="masthead" role="banner">
# <div class="site-branding">
# <h1 class="site-title">
# <a href="https://sparkkorea.com/" rel="home">
# 					스파크 코리아				</a>
# </h1>
# <p class="site-description">스파크코리아 자료공유</p>
# </div><!-- .site-branding -->
# <nav class="main-navigation" id="site-navigation" role="navigation">
# <button aria-controls="primary-menu" aria-expanded="false" class="menu-toggle">메뉴</button>
# <div class="primary-menu"><ul class="menu" id="primary-menu"><li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-27" id="menu-item-27"><a href="https://sparkkorea.com/%ec%9e%90%eb%a3%8c%ec%8b%a4/">자료실</a></li>
# <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-264" id="menu-item-264"><a href="https://sparkkorea.com/%ec%84%a4%eb%ac%b8-2/">설문s</a></li>
# <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-382" id="menu-item-382"><a href="https://sparkkorea.com/%ed%80%b4%ec%a6%88/">퀴즈</a></li>
# <li class="menu-item menu-item-type-post_type menu-item-object-page current-menu-item page_item page-item-114 current_page_item menu-item-383" id="menu-item-383"><a aria-current="page" href="https://sparkkorea.com/%ed%85%8c%ec%8a%a4%ed%8a%b8/">테스트</a></li>
# <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-397" id="menu-item-397"><a href="https://sparkkorea.com/%ec%84%a4%eb%ac%b8/">학생퀴즈</a></li>
# </ul></div> </nav>
# </header><!-- #masthead -->
# <div class="site-inner">
# <div class="site-content" id="content">
# <main class="content-area" id="primary" role="main">
# <article class="post-114 page type-page status-publish hentry" id="post-114">
# <div class="entry-inner">
# <header class="entry-header">
# <h1 class="entry-title">테스트</h1> </header><!-- .entry-header -->
# <div class="entry-content">
# <table class="type07" id="test_table">
# <thead>
# <tr>
# <th scope="cols">학번</th>
# <th scope="cols">이름</th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <td>101</td>
# <td>김효관</td>
# </tr>
# <tr>
# <td>102</td>
# <td>이순신</td>
# </tr>
# <tr>
# <td>103</td>
# <td>김어진</td>
# </tr>
# </tbody>
# </table>
# <p></p>
# <div class="sharedaddy sd-like-enabled sd-sharing-enabled" id="jp-post-flair"><div class="sharedaddy sd-sharing-enabled"><div class="robots-nocontent sd-block sd-social sd-social-icon-text sd-sharing"><h3 class="sd-title">이 글 공유하기:</h3><div class="sd-content"><ul><li class="share-twitter"><a class="share-twitter sd-button share-icon" data-shared="sharing-twitter-114" href="https://sparkkorea.com/%ed%85%8c%ec%8a%a4%ed%8a%b8/?share=twitter" rel="nofollow noopener noreferrer" target="_blank" title="트위터로 공유하기"><span>트위터</span></a></li><li class="share-facebook"><a class="share-facebook sd-button share-icon" data-shared="sharing-facebook-114" href="https://sparkkorea.com/%ed%85%8c%ec%8a%a4%ed%8a%b8/?share=facebook" rel="nofollow noopener noreferrer" target="_blank" title="페이스북에 공유하려면 클릭하세요."><span>Facebook</span></a></li><li class="share-end"></li></ul></div></div></div><div class="sharedaddy sd-block sd-like jetpack-likes-widget-wrapper jetpack-likes-widget-unloaded" data-name="like-post-frame-163927570-114-607559303b803" data-src="//widgets.wp.com/likes/index.html?ver=20210317#blog_id=163927570&amp;post_id=114&amp;origin=sparkkorea.wordpress.com&amp;obj_id=163927570-114-607559303b803&amp;domain=sparkkorea.com" id="like-post-wrapper-163927570-114-607559303b803"><h3 class="sd-title">이것이 좋아요:</h3><div class="likes-widget-placeholder post-likes-widget-placeholder" style="height: 55px;"><span class="button"><span>좋아하기</span></span> <span class="loading">가져오는 중...</span></div><span class="sd-text-color"></span><a class="sd-link-color"></a></div></div> </div><!-- .entry-content -->
# </div><!-- .entry-inner -->
# </article><!-- #post-## -->
# </main><!-- #main -->
# </div><!-- #content -->
# <footer class="site-footer" id="colophon" role="contentinfo">
# <div class="footer-bottom-info">
# <div class="site-info">
# <a href="https://wordpress.com/?ref=footer_segment_business" rel="nofollow">A WordPress.com Website.</a>
# </div><!-- .site-info -->
# </div><!-- .footer-bottom-info -->
# </footer><!-- #colophon -->
# </div><!-- .site-inner -->
# </div><!-- #page -->
# <!-- -->
# <script id="grofiles-cards-js" src="//0.gravatar.com/js/gprofiles.js?ver=202115y"></script>
# <script id="wpgroho-js-extra">
# var WPGroHo = {"my_hash":""};
# </script>
# <script src="https://s1.wp.com/wp-content/mu-plugins/gravatar-hovercards/wpgroho.js?m=1610363240h" type="text/javascript"></script>
# <script>
# 		// Initialize and attach hovercards to all gravatars
# 		( function() {
# 			function init() {
# 				if ( typeof Gravatar === 'undefined' ) {
# 					return;
# 				}
#
# 				if ( typeof Gravatar.init !== 'function' ) {
# 					return;
# 				}
#
# 				Gravatar.profile_cb = function ( hash, id ) {
# 					WPGroHo.syncProfileData( hash, id );
# 				};
#
# 				Gravatar.my_hash = WPGroHo.my_hash;
# 				Gravatar.init( 'body', '#wp-admin-bar-my-account' );
# 			}
#
# 			if ( document.readyState !== 'loading' ) {
# 				init();
# 			} else {
# 				document.addEventListener( 'DOMContentLoaded', init );
# 			}
# 		} )();
# 	</script>
# <div style="display:none">
# </div>
# <script>
# window.addEventListener( "load", function( event ) {
# 	var link = document.createElement( "link" );
# 	link.href = "https://s0.wp.com/wp-content/mu-plugins/actionbar/actionbar.css?v=20201002";
# 	link.type = "text/css";
# 	link.rel = "stylesheet";
# 	document.head.appendChild( link );
#
# 	var script = document.createElement( "script" );
# 	script.src = "https://s0.wp.com/wp-content/mu-plugins/actionbar/actionbar.js?v=20201002";
# 	script.defer = true;
# 	document.body.appendChild( script );
# } );
# </script>
# <script type="text/javascript">
# 		window.WPCOM_sharing_counts = {"https:\/\/sparkkorea.com\/%ed%85%8c%ec%8a%a4%ed%8a%b8\/":114};
# 	</script>
# <script id="comment-like-js-extra">
# var comment_like_text = {"loading":"\uac00\uc838\uc624\ub294 \uc911..."};
# </script>
# <script id="sharing-js-js-extra">
# var sharing_js_options = {"lang":"en","counts":"1","is_stats_active":"1"};
# </script>
# <script src="https://s2.wp.com/_static/??-" type="text/javascript"></script>
# <script type="text/javascript">
# var windowOpen;
# 			( function () {
# 				function matches( el, sel ) {
# 					return !! (
# 						el.matches && el.matches( sel ) ||
# 						el.msMatchesSelector && el.msMatchesSelector( sel )
# 					);
# 				}
#
# 				document.body.addEventListener( 'click', function ( event ) {
# 					if ( ! event.target ) {
# 						return;
# 					}
#
# 					var el;
# 					if ( matches( event.target, 'a.share-twitter' ) ) {
# 						el = event.target;
# 					} else if ( event.target.parentNode && matches( event.target.parentNode, 'a.share-twitter' ) ) {
# 						el = event.target.parentNode;
# 					}
#
# 					if ( el ) {
# 						event.preventDefault();
#
# 						// If there's another sharing window open, close it.
# 						if ( typeof windowOpen !== 'undefined' ) {
# 							windowOpen.close();
# 						}
# 						windowOpen = window.open( el.getAttribute( 'href' ), 'wpcomtwitter', 'menubar=1,resizable=1,width=600,height=350' );
# 						return false;
# 					}
# 				} );
# 			} )();
# var windowOpen;
# 			( function () {
# 				function matches( el, sel ) {
# 					return !! (
# 						el.matches && el.matches( sel ) ||
# 						el.msMatchesSelector && el.msMatchesSelector( sel )
# 					);
# 				}
#
# 				document.body.addEventListener( 'click', function ( event ) {
# 					if ( ! event.target ) {
# 						return;
# 					}
#
# 					var el;
# 					if ( matches( event.target, 'a.share-facebook' ) ) {
# 						el = event.target;
# 					} else if ( event.target.parentNode && matches( event.target.parentNode, 'a.share-facebook' ) ) {
# 						el = event.target.parentNode;
# 					}
#
# 					if ( el ) {
# 						event.preventDefault();
#
# 						// If there's another sharing window open, close it.
# 						if ( typeof windowOpen !== 'undefined' ) {
# 							windowOpen.close();
# 						}
# 						windowOpen = window.open( el.getAttribute( 'href' ), 'wpcomfacebook', 'menubar=1,resizable=1,width=600,height=400' );
# 						return false;
# 					}
# 				} );
# 			} )();
# </script>
# <script type="text/javascript">
# // <![CDATA[
# (function() {
# try{
#   if ( window.external &&'msIsSiteMode' in window.external) {
#     if (window.external.msIsSiteMode()) {
#       var jl = document.createElement('script');
#       jl.type='text/javascript';
#       jl.async=true;
#       jl.src='/wp-content/plugins/ie-sitemode/custom-jumplist.php';
#       var s = document.getElementsByTagName('script')[0];
#       s.parentNode.insertBefore(jl, s);
#     }
#   }
# }catch(e){}
# })();
# // ]]>
# </script> <iframe id="likes-master" name="likes-master" scrolling="no" src="https://widgets.wp.com/likes/master.html?ver=20210317#ver=20210317&amp;lang=ko&amp;origin=https://sparkkorea.com" style="display:none;"></iframe>
# <div id="likes-other-gravatars"><div class="likes-text"><span>%d</span> 블로거가 이것을 좋아합니다:</div><ul class="wpl-avatars sd-like-gravatars"></ul></div>
# <script defer="" src="//stats.wp.com/w.js?61"></script> <script type="text/javascript">
# _tkq = window._tkq || [];
# _stq = window._stq || [];
# _tkq.push(['storeContext', {'blog_id':'163927570','blog_tz':'9','user_lang':'ko','blog_lang':'ko','user_id':'0'}]);
# _stq.push(['view', {'blog':'163927570','v':'wpcom','tz':'9','user_id':'0','post':'114','subd':'sparkkorea'}]);
# _stq.push(['extra', {'crypt':''}]);
# _stq.push([ 'clickTrackerInit', '163927570', '114' ]);
# 	</script>
# <noscript><img alt="" src="https://pixel.wp.com/b.gif?v=noscript" style="height:1px;width:1px;overflow:hidden;position:absolute;bottom:1px;"/></noscript>
# <script>
# if ( 'object' === typeof wpcom_mobile_user_agent_info ) {
#
# 	wpcom_mobile_user_agent_info.init();
# 	var mobileStatsQueryString = "";
#
# 	if( false !== wpcom_mobile_user_agent_info.matchedPlatformName )
# 		mobileStatsQueryString += "&x_" + 'mobile_platforms' + '=' + wpcom_mobile_user_agent_info.matchedPlatformName;
#
# 	if( false !== wpcom_mobile_user_agent_info.matchedUserAgentName )
# 		mobileStatsQueryString += "&x_" + 'mobile_devices' + '=' + wpcom_mobile_user_agent_info.matchedUserAgentName;
#
# 	if( wpcom_mobile_user_agent_info.isIPad() )
# 		mobileStatsQueryString += "&x_" + 'ipad_views' + '=' + 'views';
#
# 	if( "" != mobileStatsQueryString ) {
# 		new Image().src = document.location.protocol + '//pixel.wp.com/g.gif?v=wpcom-no-pv' + mobileStatsQueryString + '&baba=' + Math.random();
# 	}
#
# }
# </script>
# </body>
# </html>

# %%
columnList = []
rowList = []
tableTag = htmlObj.find(name="table", attrs={"id":"test_table"})
tbodyTag = tableTag.find(name="tbody")
trs = tbodyTag.find_all(name="tr")
for i in range(0, len(trs)):
    
    eachTr = trs[i]
    tds = eachTr.find_all("td")
    
    for j in range(0, len(tds)):
        td = tds[j].text
        
        
        columnList.append(td)
    rowList.append(columnList)
    columnList = []
table = pd.DataFrame(rowList, columns=["학번","이름"])
table
# Out:
#     학번   이름
# 0  101  김효관
# 1  102  이순신
# 2  103  김어진

# %%
from bs4 import BeautifulSoup # 태그를 이쁘게 쓰게해준다
import requests # 웹페이지에 접속요청

# %%
url = "https://www.coupang.com/np/search?q=%EC%95%84%EB%A9%94%EB%A6%AC%EC%B9%B4%EB%85%B8&channel=recent"
headers = {'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10.14; rv:71.0) Gecko/20100101 Firefox/71.0'}
data=requests.get(url,headers=headers)
data.text
resp = requests.get(url)
resp.encoding = 'utf-8'

# %%
html = resp.text

htmlObj = BeautifulSoup(html, "html.parser")
htmlObj
# Out:
# <!DOCTYPE html>
#
# <html lang="ko-KR">
# <head>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="ko" http-equiv="content-language"/>
# <meta charset="utf-8"/>
# <link href="//img.navimro.com/img/ms3/icon/favicon.ico" rel="SHORTCUT ICON" type="image/ico"/>
# <title>그라인더 검색결과 - 나비엠알오</title>
# <meta content="그라인더,나비엠알오,NAVIMRO,기업전용,쇼핑몰,공구,사무용품,문구,안전용품,산업안전용품,절삭공구,측정공구,용접공구,연마공구,금형공구,포장용품,전동공구,기계배관,청소용품" name="keywords"/>
# <meta content="그라인더 등 기업에 필요한 모든 상품을 원스톱으로 구매. 150만가지 이상의 상품을 취급하는 No.1 기업 전용 쇼핑몰 나비엠알오(NAVIMRO)입니다." name="description"/>
# <link href="https://www.navimro.com/s/q-%EA%B7%B8%EB%9D%BC%EC%9D%B8%EB%8D%94/" rel="canonical"/>
# <link href="https://m.navimro.com/s/q-%EA%B7%B8%EB%9D%BC%EC%9D%B8%EB%8D%94/" rel="alternate"/>
# <meta content="width=device-width" name="viewport"/>
# <meta content="그라인더 검색결과 - 나비엠알오" property="og:title"/>
# <meta content="그라인더 등 기업에 필요한 모든 상품을 원스톱으로 구매. 150만가지 이상의 상품을 취급하는 No.1 기업 전용 쇼핑몰 나비엠알오(NAVIMRO)입니다." property="og:description"/>
# <meta content="//img.navimro.com/img/ms3/main/navimro.png" property="og:image"/>
# <meta content="https://www.navimro.com" property="og:url"/>
# <script>var time = 4000;</script>
# <!-- Page hiding snippet (recommended) -->
# <style>.async-hide { opacity: 0 !important} </style>
# <script>(function(a,s,y,n,c,h,i,d,e){s.className+=' '+y;h.start=1*new Date;
# h.end=i=function(){s.className=s.className.replace(RegExp(' ?'+y),'')};
# (a[n]=a[n]||[]).hide=h;setTimeout(function(){i();h.end=null},c);h.timeout=c;
# })(window,document.documentElement,'async-hide','dataLayer',time,{'GTM-W2ZK7HS':true});
# var webLoginFlag = false;
# </script>
# <script async="" src="https://www.googletagmanager.com/gtag/js?id=UA-39390363-1"></script>
# <script type="text/javascript">
#
#
# var getCookie = function(name) {
# 	var value = document.cookie.match('(^|;) ?' + name + '=([^;]*)(;|$)');
# 	return value? value[2] : null;
# };
#
# // 사용자 쿠키값 확인 Y/N
# var cookieMember = "N";
# if(getCookie('member') == "Y") {
# 	cookieMember = "Y";
# }
#
# //실제 운영에 검색엔진 버전 반영시에는 searchV 값 삽입
# var searchV="V2";
#
# var encCustomerCode = '';
#
# // 구매신청에 시간 셋팅
# var nTime = '2021-04-13 17:29:15';
#
# //마케팅팀 사용 변수
#
#
#
# 	var loginFlag = false;
# 	var userId = "";
# 	var customerCode = "";
# 	var userType = "";
# 	var joinUserType = "";
# 	var regDate = "";
# 	var orderCnt=0;
# 	var favPageType="";
# 	var emtest="";
# 	var oldRfm="";
# 	var rfm="";
# 	var grade="";
#
#
#
# 	<!-- Global site tag (gtag.js) - Google Analytics START -->
# 	window.dataLayer = window.dataLayer || [];
# 	function gtag(){dataLayer.push(arguments);}
# 	gtag('js', new Date());
# 	gtag('config', 'UA-39390363-1', {
# 		'optimize_id': 'GTM-W2ZK7HS',
# 		'user_id': customerCode,
# 		'custom_map': {'dimension2': 'uid', 'dimension8': 'member', 'dimension9': 'searchV', 'dimension10': 'user_id_new'}
# 	});
# 	gtag('config', 'AW-877288428');
# 	<!--// Global site tag (gtag.js) - Google Analytics END //-->
#
# 	<!-- Google Tag Manager START -->
# 	(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':new Date().getTime(),event:'gtm.js'});
# 	var f=d.getElementsByTagName(s)[0],j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;
# 	j.src='https://www.googletagmanager.com/gtm.js?id='+i+dl;
# 	f.parentNode.insertBefore(j,f);})(window,document,'script','dataLayer','GTM-MVJZ2VJ');
# 	<!--// Google Tag Manager END //-->
# </script>
# <span itemscope="" itemtype="http://schema.org/Organization">
# <link href="https://www.navimro.com" itemprop="url"/>
# <!-- <a itemprop="sameAs" href="https://goo.gl/JN2Kn3"></a> -->
# <a href="https://pf.kakao.com/_jALxiV" itemprop="sameAs"></a>
# <a href="https://blog.naver.com/navimro3" itemprop="sameAs"></a>
# <a href="https://www.facebook.com/788346461357094" itemprop="sameAs"></a>
# </span>
# <link href="/res/css/header.min.css?v=2021032512" rel="stylesheet" type="text/css">
# <link href="/res/css/footer.min.css?v=2021031612" rel="stylesheet" type="text/css"/>
# <link href="/res/css/ec_common.min.css?v=2021032512" rel="stylesheet" type="text/css"/>
# <link href="/res/css/ec_default.min.css?v=2021020212" rel="stylesheet" type="text/css"/>
# <link href="/res/lib/jquery-ui-1.12.1.min.css" rel="stylesheet" type="text/css"/>
# <!-- .js -->
# <script src="/res/lib/jquery-1.11.1.min.js"></script>
# <script src="/res/lib/js.cookie.min.js?v=2018021318"></script>
# <script src="/res/lib/jquery-cookie/jquery.cookie.min.js?v=2018021318"></script>
# <script src="/res/lib/jquery-ui-1.12.1.min.js"></script>
# <script src="/res/js/jquery.bxslider.min.js?v=2018021318"></script>
# <!--[if lt IE 9]><script src="//ie7-js.googlecode.com/svn/version/2.1(beta4)/IE9.js"></script><![endif]-->
# <!--[if (gte IE 6)&(lte IE 8)]>
# 	<script src="/res/js/selectivizr.min.js?v=2019022618"></script>
# <![endif]-->
# <script src="/res/js/jquery.actual.min.js?v=2018021318" type="text/javascript"></script>
# <script src="/res/js/placeholder.min.js?v=2019021912" type="text/javascript"></script>
# <script async="" src="/res/js/gnb.min.js?v=2020080612" type="text/javascript"></script>
# <script src="/res/js/common.min.js?v=2020092412" type="text/javascript"></script>
# <script async="" src="/res/js/header.min.js?v=2020092212" type="text/javascript"></script>
# <script async="" src="/res/js/login.min.js?v=2020092212" type="text/javascript"></script>
# <script type="text/javascript">
# //헤더상단 배너 close 쿠키, 빠른 실행을 위해 직접 삽입
# var cookieHeadBanner = "COOKIE_HEAD_BANNER";
# var browserBanner = "BROWSER_HEAD_BANNER";
#
# $(document).ready(function(){
# 	$(".bnr-comm-layer .close").click(function(){
# 		// 페이지 바뀌어도 배너 ON/OFF 유지되도록 쿠키 ON/OFF
# 		$.cookie(cookieHeadBanner , "OFF", { path:'/' });
# 	});
# 	//20200130 : lsy - win7 + ie9,10 팝업 대응
# 	$(".browser-layer .close").click(function(){
# 		// 페이지 바뀌어도 배너 ON/OFF 유지되도록 쿠키 ON/OFF
# 		if(false){
# 			$.cookie(browserBanner , "OFF", { expires: 30, path:'/' });
# 		}else{
# 			$.cookie(browserBanner , "OFF", { path:'/' });
# 		}
# 	});
# });
# </script>
# </link></head>
# <body>
# <!-- Google Tag Manager (noscript) -->
# <noscript>
# <iframe height="0" src="https://www.googletagmanager.com/ns.html?id=GTM-MVJZ2VJ" style="display: none; visibility: hidden" width="0"></iframe>
# </noscript>
# <!-- End Google Tag Manager (noscript) -->
# <link href="/res/css/header_autocomplete.min.css?v=2020080612" rel="stylesheet" type="text/css"/>
# <!-- header start -->
# <div id="header">
# <div>
# <style></style>
# </div>
# <div class="bnr-comm-layer clearFix"><a class="close"><img alt="배너닫기" src="/img/ms3/header/common-topBnr-close.png"/></a>
# <p class="inner">
# <a href="/register"><img alt="MRO 부문 1위" src="/img/ms3/banner/bnr-comm-first.gif"/></a>
# <a href="/register" onclick="gta_push('Registration Inflow','Header','Click top banner');"><img alt="신규가입 할인쿠폰 일만원 증정" src="/img/ms3/banner/bnr-comm-second.gif"/></a>
# <a href="/register"><img alt="5만원 이상 구매시 무료배송" src="/img/ms3/banner/bnr-comm-third.gif"/></a>
# </p></div>
# <!--[if IE 7]>
# 	<div class="browser-layer clearFix">
# 		<p class="inner">
# 			<img src="//img.navimro.com/img/ms3/banner/explorer_old.jpg" alt="익스플로러 구버전 안내" usemap="#Map" />
# 			<map name="Map" id="Map">
# 				<area shape="rect" coords="814,2,935,98" href="/help/explorer" target="_self">
# 				<area shape="rect" coords="945,2,1064,98" href="/help/chrome" target="_self">
# 			</map>
# 		</p>
# 	</div>
# 	<![endif]-->
# <!--[if IE 8]>
# 	<div class="browser-layer clearFix ">
# 		<p class="inner">
# 			<a class="close"><img src="//img.navimro.com/img/ms3/header/browser-topBnr-close.png" alt="안내닫기"></a>
# 			<img src="//img.navimro.com/img/ms3/banner/explorer_old.jpg" alt="익스플로러 구버전 안내" usemap="#Map" />
# 			<map name="Map" id="Map">
# 				<area shape="rect" coords="814,2,935,98" href="/help/explorer" target="_self">
# 				<area shape="rect" coords="945,2,1064,98" href="/help/chrome" target="_self">
# 			</map>
# 		</p>
# 	</div>
# 	<![endif]-->
# <!-- //20200130 : lsy - win7 + ie9,10 팝업 대응 (IE10에서 조건부 주석을 사용 못해서 팝업 소스 추가 - close버튼 쿠키 : 30일) -->
# <!-- 상단 공통 링크 start -->
# <div class="link-comm">
# <div class="inner">
# <p class="bookmark"><i class="icon icon-bookmark"></i><a href="javascript:addBookmark('//www.navimro.com', '[나비엠알오] 기업소모품 종합쇼핑몰')" onclick="gta_push_none('Add to Favorites site','Header','');">나비엠알오 즐겨찾기</a></p>
# <ul class="menu-member">
# <li class="first status-login"><div><a href="//www.navimro.com/login" onclick="gta_push('Login in Inflow','Header','Click Login in shortcut');">로그인</a></div></li>
# <li class="status-register"><a href="//www.navimro.com/register" onclick="gta_push('Registration Inflow','Header','Click registration shortcut');">회원가입</a></li>
# </ul>
# </div>
# </div>
# <!-- 상단 공통 링크 end -->
# <!-- 로고 및 검색 영역 start -->
# <div class="Wrap">
# <div class="Wrap-rap">
# <div class="inner" id="search-wrap">
# <!-- 마케팅 백오피스 팝업 영역 -->
# <div class="notice-popup-area">
# <div style="">
# <script>$(window).ready(function() {
#
# 			// width가 좁을 때 열기 버튼 노출
# 			$("#popup-float .btn-open").click(function() {
# 				$("#popup-float").toggleClass("sm-area-opend");
# 				$("#popup-float .btn-open").toggleClass("btn-open-closed");
# 				$("#popup-float .btn-open").toggleClass("btn-open-opend");
# 			});
# 			$("#popup-float .btn-open-closed").click(function() {
# 				gta_push_none('promotion pop','click tap-open');
# 			});
#
# 			// 접속하자마자 Big 배너 띄우기
# 			var showJoin = function() {
# 				$("#popup-float .big-area__bn.join").stop().animate({width: ["420px", "swing"], opacity: ["show", "swing"]}, 450)
#                 .animate({width: ["400px", "swing"]}, 200);
#                 setCookie("noMore","today",1);
# 				gta_push_none('promotion pop','show big popup');
# 			};
# 			if( (getCookie("noMore") != "today")&&(loginFlag == false)&&(getCookie("member") != "Y") ) {
# 				setTimeout(showJoin, 2000);
# 				clearTimeout(showJoin);
# 			};
#
# 			// 조건에 따라 sm 띄우기
# 			if( (loginFlag == false)&&(getCookie("member") != "Y") ) {
# 				$("#popup-float .sm-area__bn.join").show();
# 			};
#
# 			// Big 배너 닫기
# 			$("#popup-float .big-area__bn .close-pop").click(function() {
# 				$("#popup-float .big-area__bn").hide();
# 				setCookie("noMore","today",1);
# 				gta_push_none('promotion pop','click close bn_big');
# 			});
#
# 			// 마우스 오버 시 sm에 border처리
# 			$("#popup-float .sm-area__bn.join").hover(function() {
# 				$("#popup-float .sm-area .sm-area__bn.join > a > .bn__hover").show();
# 			}, function() {
# 				$("#popup-float .sm-area .sm-area__bn.join > a > .bn__hover").hide();
# 			});
#
#
#             // 마우스 오버 시 Big 배너 띄우기
#             $(document).on("mouseenter", "#popup-float .sm-area__bn.join", function(){
#                 var showJoinBig = function() {
#                     $("#popup-float .big-area__bn").css("width","400px");
#                     $("#popup-float .big-area__bn.print").hide();
#                     $("#popup-float .big-area__bn.join").show();
#                     gta_push_none('promotion pop','mouseover bn_sm','registration');
#                 };
#                 timer = setTimeout(showJoinBig, 300);
#             }).on("mouseleave", "#popup-float .sm-area__bn.join", function(){
#                 clearTimeout(timer);
#             });
#
#             // Big배너 클릭시 setCookie noMore
#             $(".big-area__bn > a").click(function() {
#                setCookie("noMore","today",1);
#             });
#
# 		});</script>
# <style>/* @media screen and (max-width: 1470px) {
# 			#popup-float {
# 				left: -1000px;
# 			}
# 			#popup-float.sm-area-opend {
# 				left: 1278px;
# 			}
# 			#popup-float .sm-area {
# 				border: 1px solid #989ba2;
# 				background: #fff;
# 				padding: 5px 10px 10px 10px;
# 				border-bottom-right-radius: 10px;
# 				vertical-align: bottom;
# 			}
# 			#popup-float .btn-open {
# 				display: inline-block !important;
# 				cursor: pointer;
# 				width: 60px;
# 				height: 88px;
# 				margin-top: -6px;
# 			}
# 			#popup-float .btn-open.btn-open-closed {
# 				background: url(/img/ms3/banner/pop-float/tab-open.png) no-repeat;
# 			}
# 			#popup-float .btn-open.btn-open-opend {
# 				left: 111px !important;
# 				margin-left: -2px;
# 				background: url(/img/ms3/banner/pop-float/tab-close.png) no-repeat;
# 				z-index: 9999;
# 			}
# 		}
# 		#popup-float {
# 			position: fixed;
# 			bottom: 65px;
# 			margin-left: -1280px;
# 			font-size: 0;
# 		}
# 		#popup-float .sm-area, #popup-float .big-area, #popup-float .sm-area-wrap {
# 			display: inline-block;
# 		}
# 		#popup-float .sm-area-wrap {
# 			vertical-align: top;
# 		}
# 		#popup-float .sm-area .sm-area__bn {
# 			margin-top: 5px;
# 			position: relative;
# 		}
# 		#popup-float .sm-area .sm-area__bn > a > .bn__hover {
# 			display: none;
# 			border: 3px solid #ff7200;
# 			width: 90px;
# 			height: 100px;
# 			border-radius: 10px;
# 			position: absolute;
# 			top: 0;
# 			box-sizing: border-box;
# 		}
# 		#popup-float .big-area {
# 			margin-left: 10px;
# 			vertical-align: bottom;
# 			box-shadow: rgba(50, 53, 60, 0.3) 0px 2px 6px 1px;
#     		border-radius: 20px;
# 		}
# 		#popup-float .big-area__bn {
# 			position: relative;
# 			display: none;
#             width: 0;
# 		}
# 		#popup-float .btn-open {
# 			display: none;
# 			position: fixed;
# 			left: 0;
# 			vertical-align: top;
# 		}
# 		#popup-float .big-area__bn .close-pop {
# 			position: absolute;
# 			top: 10px;
# 			right: 10px;
# 			cursor: pointer;
# 			width: 30px !important;
# 			height: 30px;
# 		} */
#
#
# @media screen and (max-width: 1470px) {
# 	#popup-float {
# 		left: -1000px;
# 		margin-left: -1280px !important;
# 	}
# 	#popup-float.sm-area-opend {
# 		left: 1278px;
# 	}
# 	#popup-float .sm-area {
# 		border: 1px solid #989ba2;
# 		background: #fff;
# 		padding: 5px 10px 10px 10px;
# 		border-bottom-right-radius: 10px;
# 		vertical-align: bottom;
# 	}
# 	#popup-float .btn-open {
# 		display: inline-block !important;
# 		cursor: pointer;
# 		width: 60px;
# 		height: 88px;
# 		margin-top: -6px;
# 	}
# 	#popup-float .btn-open.btn-open-closed {
# 		background: url(/img/ms3/banner/pop-float/tab-open.png) no-repeat;
# 	}
# 	#popup-float .btn-open.btn-open-opend {
# 		left: 111px !important;
# 		margin-left: -2px;
# 		background: url(/img/ms3/banner/pop-float/tab-close.png) no-repeat;
# 		z-index: 9999;
# 	}
# }
# #popup-float {
# 	position: fixed;
# 	bottom: 65px;
# 	margin-left: -100px;
# 	font-size: 0;
# }
# #popup-float .sm-area, #popup-float .big-area, #popup-float .sm-area-wrap {
# 	display: inline-block;
# }
# #popup-float .sm-area-wrap {
# 	vertical-align: top;
# }
# #popup-float .sm-area .sm-area__bn {
# 	margin-top: 5px;
# 	position: relative;
# }
# #popup-float .sm-area .sm-area__bn > a > .bn__hover {
# 	display: none;
# 	border: 3px solid #ff7200;
# 	width: 90px;
# 	height: 100px;
# 	border-radius: 10px;
# 	position: absolute;
# 	top: 0;
# 	box-sizing: border-box;
# }
# #popup-float .big-area {
# 	margin-left: 10px;
# 	vertical-align: bottom;
# 	box-shadow: rgba(50, 53, 60, 0.3) 0px 2px 6px 1px;
# 	border-radius: 20px;
# }
# #popup-float .big-area__bn {
# 	position: relative;
# 	display: none;
# 	width: 0;
# }
# #popup-float .btn-open {
# 	display: none;
# 	position: fixed;
# 	left: 0;
# 	vertical-align: top;
# }
# #popup-float .big-area__bn .close-pop {
# 	position: absolute;
# 	top: 10px;
# 	right: 10px;
# 	cursor: pointer;
# 	width: 30px !important;
# 	height: 30px;
# }</style>
# <div id="popup-float">
# <div class="sm-area">
# <div class="sm-area-wrap">
# <div class="sm-area__bn sm-area__bn1">
# <a href="https://www.navimro.com/plan/detail?planId=343" onclick="gta_push('promotion pop','click bn_sm','PB신규상품');">
# <img alt="PB신규상품" src="/img/ms3/banner/floating-210330.jpg" style="width: 90px; padding: 0 0 5px;"/>
# </a>
# </div>
# <div class="sm-area__bn sm-area__bn2">
# <a href="https://www.navimro.com/plan/detail?planId=339" onclick="gta_push('promotion pop','click bn_sm','봄/여름 근무복');">
# <img alt="봄여름 근무복" src="/img/ms3/banner/uniform-floating.jpg" style="width: 90px; padding: 0 0 5px;"/>
# </a>
# </div>
# <!-- 회원가입 -->
# <div class="sm-area__bn join" style="display:none;">
# <a href="/register/" onclick="gta_push('promotion pop','click bn_sm','registration');">
# <img src="/img/ms3/banner/pop-float/bn_registration_small.png"/>
# <div class="bn__hover"></div>
# </a>
# </div>
# </div>
# <div class="btn-open btn-open-closed"></div>
# </div>
# <div class="big-area">
# <!-- 회원가입 -->
# <div class="big-area__bn join">
# <img alt="닫기" class="close-pop" src="/img/ms3/header/common-topBnr-close.png"/>
# <a href="/register/" onclick="gta_push('promotion pop','click bn_big','registration');"><img src="/img/ms3/banner/pop-float/bn_registration_big.png"/></a>
# </div>
# </div>
# </div>
# <script>
# $(window).ready(function() {
#
# 			// width가 좁을 때 열기 버튼 노출
# 			$("#popup-float .btn-open").click(function() {
# 				$("#popup-float").toggleClass("sm-area-opend");
# 				$("#popup-float .btn-open").toggleClass("btn-open-closed");
# 				$("#popup-float .btn-open").toggleClass("btn-open-opend");
# 			});
# 			$("#popup-float .btn-open-closed").click(function() {
# 				gta_push_none('promotion pop','click tap-open');
# 			});
#
# 			// 접속하자마자 Big 배너 띄우기
# 			var showJoin = function() {
# 				$("#popup-float .big-area__bn.join").stop().animate({width: ["420px", "swing"], opacity: ["show", "swing"]}, 450)
#                 .animate({width: ["400px", "swing"]}, 200);
#                 setCookie("noMore","today",1);
# 				gta_push_none('promotion pop','show big popup');
# 			};
# 			if( (getCookie("noMore") != "today")&&(loginFlag == false)&&(getCookie("member") != "Y") ) {
# 				setTimeout(showJoin, 2000);
# 				clearTimeout(showJoin);
# 			};
#
# 			// 조건에 따라 sm 띄우기
# 			if( (loginFlag == false)&&(getCookie("member") != "Y") ) {
# 				$("#popup-float .sm-area__bn.join").show();
# 			};
#
# 			// Big 배너 닫기
# 			$("#popup-float .big-area__bn .close-pop").click(function() {
# 				$("#popup-float .big-area__bn").hide();
# 				setCookie("noMore","today",1);
# 				gta_push_none('promotion pop','click close bn_big');
# 			});
#
# 			// 마우스 오버 시 sm에 border처리
# 			$("#popup-float .sm-area__bn.join").hover(function() {
# 				$("#popup-float .sm-area .sm-area__bn.join > a > .bn__hover").show();
# 			}, function() {
# 				$("#popup-float .sm-area .sm-area__bn.join > a > .bn__hover").hide();
# 			});
#
#
#             // 마우스 오버 시 Big 배너 띄우기
#             $(document).on("mouseenter", "#popup-float .sm-area__bn.join", function(){
#                 var showJoinBig = function() {
#                     $("#popup-float .big-area__bn").css("width","400px");
#                     $("#popup-float .big-area__bn.print").hide();
#                     $("#popup-float .big-area__bn.join").show();
#                     gta_push_none('promotion pop','mouseover bn_sm','registration');
#                 };
#                 timer = setTimeout(showJoinBig, 300);
#             }).on("mouseleave", "#popup-float .sm-area__bn.join", function(){
#                 clearTimeout(timer);
#             });
#
#             // Big배너 클릭시 setCookie noMore
#             $(".big-area__bn > a").click(function() {
#                setCookie("noMore","today",1);
#             });
#
# 		});
# </script>
# <style>
# /* @media screen and (max-width: 1470px) {
# 			#popup-float {
# 				left: -1000px;
# 			}
# 			#popup-float.sm-area-opend {
# 				left: 1278px;
# 			}
# 			#popup-float .sm-area {
# 				border: 1px solid #989ba2;
# 				background: #fff;
# 				padding: 5px 10px 10px 10px;
# 				border-bottom-right-radius: 10px;
# 				vertical-align: bottom;
# 			}
# 			#popup-float .btn-open {
# 				display: inline-block !important;
# 				cursor: pointer;
# 				width: 60px;
# 				height: 88px;
# 				margin-top: -6px;
# 			}
# 			#popup-float .btn-open.btn-open-closed {
# 				background: url(/img/ms3/banner/pop-float/tab-open.png) no-repeat;
# 			}
# 			#popup-float .btn-open.btn-open-opend {
# 				left: 111px !important;
# 				margin-left: -2px;
# 				background: url(/img/ms3/banner/pop-float/tab-close.png) no-repeat;
# 				z-index: 9999;
# 			}
# 		}
# 		#popup-float {
# 			position: fixed;
# 			bottom: 65px;
# 			margin-left: -1280px;
# 			font-size: 0;
# 		}
# 		#popup-float .sm-area, #popup-float .big-area, #popup-float .sm-area-wrap {
# 			display: inline-block;
# 		}
# 		#popup-float .sm-area-wrap {
# 			vertical-align: top;
# 		}
# 		#popup-float .sm-area .sm-area__bn {
# 			margin-top: 5px;
# 			position: relative;
# 		}
# 		#popup-float .sm-area .sm-area__bn > a > .bn__hover {
# 			display: none;
# 			border: 3px solid #ff7200;
# 			width: 90px;
# 			height: 100px;
# 			border-radius: 10px;
# 			position: absolute;
# 			top: 0;
# 			box-sizing: border-box;
# 		}
# 		#popup-float .big-area {
# 			margin-left: 10px;
# 			vertical-align: bottom;
# 			box-shadow: rgba(50, 53, 60, 0.3) 0px 2px 6px 1px;
#     		border-radius: 20px;
# 		}
# 		#popup-float .big-area__bn {
# 			position: relative;
# 			display: none;
#             width: 0;
# 		}
# 		#popup-float .btn-open {
# 			display: none;
# 			position: fixed;
# 			left: 0;
# 			vertical-align: top;
# 		}
# 		#popup-float .big-area__bn .close-pop {
# 			position: absolute;
# 			top: 10px;
# 			right: 10px;
# 			cursor: pointer;
# 			width: 30px !important;
# 			height: 30px;
# 		} */
#
#
# @media screen and (max-width: 1470px) {
# 	#popup-float {
# 		left: -1000px;
# 		margin-left: -1280px !important;
# 	}
# 	#popup-float.sm-area-opend {
# 		left: 1278px;
# 	}
# 	#popup-float .sm-area {
# 		border: 1px solid #989ba2;
# 		background: #fff;
# 		padding: 5px 10px 10px 10px;
# 		border-bottom-right-radius: 10px;
# 		vertical-align: bottom;
# 	}
# 	#popup-float .btn-open {
# 		display: inline-block !important;
# 		cursor: pointer;
# 		width: 60px;
# 		height: 88px;
# 		margin-top: -6px;
# 	}
# 	#popup-float .btn-open.btn-open-closed {
# 		background: url(/img/ms3/banner/pop-float/tab-open.png) no-repeat;
# 	}
# 	#popup-float .btn-open.btn-open-opend {
# 		left: 111px !important;
# 		margin-left: -2px;
# 		background: url(/img/ms3/banner/pop-float/tab-close.png) no-repeat;
# 		z-index: 9999;
# 	}
# }
# #popup-float {
# 	position: fixed;
# 	bottom: 65px;
# 	margin-left: -100px;
# 	font-size: 0;
# }
# #popup-float .sm-area, #popup-float .big-area, #popup-float .sm-area-wrap {
# 	display: inline-block;
# }
# #popup-float .sm-area-wrap {
# 	vertical-align: top;
# }
# #popup-float .sm-area .sm-area__bn {
# 	margin-top: 5px;
# 	position: relative;
# }
# #popup-float .sm-area .sm-area__bn > a > .bn__hover {
# 	display: none;
# 	border: 3px solid #ff7200;
# 	width: 90px;
# 	height: 100px;
# 	border-radius: 10px;
# 	position: absolute;
# 	top: 0;
# 	box-sizing: border-box;
# }
# #popup-float .big-area {
# 	margin-left: 10px;
# 	vertical-align: bottom;
# 	box-shadow: rgba(50, 53, 60, 0.3) 0px 2px 6px 1px;
# 	border-radius: 20px;
# }
# #popup-float .big-area__bn {
# 	position: relative;
# 	display: none;
# 	width: 0;
# }
# #popup-float .btn-open {
# 	display: none;
# 	position: fixed;
# 	left: 0;
# 	vertical-align: top;
# }
# #popup-float .big-area__bn .close-pop {
# 	position: absolute;
# 	top: 10px;
# 	right: 10px;
# 	cursor: pointer;
# 	width: 30px !important;
# 	height: 30px;
# }
# </style>
# </div>
# </div>
# <div class="fl">
# <a href="//www.navimro.com"><img alt="NAVIMRO" src="//img.navimro.com/img/ms3/header/logo.jpg"/></a>
# </div>
# <!--    서치박스	-->
# <div class="search-comm2">
# <form method="get">
# <input autocomplete="off" class="lr ui-autocomplete-input sh-search" id="suggest_search" maxlength="24" placeholder="가격은 내리고 품질은 올리고! 나비엠알오 브랜드 상품" type="text" value="그라인더"/>
# <input alt="검색" class="fr" onclick="return keywordSearch();" src="//img.navimro.com/img/ms3/header/search_icon-new.png" type="image">
# <input id="q" name="q" type="hidden" value=""/>
# <input id="disp" name="disp" type="hidden" value="0"/>
# <input name="keyword" type="hidden" value=""/>
# <div class="x-img">
# <a><img alt="삭제" src="//img.navimro.com/img/ms3/buttons/btn-input-value-x.gif"/></a>
# </div>
# </input></form>
# <!-- 최근검색 시작 -->
# <div class="Search-list-box dp-none">
# <div class="inner-box" id="search-body">
# <div class="tab clearFix">
# <a class="first active" onclick="latelySearch_list(1, 'tab-area', this); onGetKeywordLatest();">최근 검색어</a>
# <a onclick="popupLoginReload();">즐겨찾기 검색어</a>
# </div>
# <div class="tab-area" id="latelySearch-list1">
# <p class="clearFix mt20 ml20 dp-none" id="my-keyword1-none">
# 									최근 검색어가 없습니다.
# 								</p>
# <ul class="list">
# <li class="clearFix dp-none">
# <p class="wish none mu-pointer"></p>
# <p class="keyword"></p>
# <!-- <p class="date del" onclick="onRemoveKeywordLatest(this);"></p> -->
# </li>
# </ul>
# <p class="all-clear mu-pointer" onclick="onRemoveKeywordLatestAll();">기록전체 삭제</p>
# </div>
# <div class="tab-area" id="latelySearch-list2" style="display:none;">
# <p class="clearFix mt20 ml20 dp-none ln20" id="my-keyword-none">
# 									즐겨찾는 검색어가 없습니다.
# 									<br/>최근 검색어에서 ☆를 선택하여 자주 검색하는 키워드를
# 									<br/>즐겨찾기 검색어로 저장해보세요.
# 								</p>
# <ul class="list">
# <li class="clearFix dp-none">
# <p class="wish mu-pointer" onclick="onRemoveKeywordFavorit(this, 'tab2');"></p>
# <p class="keyword"></p>
# <!-- <p class="date del" onclick="onRemoveKeywordFavorit(this, 'tab2');"></p> -->
# </li>
# </ul>
# <p class="all-clear" onclick="onRemoveKeywordFavoritAll();"><a>즐겨찾기 전체 삭제</a></p>
# </div>
# </div>
# </div>
# <!-- 최근검색 끝 -->
# </div>
# <!--    고객님의 등급		-->
# <!--    아이콘메뉴	-->
# <div class="etc-menu">
# <ul>
# <li>
# <a class="cart" href="//www.navimro.com/cart" onclick="gta_push('Go to Cart','Header','');" target="_self">
# <i id="cart-count"></i>
# </a>
# </li>
# <li class="login">
# <a href="//www.navimro.com/login"></a>
# <div class="drop-down my-sp" style="display: none;">
# <ul>
# <li><a href="//www.navimro.com/userInfo/userInfo" onclick="gta_push('Header','click drop','my page');" target="_self">마이페이지</a></li>
# <li><a href="//www.navimro.com/mypage/orderHistory" onclick="gta_push('Header','click drop','order history');" target="_self">주문/배송조회</a></li>
# <li><a href="//www.navimro.com/mypage/frequentlyItem" onclick="gta_push('Header','click drop','frequently');">자주 구매한 상품</a></li>
# <li><a href="//www.navimro.com/wish/wishList" onclick="gta_push('Header','click drop','wish list');" target="_self">찜한 상품</a></li>
# </ul>
# </div>
# </li>
# <li>
# <a href="javascript:addBookmark('//www.navimro.com', '[나비엠알오] 기업소모품 종합쇼핑몰')" onclick="gta_push_none('Header','click icon','favorite');" target="_self"></a>
# </li>
# <li class="help-center">
# <a href="//www.navimro.com/help" onclick="gta_push_none('Header','click icon','cs');" target="_self"></a>
# <div class="drop-down help" style="display: none;">
# <ul>
# <li><a href="//www.navimro.com/faq" onclick="gta_push_none('Header','click drop','faq');" target="_self">고객센터</a></li>
# <li><a href="//www.navimro.com/pages/help/refund" onclick="gta_push_none('Header','click drop','refund');" target="_self">교환/환불안내</a></li>
a><ul class="dp3"></ul></li>
# <li class="li-dp2"><a href="/s/c-20018" id="20018">표면처리제</a><ul class="dp3"></ul></li>
# <li class="li-dp2"><a href="/s/c-20019" id="20019">산업용 윤활유</a><ul class="dp3"></ul></li>
# </ul>
# <div class="recommend">
# <div class="ca-reco">
# <p class="category__recommend-title">추천상품</p>
# <div class="ca-reco-product">
# <a href="/g/183341"><img alt="윤활 방청제 (N-360)" src="//img.navimro.com/img/pi/thum/K06689036.jpg"/><p class="info">윤활 방청제 (N-360)</p><p class="name">나비엠알오</p><p class="price">1690</p></a>
# </div>
# <div class="ca-reco-product">
# <a href="/g/310960"><img alt="다목적용 순간 접착제 (NV-020)" src="//img.navimro.com/img/pi/thum/K15357998.jpg"/><p class="info">다목적용 순간 접착제 (NV-020)</p><p class="name">나비엠알오</p><p class="price">1290</p></a>
# </div>
# <div class="ca-reco-product">
# <a href="/g/259053"><img alt="뿌리는 구리스" src="//img.navimro.com/img/pi/thum/K11288792.jpg"/><p class="info">뿌리는 구리스</p><p class="name">나비엠알오</p><p class="price">2490</p></a>
# </div>
# <div class="ca-reco-product">
# <a href="/g/259054"><img alt="서스 코팅제 (L-316)" src="//img.navimro.com/img/pi/thum/K11288827.jpg"/><p class="info">서스 코팅제 (L-316)</p><p class="name">나비엠알오</p><p class="price">4190</p></a>
# </div>
# <div class="ca-reco-product">
# <a href="/g/211582"><img alt="핫멜트 접착제 (핫멜트 봉)" src="//img.navimro.com/img/pi/thum/K07973113.jpg"/><p class="info">핫멜트 접착제 (핫멜트 봉)</p><p class="name">나비엠알오</p><p class="price">3990</p></a>
# </div>
# <div class="ca-reco-product">
# <a href="/g/60214"><img alt="스프레이 접착제 (그래픽 아트 77)" src="//img.navimro.com/img/pi/thum/K01288951.jpg"/><p class="info">스프레이 접착제 (그래픽 아트 77)</p><p class="name">3M</p><p class="price">8690</p></a>
# </div>
# </div>
# </div>
# ...
# <div class="item__icon">
# </div>
# <p class="item__price">
# <strong class="fl">34,990</strong>
# <span>원</span>
# </p>
# </div>
# </li>
# </ul>
# </div>
# </div>
# <!--// GRID 상품표시영역 종료 //-->
# <!-- FOOTER 페이징 START-->
# <div class="paging">
# <div class="clearFix">
# <!-- 처음, 이전 블럭이동 -->
# <a class="icon icon-page-prev2" href="/s/q-%EA%B7%B8%EB%9D%BC%EC%9D%B8%EB%8D%94/page-1/?sort=score&amp;disp=0&amp;hits=90" title="처음"></a>
# <a class="icon icon-page-prev1" href="/s/q-%EA%B7%B8%EB%9D%BC%EC%9D%B8%EB%8D%94/page-1/?sort=score&amp;disp=0&amp;hits=90" title="이전"></a>
# <!-- 하나의 블럭에서 반복문 수행 시작페이지부터 끝페이지까지 -->
# <a class="active" href="#" onclick="return false">1</a>
# <a class="number" href="/s/q-%EA%B7%B8%EB%9D%BC%EC%9D%B8%EB%8D%94/page-2/?sort=score&amp;disp=0&amp;hits=90">2</a>
# <a class="number" href="/s/q-%EA%B7%B8%EB%9D%BC%EC%9D%B8%EB%8D%94/page-3/?sort=score&amp;disp=0&amp;hits=90">3</a>
# <a class="number" href="/s/q-%EA%B7%B8%EB%9D%BC%EC%9D%B8%EB%8D%94/page-4/?sort=score&amp;disp=0&amp;hits=90">4</a>
# <a class="number" href="/s/q-%EA%B7%B8%EB%9D%BC%EC%9D%B8%EB%8D%94/page-5/?sort=score&amp;disp=0&amp;hits=90">5</a>
# <a class="number" href="/s/q-%EA%B7%B8%EB%9D%BC%EC%9D%B8%EB%8D%94/page-6/?sort=score&amp;disp=0&amp;hits=90">6</a>
# <a class="number" href="/s/q-%EA%B7%B8%EB%9D%BC%EC%9D%B8%EB%8D%94/page-7/?sort=score&amp;disp=0&amp;hits=90">7</a>
# <a class="number" href="/s/q-%EA%B7%B8%EB%9D%BC%EC%9D%B8%EB%8D%94/page-8/?sort=score&amp;disp=0&amp;hits=90">8</a>
# <a class="number" href="/s/q-%EA%B7%B8%EB%9D%BC%EC%9D%B8%EB%8D%94/page-9/?sort=score&amp;disp=0&amp;hits=90">9</a>
# <a class="number" href="/s/q-%EA%B7%B8%EB%9D%BC%EC%9D%B8%EB%8D%94/page-10/?sort=score&amp;disp=0&amp;hits=90">10</a>
# <!-- 끝, 다음 블럭이동 -->
# <a class="icon icon-page-next1" href="/s/q-%EA%B7%B8%EB%9D%BC%EC%9D%B8%EB%8D%94/page-11/?sort=score&amp;disp=0&amp;hits=90" title="다음"></a>
# <a class="icon icon-page-next2" href="/s/q-%EA%B7%B8%EB%9D%BC%EC%9D%B8%EB%8D%94/page-24/?sort=score&amp;disp=0&amp;hits=90" title="끝"></a>
# </div>
# </div>
# <!-- FOOTER 페이징 종료 //-->
# </div>
# <!-- 상품 컨텐츠 영역 종료 //-->
# </div>
# <!-- 메인 컨텐츠 영역 종료 //-->
# </div>
# <!-- sub-container 종료 //-->
# </div>
# <!-- container 종료 //-->
# <input id="addCart-event" type="hidden"/>
# <script type="text/javascript">
# 	//sub Banner 노출
# 	if(cookieMember == 'N') {
# 		$('#subBannerN').removeClass('dp-none');
# 		$('#subBannerY').addClass('dp-none');
# 	}else if(cookieMember == 'Y') {
# 		$('#subBannerY').removeClass('dp-none');
# 		$('#subBannerN').addClass('dp-none');
# 	}
# </script>
# <!-- FOOTER -->
# <div class="mb60" id="footer">
# <div class="bnr-footer-exchange text-center">
# <a href="//www.navimro.com/pages/help/refund"><img alt="" src="//img.navimro.com/img/ms3/footer/bnr-footer-exchange2.jpg"/></a>
# </div>
# <div class="link-footer-menu">
# <ul class="inner">
# <!-- <li><a href="#.">인기검색어 추천상품</a></li> -->
# <li><a href="//www.navimro.com/pages/biz/company02">회사소개</a></li>
# <li><a href="/pages/sub/per_info">개인정보처리방침</a></li>
# <li><a href="/pages/sub/terms">이용약관</a></li>
# <li><a href="//www.navimro.com/pages/biz/company10">공급사 제휴문의</a></li>
# <li><a href="//www.navimro.com/pages/help/guide">이용가이드</a></li>
# <li><a href="//www.navimro.com/quickorder">빠른주문</a></li>
# <li><a href="//www.navimro.com/pages/help/payment">결제안내</a></li>
# <li><a href="//www.navimro.com/k/map">검색 네비게이션</a></li>
# <!-- <li class="last"><a href="/res/download/TeamViewerQS_ko-idc7zrz2jd.exe">원격지원 </a></li> -->
# </ul>
# </div>
# <!-- 풋터 수정화면 이미지 수정작업 필요 -->
# <div class="footer-info-new inner">
# <div class="logo">
# <img alt="나비엠알오" src="//img.navimro.com/img/ms3/footer/footer-logo.png"/>
# </div>
# <div class="copyright">
# <p>
# <span class="fw-bold fc-black">(주)나비엠알오</span><br/>
# 				대표이사 : 김형근   서울시 금천구 디지털로 130 남성프라자 308, 309호
# 			</p>
# <p>
# <span>사업자등록번호 : 119-86-66372</span><a class="doc01" href="javascript:window.open('//www.navimro.com/res/download/navimro.jpg', 'navimro', 'width=600px, height=853px; scrollbars=yes').focus();"><img alt="" class="" src="//img.navimro.com/img/ms3/footer/navimro_licensee.gif"/></a>
# </p>
# <p>
# <span>통신판매업신고번호 : 금천구 제 0203호</span><a class="doc02" href="javascript:window.open('http://www.ftc.go.kr/info/bizinfo/communicationViewPopup.jsp?wrkr_no=1198666372', 'communicationViewPopup', 'width=750, height=700;').focus();"><img alt="" class="" src="//img.navimro.com/img/ms3/footer/footer_no.gif"/></a>
# </p>
# <p>
# <span>개인정보보호책임자 : 옥태석 <a href="mailto:help@navimro.com">help@navimro.com</a></span>
# </p>
# <p>
# <br/>
#
# 				착불시 반품주소 : 경기도 용인시 기흥구 동백죽전대로 201-9 용인동백물류센터<br/> (주)나비엠알오<br/>
# </p>
# </div>
# <div class="customer">
# <p>
# 				고객만족센터 : <span class="fs21 ls0 fw-bold fc-black">1899-0947</span><br/>
# 				운영시간 : 월요일~금요일 09:00~18:00 / 점심시간 12:00~13:00<br/>
# 				FAX : 02-6499-0947<br/>
# </p>
# <a class="remote-btn" href="//www.navimro.com/res/download/TeamViewerQS_ko-idc7zrz2jd.exe" style="left: 25%;">원격지원 서비스 다운로드</a>
# <a class="company-btn" href="//www.navimro.com/pages/biz/company02" target="_self">회사소개 바로가기</a>
# </div>
# </div>
# <div class="bnr-footer-logo inner">
# <img alt="클릭하시면 KCP 결제시스템의 유효성을 확인하실 수 있습니다." class="fl pointer" onclick="javascript:window.open('http://admin.kcp.co.kr/Modules/escrow/kcp_pop.jsp?site_cd=G0250','mark','scrollbars=no,resizable=no,width=505,height=455');" src="//img.navimro.com/img/ms3/footer/bnr-footer-logo1.jpg" title="클릭하시면 KCP 결제시스템의 유효성을 확인하실 수 있습니다.">
# <img alt="정보보호관리체계인증" class="fl pointer" onclick="window.open('//img.navimro.com/img/ms3/footer/isms_navimro.html', 'CLIENT_WINDOW', 'resizable=no scrollbars=no width=500 height=700 left=' + (screen.availWidth-500)/2 + ' top=' + (screen.availHeight-700)/2)" src="//img.navimro.com/img/ms3/footer/bnr-footer-logo2.jpg" title="정보보호관리체계인증">
# <img alt="Comodo PositiveSSL Wildcard" class="fl" src="//img.navimro.com/img/ms3/footer/bnr-footer-logo3.jpg" title="Comodo PositiveSSL Wildcard">
# <a class="fl" href="javascript:window.open('http://www.ftc.go.kr/info/bizinfo/communicationViewPopup.jsp?wrkr_no=1198666372', 'communicationViewPopup', 'width=750, height=700;').focus();"><img alt="이미지를 클릭하시면 공정거래위원회에 등록된 나비엠알오의 사업자 등록번호를 확인하실 수 있습니다." src="//img.navimro.com/img/ms3/footer/bnr-footer-logo4.jpg" title="이미지를 클릭하시면 공정거래위원회에 등록된 나비엠알오의 사업자 등록번호를 확인하실 수 있습니다."/></a>
# </img></img></img></div>
# <div class="dp-none" id="social">
# <a class="facebook" href="https://www.facebook.com/788346461357094" target="_blank">facebook</a>
# <a class="kakao" href="http://pf.kakao.com/_jALxiV" target="_blank">kakao</a>
# <a class="blog" href="https://blog.naver.com/navimro3" target="_blank">naver blog</a>
# <a class="utube" href="https://goo.gl/JN2Kn3" target="_blank">utube</a>
# </div>
# </div>
# <!--// FOOTER //-->
# <!-- frb.jsp (footer remote bar) -->
# <link href="/res/css/fnb.min.css?v=2021020212" rel="stylesheet" type="text/css"/>
# <script src="/res/js/fnb.min.js?v=2020071412"></script>
# <style>
# .view-pro-close {
# 	background: url('//img.navimro.com/img/ms3/footer/remote-close-s.png') no-repeat;
# 	width:15px;
# 	height:15px;
# }
# </style>
# <a class="on" id="remoteBtn">ON</a>
# <div class="dp-none" id="remoteArea">
# <div class="inner">
# <div class="remote-bnr dp-none">
# <a class="bnr-close" href="javascript:void(0)"><img alt="닫기" src="//img.navimro.com/img/ms3/footer/remote-bnr-close.png"/></a>
# <!--<a href="//www.navimro.com/register" onClick="gta_push('Registration Inflow','Remote Bar','Click keyword banner');"></a>-->
# <img alt="할인쿠폰" src="//img.navimro.com/img/ms3/footer/floatBar/bn-floatBar-keyword.png" usemap="#Map"/>
# <map id="Map" name="Map">
# <area alt="할인쿠폰" coords="1,2,381,290" href="//www.navimro.com/register" onclick="gta_push('Registration Inflow','Remote Bar','Click keyword banner');" shape="rect" target="_self"/>
# </map>
# </div>
# <div class="quick-btn">
# <div class="remote-search fl">
# <input class="pl10 w150" id="frbSearch" type="text"/>
# <img alt="검색" class="mu-pointer" onclick="gta_push('Search','Remote Bar',''); searchByFooter();" src="//img.navimro.com/img/ms3/footer/floatBar/fnb-search-icon.gif"/>
# </div>
# <a class="btn" href="//www.navimro.com"><img alt="홈으로" src="//img.navimro.com/img/ms3/footer/floatBar/quick-home.png"/></a>
# <a class="btn" href="//www.navimro.com/cart"><img alt="장바구니" src="//img.navimro.com/img/ms3/footer/floatBar/quick-cart.png"/></a>
# <a class="btn fnb-search search-off"><img alt="검색" src="//img.navimro.com/img/ms3/footer/floatBar/quick-search.png"/></a>
# <a class="btn" href="//www.navimro.com/quickorder"><img alt="빠른주문" src="//img.navimro.com/img/ms3/footer/floatBar/quick-fastOrder.png"/></a>
# <a class="btn" href="//www.navimro.com/mypage/orderHistory"><img alt="마이쇼핑" src="//img.navimro.com/img/ms3/footer/floatBar/quick-myshop.png"/></a>
# <a class="btn" href="//www.navimro.com/help" onclick="gta_push('CS','Remote bar icon','');"><img alt="고객센터" src="//img.navimro.com/img/ms3/footer/floatBar/quick-cumtom.png"/></a>
# </div>
# <div class="bar"></div>
# <div class="view-pro" id="latest-viewed">
# <ul class="clearFix w320">
# <li class="tit"><img alt="최근본상품" src="//img.navimro.com/img/ms3/footer/floatBar/tit-view-pro.gif"/></li>
# <li class="more mu-pointer"><img alt="더보기" onclick="moreList(this);" src="//img.navimro.com/img/ms3/footer/floatBar/more-plus.png"/></li>
# </ul>
# <div class="more-list">
# <a class="more-close" href="#." onclick="closeMoreList(this);"><img alt="닫기" src="//img.navimro.com/img/ms3/footer/remote-close-b.png"/></a>
# </div>
# </div>
# <div class="bar"></div>
# <div class="view-pro">
# <div>
# <a class="btn-remote-login" href="//www.navimro.com/login" onclick="gta_push('Login in Inflow','Remote Bar','Click Login in btn');">로그인</a>
# <a class="btn-remote-join" href="//www.navimro.com/register" onclick="gta_push('Registration Inflow','Remote Bar','Click registration btn');">회원가입</a>
# </div>
# </div>
# <div class="bar"></div>
# <div class="top">
# <a class="goTop" href="#"><img alt="" src="//img.navimro.com/img/ms3/footer/floatBar/gotop.png"/></a>
# </div>
# </div>
# </div>
# <script>
# //이미지 호스트
# function getImgHost() {
# 	var imgHostObj = $('#img-url');
# 	return (imgHostObj != null) ? imgHostObj.val() : "";
# }
# //리소스 호스트 주소
# function getResHost() {
# 	var imgResObj = $('#res-url');
# 	return (imgResObj != null) ? imgResObj.val() : "";
# }
# //ms3 호스트 주소
# function getMs3Host() {
# 	var ms3HostObj = $('#ms3-url');
# 	return (ms3HostObj != null) ? ms3HostObj.val() : "";
# }
# //ec 호스트 주소
# function getEcHost() {
# 	var ecHostObj = $('#ec-url');
# 	return (ecHostObj != null) ? ecHostObj.val() : "";
# }
# </script>
# <input id="ec-url" type="hidden" value="//www.navimro.com"/>
# <input id="ms3-url" type="hidden" value="//www.navimro.com"/>
# <input id="img-url" type="hidden" value="//img.navimro.com/"/>
# <input id="res-url" type="hidden" value="/res/"/>
# <input id="login-flag" type="hidden" value="false"/>
# <div class="se-pre-con dp-none">
# <div class="modal-backdrop"></div>
# <div class="modal-scrollable">
# <div class="loading-spinner wp100">
# <div class="layer">
# <div class="layer_inner">
# <div class="content"><img alt="Loading.." src="//img.navimro.com/img/ms3/progress/animated_spinner.gif"/></div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <script>
# function openAlert1Btn(text, submitText, submitFunc) {
# 	// 원버튼 알럿레이어는 알럿박스로 전환
#
# 	alert(text);
# 	if (submitFunc != null) {
# 		submitFunc();
# 	}
# }
# function openAlert2Btn(text, submitText, submitFunc, cancelText, cancelFunc) {
# 	$('#common-alert-2btn').fadeIn("fast");
# 	$('#common-alert-2btn .text').html(text);
# 	$('#common-alert-2btn .submit').html(submitText);
# 	$('#common-alert-2btn .submit').click(submitFunc);
# 	$('#common-alert-2btn .cancel').html(cancelText);
# 	$('#common-alert-2btn .cancel').click(cancelFunc);
# }
#
# // 예/아니오 버튼 색상 반전
# function openAlert2BtnRevers(text, submitText, submitFunc, cancelText, cancelFunc) {
# 	$('#common-alert-2btn-revers').fadeIn("fast");
# 	$('#common-alert-2btn-revers .text').html(text);
# 	$('#common-alert-2btn-revers .submit').html(cancelText);
# 	$('#common-alert-2btn-revers .submit').click(cancelFunc);
# 	$('#common-alert-2btn-revers .cancel').html(submitText);
# 	$('#common-alert-2btn-revers .cancel').click(submitFunc);
# }
#
# // 팝업용 공통 알럿창
# function openPopAlert1Btn(text, submitText, submitFunc) {
# 	$('#pw-alert .alert-text .text').html(text);
# 	$('#pw-alert .alert-btn .btn').html(submitText);
# 	$('#pw-alert .alert-btn .btn').click(function() {submitFunc(); openPopAlertInit(); });
# 	$('#pw-alert .alert-btn .alert-btn-inv').hide();
# 	$('#pw-alert').show();
# }
# //팝업용 공통 컨펀창
# function openPopAlert2Btn(text, submitText, submitFunc, submitText2, submitFunc2) {
# 	$('#pw-alert .alert-text .text').html(text);
# 	$('#pw-alert .alert-btn .btn').html(submitText);
# 	$('#pw-alert .alert-btn .btn').click(function() {submitFunc(); openPopAlertInit();});
# 	$('#pw-alert .alert-btn .alert-btn-inv').show();
# 	$('#pw-alert .alert-btn .alert-btn-inv').html(submitText2);
# 	$('#pw-alert .alert-btn .alert-btn-inv').click(function() {submitFunc2(); openPopAlertInit();});
# 	$('#pw-alert').show();
# }
# //팝업용 공통창 reset
# function openPopAlertInit() {
# 	$('#pw-alert').hide();
# 	$('#pw-alert .alert-text .text').html('');
# 	$('#pw-alert .alert-btn .btn').html('');
# 	$('#pw-alert .alert-btn .btn').unbind('click');
# 	$('#pw-alert .alert-btn .alert-btn-inv').hide();
# 	$('#pw-alert .alert-btn .alert-btn-inv').html('');
# 	$('#pw-alert .alert-btn .alert-btn-inv').unbind('click');
# }
#
# </script>
# <div class="alert-div" id="common-alert-2btn">
# <p class="text"></p>
# <p class="btn-area">
# <a class="submit"></a>
# <a class="cancel"></a>
# </p>
# </div>
# <div class="alert-div" id="common-alert-2btn-revers">
# <p class="text"></p>
# <p class="btn-area">
# <a class="cancel"></a>
# <a class="submit"></a>
# </p>
# </div>
# <div class="dp-none" id="pw-alert">
# <div class="alert-text">
# <p class="text"></p>
# </div>
# <div class="alert-btn">
# <button class="alert-btn-inv dp-none"></button>
# <button class="btn"></button>
# </div>
# </div>
# <div class="se-pre-con dp-none">
# <div class="modal-backdrop"></div>
# <div class="modal-box" id="login-pop" style="width:460px;">
# <a class="icon icon-close-layer js-modal-close close"></a>
# <h5>나비엠알오 로그인</h5>
# <p class="mb5">회원 번호 혹은 이메일</p>
# <input class="mb10 form-control4 wp100 lt-sp0 fs15" id="loginId" placeholder="sample@example.com or 회원 번호" type="text"/>
# <p class="mb5">비밀번호</p>
# <input class="mb20 form-control4 wp100 lt-sp0 fs15" id="password" onkeyup="onKeyupPwd(event);" placeholder="비밀번호" type="password"/>
# <input id="autoLogin" name="autoLogin" onchange="autoLoginAlertCommon(this);" type="checkbox"/>
# <label class="auto_login__label" for="autoLogin">자동 로그인</label>
# <div class="auto_login__alert" style="display:none;">
# <p>개인정보보호를 위해 개인 PC에서만 사용해주세요.<br/>마이페이지 설정 또는 로그아웃을 통하여 해제할 수 있습니다.</p>
# <a href="/help">자세히보기</a>
# </div>
# <div class="clearFix" style="text-align:center;">
# <a class="fr btn btn-orange btn-ms w160" id="login-pop-btn" onclick="gta_push('Login in','Popup','Completion of Login in btn');">로그인</a>
# <a class="fl btn btn-in-white btn-ms w155" href="//www.navimro.com/register" onclick="gta_push('Registration Inflow','Popup','Click registration btn');">회원가입</a>
# <img alt="로그인.." class="dp-none mr10" id="login-pop-progress" src="//img.navimro.com/img/ms3/progress/animated_spinner_sm.gif"/>
# </div>
# <div id="nonMember" style="display:none;">
# <button class="noMember-order" onclick="javascript:nonMemberDoOrder(); gta_push_none('nonMember', 'click go to order', 'cart page');">비회원 구매하기 &gt;</button>
# </div>
# <div class="text-center mt10">
# <a href="//www.navimro.com/inquiry/idInquiry" onclick="gta_push('Login Popup','ID Inquiry Btn','');" target="_blank">아이디 찾기</a>ㅣ
# 			<a href="//www.navimro.com/inquiry/passInquiry" onclick="gta_push('Login Popup','PW Inquiry Btn','');" target="_blank">비밀번호 찾기</a></div>
# </div>
# </div>
# <script src="//wcs.naver.net/wcslog.js"> </script>
# <script>
#
# gtag('event', 'uid_dimension', {'uid': customerCode, 'non_interaction': true});
# gtag('event', 'member_dimension', {'member': cookieMember, 'non_interaction': true});
# gtag('event', 'searchV_dimension', {'searchV': searchV, 'non_interaction': true});
# gtag('event', 'user_id_new_dimension', {'user_id_new': userId + '_' + emtest, 'non_interaction': true});
#
#
#
# if (!wcs_add) var wcs_add={};
# wcs_add["wa"] = "s_3d0f720bbe67";
# if (!_nasa) var _nasa={};
# wcs.inflow();
# wcs_do(_nasa);
# </script>
# </body>
# </html>

# %%
targetValue = htmlObj.find(name="div", attrs = {"id":"membership_campaign"})
targetValue
