# %% [markdown]
# # 1. 라이브러리 선언

# %%
import pandas as pd

# %% [markdown]
# # 2. 공공데이터 (파일데이터 불러오기)

# %%
pirLirUrl = "https://www.data.go.kr/cmm/cmm/fileDownload.do?atchFileId=FILE_000000002340074&fileDetailSn=1&dataNm=%ED%95%9C%EA%B5%AD%EC%A3%BC%ED%83%9D%EA%B8%88%EC%9C%B5%EA%B3%B5%EC%82%AC_%EC%A7%80%EC%97%AD%EB%B3%84%20PIR%20%EB%B0%8F%20LIR"

# %%
indata = pd.read_csv(pirLirUrl, encoding="ms949")
indata.tail()
# Out:
#        연도  월  전국PIR  서울PIR  부산PIR  대구PIR  인천PIR  광주PIR  대전PIR  울산PIR  ...  \
# 190  2020  1   4.47   5.44   4.84   5.16   4.39   4.76   4.52   4.11  ...
# 191  2020  2   4.45   5.02   5.04   4.92   4.49   4.52   4.36   3.90  ...
# 192  2020  3   4.76   5.12   5.22   5.20   4.76   5.04   4.74   4.11  ...
# 193  2020  4   4.83   4.95   5.67   5.91   4.78   5.41   5.40   4.44  ...
# 194  2020  5   4.56   4.88   7.01   5.44   4.56   3.16   4.72   5.77  ...
#
#      세종LIR  경기LIR  강원LIR  충북LIR  충남LIR  전북LIR  전남LIR  경북LIR  경남LIR  제주LIR
# 190   2.63   2.39   1.90   1.76   1.87   1.94   1.85   1.80   2.02   2.13
# 191   2.69   2.34   1.96   1.87   1.89   1.83   1.68   1.69   1.91   2.07
# 192   2.22   2.56   2.13   1.98   2.03   1.97   1.89   1.95   2.23   2.27
# 193   1.73   2.54   2.13   2.09   2.14   2.11   1.94   1.97   2.06   1.85
# 194   0.00   2.23   2.44   1.08   1.65   1.04   1.68   1.99   2.17   0.96
#
# [5 rows x 38 columns]

# %% [markdown]
# # 2번에 대한 실습 (공공데이터포털에서 한국감정원 오피스텔 동향조사 현황자료를 검색하여 데이터타입자료를 불러오세요)

# %%
import pandas as pd
#패키지 임포트

url = "https://www.data.go.kr/cmm/cmm/fileDownload.do?atchFileId=FILE_000000002312933&fileDetailSn=1&dataNm=%ED%95%9C%EA%B5%AD%EB%B6%80%EB%8F%99%EC%82%B0%EC%9B%90_%EC%98%A4%ED%94%BC%EC%8A%A4%ED%85%94%20%EC%A0%84%EC%84%B8%EA%B0%80%EA%B2%A9(%EC%9B%94%EB%B3%84)_20201014"
# 다운로드 링크를 url변수에 지정
indata = pd.read_csv(url, encoding="ms949")
# csv파일을 읽어올 링크와 인코딩 형식을 indata변수에 담음
indata
# 출력

# %% [markdown]
# # 국가통계포털 API데이터 불러오기 (횡단면 조회)

# %%
import pandas as pd

url = "https://kosis.kr/openapi/statisticsData.do?method=getList&apiKey=ZDBkZjU4MzlkOWQ3MDAzYTZkZDdhYjBjZDM0ZDE0MTY=&format=json&jsonVD=Y&userStatsId=hdk2006/101/DT_1B040A3/2/1/20210412145641&prdSe=M&newEstPrdCnt=1"
json = pd.DataFrame()
try:
    json = pd.read_json(url)
except Exception as e:
    print(e)
json

# %% [markdown]
# # 국가통계포털 API데이터 불러오기 (시계열 조회, 총인구수 * 서울특별시)

# %%
import pandas as pd
url = "https://kosis.kr/openapi/statisticsData.do?method=getList&apiKey=ZDBkZjU4MzlkOWQ3MDAzYTZkZDdhYjBjZDM0ZDE0MTY=&format=json&jsonVD=Y&userStatsId=hdk2006/101/DT_1B040A3/2/1/20210412150415_1&prdSe=M&newEstPrdCnt=3"
json = pd.DataFrame()
try:
    json = pd.read_json(url)
except Exception as e:
    print(e)
json

# %% [markdown]
# # 1행 82500 2008
# # 2행 72500 2010

# %%
columnList = [] 
rowList = []  # 리스트 선언

# %%
columnList.append("82500")
columnList.append("2008")  # 컬럼 리스트에 값 추가
rowList.append(columnList) # 로우 리스트에 컬럼리스트를 추가

# %%
columnList=[]  # 컬럼리스트 초기화
columnList.append("72500")
columnList.append("2010") #컬럼 리스트 값 추가
rowList.append(columnList)  # 로우 리스트에 컬럼리스트 추가

pd.DataFrame(rowList) # 출력
# Out:
#        0     1
# 0  82500  2008
# 1  72500  2010

# %%
pip install bs4
# Out:
# Collecting bs4
#   Downloading bs4-0.0.1.tar.gz (1.1 kB)
# Requirement already satisfied: beautifulsoup4 in c:\users\smart-20\anaconda3\lib\site-packages (from bs4) (4.9.3)
# Requirement already satisfied: soupsieve>1.2; python_version >= "3.0" in c:\users\smart-20\anaconda3\lib\site-packages (from beautifulsoup4->bs4) (2.0.1)
# Building wheels for collected packages: bs4
#   Building wheel for bs4 (setup.py): started
#   Building wheel for bs4 (setup.py): finished with status 'done'
#   Created wheel for bs4: filename=bs4-0.0.1-py3-none-any.whl size=1277 sha256=c0bc422d357093d8b975776ff47acabc53e7c5f2987206fd96626c8d161c300d
#   Stored in directory: c:\users\smart-20\appdata\local\pip\cache\wheels\75\78\21\68b124549c9bdc94f822c02fb9aa3578a669843f9767776bca
# Successfully built bs4
# Installing collected packages: bs4
# Successfully installed bs4-0.0.1
# Note: you may need to restart the kernel to use updated packages.

# %%
import requests        # API 서비스에 연결
from lxml import html  # parse XML 사용
from bs4 import BeautifulSoup   # 정렬해주는 BeautifulSoup 사용
import pandas as pd

# %%
url="http://openapi.molit.go.kr/OpenAPI_ToolInstallPackage/service/rest/RTMSOBJSvc/getRTMSDataSvcAptTradeDev"
response = requests.get(url+queryParams)
response.encoding="utf-8"


xmlobj = BeautifulSoup(response.text,"lxml-xml") #parser
xmlobj

# %%
import requests        # API 서비스에 연결
from lxml import html  # parse XML 사용
from bs4 import BeautifulSoup   # 정렬해주는 BeautifulSoup 사용
import pandas as pd
from urllib.request import Request, urlopen
from urllib.parse import urlencode, quote_plus,unquote

API_Key = 'AT33s775KYpJOkUBJu0dxkJuUeIfDIOJRzAH084EQS3JN%2BzFjErLHuk%2FGZa9L4gBTSGCzeA69tI9PwLp7B37IQ%3D%3D' # 서비스 키
url="http://openapi.molit.go.kr/OpenAPI_ToolInstallPackage/service/rest/RTMSOBJSvc/getRTMSDataSvcAptTradeDev" # 실질적인 url 주소
queryParams = '?' + urlencode({          # 아래 3가지 요소를 합한 값
    quote_plus('ServiceKey') : API_Key,  # ServiceKey
    quote_plus('LAWD_CD'): '11110',      # LAWD_CD
    quote_plus('DEAL_YMD'):'201512'      # DEAL_YMD
})

response = requests.get("http://openapi.molit.go.kr/OpenAPI_ToolInstallPackage/service/rest/RTMSOBJSvc/getRTMSDataSvcAptTradeDev?serviceKey=AT33s775KYpJOkUBJu0dxkJuUeIfDIOJRzAH084EQS3JN%2BzFjErLHuk%2FGZa9L4gBTSGCzeA69tI9PwLp7B37IQ%3D%3D&pageNo=1&numOfRows=10&LAWD_CD=11110&DEAL_YMD=201512")
#response는 url?ServiceKey&pageNo=1&numOfRows=10(item의 규격)&LAWD_CD&DEAL_YMD 를 합한 값을 가져오는 변수
response.encoding='utf-8'     # response의 인코딩 형식 지정
pageSource = response.text
xmlobj = BeautifulSoup(pageSource,"lxml-xml") #태그와 내용을 모두 보여줌

rowList = []                    # 행 내용을 담을 빈 배열을 생성
columnList = []                 # 열 내용을 담을 빈 배열을 생성
rows = xmlobj.findAll('item')   # "items" 안에 모든 내용을 담을 rows라는 변수를 생성

for i in range(0, len(rows)): 
    columns = rows[i].findAll() # 하나의 "item"의 모든 내용을 담을 columns라는 변수를 생성
    
    for j in range(0, len(columns)):  
        columnValue = columns[j].text    # item의 태그를 제외한 내용만을 담는 columnValue생성
        columnList.append(columnValue)   # 내용들을 columnList에 추가함
    rowList.append(columnList)           # 하나의 "item"이 columnList에 추가가 완료 되면 하나의 행(rows)이 완성됨 
    columnList = []                      # 다음 "item"값들을 넣어주기 위해 columnList를 초기화
    
homePriceSeoul = pd.DataFrame(rowList)  # 만들어진 표를 homePriceSeoul 변수에 담음
homePriceSeoul                          # 출력

columnHead = []               #item의 태그만을 받아 제목으로 쓰기위해 빈 리스트 columnHead를 만들어줌
for i in range(0, len(columns)):
    eachColumns = columns[i]        # item 하나당 받은 태그의 내용을 eachColumns 변수에 넣어줌
    columnHead.append(eachColumns.name)  # eachColumns의 태그이름만을 columnHead에 추가해줌
homePriceSeoul.columns = columnHead # homePriceSeoul테이블의 columns
homePriceSeoul                      # 출력

# %%
# 혁중이 형이 짠 컬럼이름 정해주는 코드
# columnNameList = []
# for i in range(0, len(columns)):
#         eachColumn = columns[i]
#         columnNameList.append(eachColumn.name.strip())  # or text.strip() 공백제거
# housePriceData.columns = columnNameList
# housePriceData

# %% [markdown]
# # 금융 검색 후 “시도별 금융권 대출잔액 수준별 인구＂

# %%
import pandas as pd
#
url = "https://kosis.kr/openapi/statisticsData.do?method=getList&apiKey=ZDBkZjU4MzlkOWQ3MDAzYTZkZDdhYjBjZDM0ZDE0MTY=&format=json&jsonVD=Y&userStatsId=hdk2006/101/DT_1MA0028/2/1/20210412192956&prdSe=Y&newEstPrdCnt=1"
# 시도별 금융권 대출잔액 수준별 인구의 url을 변수로 지정
json = pd.DataFrame()
# DataFrame 형식으로 나타냄
try:
    json = pd.read_json(url)
# url의 자료를 json을 불러와서 나타냄
except Exception as e:
    print(e)
# 오류가 있다면 오류구문 출력
json
# 결과출력
# Out:
#                    TBL_NM  ITM_NM_ENG ITM_ID  ORG_ID  UNIT_NM_ENG C1_OBJ_NM  \
# 0     시도별 금융권 대출잔액 수준별 인구  Population   T001     101  1000Persons       시도별
# 1     시도별 금융권 대출잔액 수준별 인구  Population   T001     101  1000Persons       시도별
# 2     시도별 금융권 대출잔액 수준별 인구  Population   T001     101  1000Persons       시도별
# 3     시도별 금융권 대출잔액 수준별 인구  Population   T001     101  1000Persons       시도별
# 4     시도별 금융권 대출잔액 수준별 인구  Population   T001     101  1000Persons       시도별
# ...                   ...         ...    ...     ...          ...       ...
# 1183  시도별 금융권 대출잔액 수준별 인구  Population   T001     101  1000Persons       시도별
# 1184  시도별 금융권 대출잔액 수준별 인구  Population   T001     101  1000Persons       시도별
# 1185  시도별 금융권 대출잔액 수준별 인구  Population   T001     101  1000Persons       시도별
# 1186  시도별 금융권 대출잔액 수준별 인구  Population   T001     101  1000Persons       시도별
# 1187  시도별 금융권 대출잔액 수준별 인구  Population   T001     101  1000Persons       시도별
#
#      C2_OBJ_NM     C3_OBJ_NM   C2      C1_NM_ENG  ... C1_OBJ_NM_ENG  \
# 0          연령별  금융권 대출잔액 수준별  A10  Whole country  ...   By province
# 1          연령별  금융권 대출잔액 수준별  A10  Whole country  ...   By province
# 2          연령별  금융권 대출잔액 수준별  A10  Whole country  ...   By province
# 3          연령별  금융권 대출잔액 수준별  A10  Whole country  ...   By province
# 4          연령별  금융권 대출잔액 수준별  A10  Whole country  ...   By province
# ...        ...           ...  ...            ...  ...           ...
# 1183       연령별  금융권 대출잔액 수준별  A15           Jeju  ...   By province
# 1184       연령별  금융권 대출잔액 수준별  A15           Jeju  ...   By province
# 1185       연령별  금융권 대출잔액 수준별  A15           Jeju  ...   By province
# 1186       연령별  금융권 대출잔액 수준별  A15           Jeju  ...   By province
# 1187       연령별  금융권 대출잔액 수준별  A15           Jeju  ...   By province
#
#      C2_OBJ_NM_ENG  C3_OBJ_NM_ENG    C3       DT PRD_SE  C1    C1_NM   C2_NM  \
# 0           By age  By depl level  DL00  19979.1      A   0       전국       계
# 1           By age  By depl level  DL10  11252.8      A   0       전국       계
# 2           By age  By depl level  DL11   1853.3      A   0       전국       계
# 3           By age  By depl level  DL12   2471.0      A   0       전국       계
# 4           By age  By depl level  DL13   1369.2      A   0       전국       계
# ...            ...            ...   ...      ...    ...  ..      ...     ...
# 1183        By age  By depl level  DL15      1.6      A  39  제주특별자치도  60-64세
# 1184        By age  By depl level  DL16      2.9      A  39  제주특별자치도  60-64세
# 1185        By age  By depl level  DL17      1.0      A  39  제주특별자치도  60-64세
# 1186        By age  By depl level  DL18      2.3      A  39  제주특별자치도  60-64세
# 1187        By age  By depl level  DL20     22.3      A  39  제주특별자치도  60-64세
#
#             C3_NM
# 0               계
# 1            부채있음
# 2         1천만원 미만
# 3       1-3천만원 미만
# 4       3-5천만원 미만
# ...           ...
# 1183  7천만원-1억원 미만
# 1184     1-2억원 미만
# 1185     2-3억원 미만
# 1186       3억원 이상
# 1187         부채없음
#
# [1188 rows x 26 columns]

# %% [markdown]
# # 리스트에서 데이터프레임 생성하기

# %%
import pandas as pd
rowFirst = ["A01", 202015, 100]
rowSecond = ["A02", 202016, 110]
rowThird = ["A03",202017,120]

# %%
df1 = pd.DataFrame([rowFirst,rowThird,rowSecond])

# %%
df1.columns = ["RegionID" , "YEARWEEK", "QTY"]
columnNameList = df1

# %%
columnFirst = ["A0","A01","A01"]
columnSecond = [202015, 202016, 202017]
columnThird = [100,110,150]

# %%
df2 = pd.DataFrame(zip(columnFirst, columnSecond, columnThird),columns = columnNameList)

# %%
df2.columns = columnNameList

# %%
df2
# Out:
#   (A01, 202015, 100)  (A03, 202017, 120)  (A02, 202016, 110)
# 0                 A0              202015                 100
# 1                A01              202016                 110
# 2                A01              202017                 150

# %% [markdown]
# # 타겟 URL 선언 및 접속

# %%
from bs4 import BeautifulSoup # 태그를 이쁘게 쓰게해준다
import requests # 웹페이지에 접속요청

# %%
targetUrl = "https://sparkkorea.com/%ED%80%B4%EC%A6%88/"

# %%
resp = requests.get(targetUrl)
resp.encoding = 'utf-8'

# %%
html = resp.text

htmlObj = BeautifulSoup(html, "html.parser")

# %%
htmlObj
# Out:
# <!DOCTYPE html>
#
# <html lang="ko-KR">
# <head>
# <meta charset="utf-8"/>
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <link href="http://gmpg.org/xfn/11" rel="profile"/>
# <link href="https://sparkkorea.com/xmlrpc.php" rel="pingback"/>
# <title>퀴즈 – 스파크 코리아</title>
# <meta content="max-image-preview:large" name="robots">
# <meta content="QRZVgHsoL23RuwmgmXNuXfO-mUaxCkdvhP2rRvLT270" name="google-site-verification">
# <!-- Async WordPress.com Remote Login -->
# <script id="wpcom_remote_login_js">
# var wpcom_remote_login_extra_auth = '';
# function wpcom_remote_login_remove_dom_node_id( element_id ) {
# 	var dom_node = document.getElementById( element_id );
# 	if ( dom_node ) { dom_node.parentNode.removeChild( dom_node ); }
# }
# function wpcom_remote_login_remove_dom_node_classes( class_name ) {
# 	var dom_nodes = document.querySelectorAll( '.' + class_name );
# 	for ( var i = 0; i < dom_nodes.length; i++ ) {
# 		dom_nodes[ i ].parentNode.removeChild( dom_nodes[ i ] );
# 	}
# }
# function wpcom_remote_login_final_cleanup() {
# 	wpcom_remote_login_remove_dom_node_classes( "wpcom_remote_login_msg" );
# 	wpcom_remote_login_remove_dom_node_id( "wpcom_remote_login_key" );
# 	wpcom_remote_login_remove_dom_node_id( "wpcom_remote_login_validate" );
# 	wpcom_remote_login_remove_dom_node_id( "wpcom_remote_login_js" );
# 	wpcom_remote_login_remove_dom_node_id( "wpcom_request_access_iframe" );
# 	wpcom_remote_login_remove_dom_node_id( "wpcom_request_access_styles" );
# }
#
# // Watch for messages back from the remote login
# window.addEventListener( "message", function( e ) {
# 	if ( e.origin === "https://r-login.wordpress.com" ) {
# 		var data = {};
# 		try {
# 			data = JSON.parse( e.data );
# 		} catch( e ) {
# 			wpcom_remote_login_final_cleanup();
# 			return;
# 		}
#
# 		if ( data.msg === 'LOGIN' ) {
# 			// Clean up the login check iframe
# 			wpcom_remote_login_remove_dom_node_id( "wpcom_remote_login_key" );
#
# 			var id_regex = new RegExp( /^[0-9]+$/ );
# 			var token_regex = new RegExp( /^.*|.*|.*$/ );
# 			if (
# 				token_regex.test( data.token )
# 				&& id_regex.test( data.wpcomid )
# 			) {
# 				// We have everything we need to ask for a login
# 				var script = document.createElement( "script" );
# 				script.setAttribute( "id", "wpcom_remote_login_validate" );
# 				script.src = '/remote-login.php?wpcom_remote_login=validate'
# 					+ '&wpcomid=' + data.wpcomid
# 					+ '&token=' + encodeURIComponent( data.token )
# 					+ '&host=' + window.location.protocol
# 						+ '//' + window.location.hostname;
# 				document.body.appendChild( script );
# 			}
#
# 			return;
# 		}
#
# 		// Safari ITP, not logged in, so redirect
# 		if ( data.msg === 'LOGIN-REDIRECT' ) {
# 			window.location = 'https://wordpress.com/log-in?redirect_to=' + window.location.href;
# 			return;
# 		}
#
# 		// Safari ITP, storage access failed, remove the request
# 		if ( data.msg === 'LOGIN-REMOVE' ) {
# 			var css_zap = 'html { -webkit-transition: margin-top 1s; transition: margin-top 1s; } /* 9001 */ html { margin-top: 0 !important; } * html body { margin-top: 0 !important; } @media screen and ( max-width: 782px ) { html { margin-top: 0 !important; } * html body { margin-top: 0 !important; } }';
# 			var style_zap = document.createElement( 'style' );
# 			style_zap.type = 'text/css';
# 			style_zap.appendChild( document.createTextNode( css_zap ) );
# 			document.body.appendChild( style_zap );
#
# 			var e = document.getElementById( 'wpcom_request_access_iframe' );
# 			e.parentNode.removeChild( e );
#
# 			document.cookie = 'wordpress_com_login_access=denied; path=/; max-age=31536000';
#
# 			return;
# 		}
#
# 		// Safari ITP
# 		if ( data.msg === 'REQUEST_ACCESS' ) {
# 			console.log( 'request access: safari' );
#
# 			// Check ITP iframe enable/disable knob
# 			if ( wpcom_remote_login_extra_auth !== 'safari_itp_iframe' ) {
# 				return;
# 			}
#
# 			// If we are in a "private window" there is no ITP.
# 			var private_window = false;
# 			try {
# 				var opendb = window.openDatabase( null, null, null, null );
# 			} catch( e ) {
# 				private_window = true;
# 			}
#
# 			if ( private_window ) {
# 				console.log( 'private window' );
# 				return;
# 			}
#
# 			var iframe = document.createElement( 'iframe' );
# 			iframe.id = 'wpcom_request_access_iframe';
# 			iframe.setAttribute( 'scrolling', 'no' );
# 			iframe.setAttribute( 'sandbox', 'allow-storage-access-by-user-activation allow-scripts allow-same-origin allow-top-navigation-by-user-activation' );
# 			iframe.src = 'https://r-login.wordpress.com/remote-login.php?wpcom_remote_login=request_access&origin=' + encodeURIComponent( data.origin ) + '&wpcomid=' + encodeURIComponent( data.wpcomid );
#
# 			var css = 'html { -webkit-transition: margin-top 1s; transition: margin-top 1s; } /* 9001 */ html { margin-top: 46px !important; } * html body { margin-top: 46px !important; } @media screen and ( max-width: 660px ) { html { margin-top: 71px !important; } * html body { margin-top: 71px !important; } #wpcom_request_access_iframe { display: block; height: 71px !important; } } #wpcom_request_access_iframe { border: 0px; height: 46px; position: fixed; top: 0; left: 0; width: 100%; min-width: 100%; z-index: 99999; background: #23282d; } ';
#
# 			var style = document.createElement( 'style' );
# 			style.type = 'text/css';
# 			style.id = 'wpcom_request_access_styles';
# 			style.appendChild( document.createTextNode( css ) );
# 			document.body.appendChild( style );
#
# 			document.body.appendChild( iframe );
# 		}
#
# 		if ( data.msg === 'DONE' ) {
# 			wpcom_remote_login_final_cleanup();
# 		}
# 	}
# }, false );
#
# // Inject the remote login iframe after the page has had a chance to load
# // more critical resources
# window.addEventListener( "DOMContentLoaded", function( e ) {
# 	var iframe = document.createElement( "iframe" );
# 	iframe.style.display = "none";
# 	iframe.setAttribute( "scrolling", "no" );
# 	iframe.setAttribute( "id", "wpcom_remote_login_key" );
# 	iframe.src = "https://r-login.wordpress.com/remote-login.php"
# 		+ "?wpcom_remote_login=key"
# 		+ "&origin=aHR0cHM6Ly9zcGFya2tvcmVhLmNvbQ%3D%3D"
# 		+ "&wpcomid=163927570"
# 		+ "&time=1618297345";
# 	document.body.appendChild( iframe );
# }, false );
# </script>
# <link href="//s2.wp.com" rel="dns-prefetch">
# <link href="//sparkkorea.wordpress.com" rel="dns-prefetch">
# <link href="//s0.wp.com" rel="dns-prefetch"/>
# <link href="//wordpress.com" rel="dns-prefetch"/>
# <link href="//fonts.googleapis.com" rel="dns-prefetch"/>
# <link href="https://sparkkorea.com/feed/" rel="alternate" title="스파크 코리아 » 피드" type="application/rss+xml"/>
# <link href="https://sparkkorea.com/comments/feed/" rel="alternate" title="스파크 코리아 » 댓글 피드" type="application/rss+xml"/>
# <script type="text/javascript">
# 		/* <![CDATA[ */
# 		function addLoadEvent(func) {
# 			var oldonload = window.onload;
# 			if (typeof window.onload != 'function') {
# 				window.onload = func;
# 			} else {
# 				window.onload = function () {
# 					oldonload();
# 					func();
# 				}
# 			}
# 		}
# 		/* ]]> */
# 	</script>
# <script type="text/javascript">
# 			window._wpemojiSettings = {"baseUrl":"https:\/\/s0.wp.com\/wp-content\/mu-plugins\/wpcom-smileys\/twemoji\/2\/72x72\/","ext":".png","svgUrl":"https:\/\/s0.wp.com\/wp-content\/mu-plugins\/wpcom-smileys\/twemoji\/2\/svg\/","svgExt":".svg","source":{"concatemoji":"https:\/\/s0.wp.com\/wp-includes\/js\/wp-emoji-release.min.js?m=1612197847h&ver=5.7.1-RC1-50691"}};
# 			!function(e,a,t){var n,r,o,i=a.createElement("canvas"),p=i.getContext&&i.getContext("2d");function s(e,t){var a=String.fromCharCode;p.clearRect(0,0,i.width,i.height),p.fillText(a.apply(this,e),0,0);e=i.toDataURL();return p.clearRect(0,0,i.width,i.height),p.fillText(a.apply(this,t),0,0),e===i.toDataURL()}function c(e){var t=a.createElement("script");t.src=e,t.defer=t.type="text/javascript",a.getElementsByTagName("head")[0].appendChild(t)}for(o=Array("flag","emoji"),t.supports={everything:!0,everythingExceptFlag:!0},r=0;r<o.length;r++)t.supports[o[r]]=function(e){if(!p||!p.fillText)return!1;switch(p.textBaseline="top",p.font="600 32px Arial",e){case"flag":return s([127987,65039,8205,9895,65039],[127987,65039,8203,9895,65039])?!1:!s([55356,56826,55356,56819],[55356,56826,8203,55356,56819])&&!s([55356,57332,56128,56423,56128,56418,56128,56421,56128,56430,56128,56423,56128,56447],[55356,57332,8203,56128,56423,8203,56128,56418,8203,56128,56421,8203,56128,56430,8203,56128,56423,8203,56128,56447]);case"emoji":return!s([55357,56424,8205,55356,57212],[55357,56424,8203,55356,57212])}return!1}(o[r]),t.supports.everything=t.supports.everything&&t.supports[o[r]],"flag"!==o[r]&&(t.supports.everythingExceptFlag=t.supports.everythingExceptFlag&&t.supports[o[r]]);t.supports.everythingExceptFlag=t.supports.everythingExceptFlag&&!t.supports.flag,t.DOMReady=!1,t.readyCallback=function(){t.DOMReady=!0},t.supports.everything||(n=function(){t.readyCallback()},a.addEventListener?(a.addEventListener("DOMContentLoaded",n,!1),e.addEventListener("load",n,!1)):(e.attachEvent("onload",n),a.attachEvent("onreadystatechange",function(){"complete"===a.readyState&&t.readyCallback()})),(n=t.source||{}).concatemoji?c(n.concatemoji):n.wpemoji&&n.twemoji&&(c(n.twemoji),c(n.wpemoji)))}(window,document,window._wpemojiSettings);
# 		</script>
# <style type="text/css">
# img.wp-smiley,
# img.emoji {
# 	display: inline !important;
# 	border: none !important;
# 	box-shadow: none !important;
# 	height: 1em !important;
# 	width: 1em !important;
# 	margin: 0 .07em !important;
# 	vertical-align: -0.1em !important;
# 	background: none !important;
# 	padding: 0 !important;
# }
# </style>
# <link href="https://s1.wp.com/_static/??-?cssminify=yes" id="all-css-0-1" media="all" rel="stylesheet" type="text/css"/>
# <style id="wp-block-library-inline-css">
# .has-text-align-justify {
# 	text-align:justify;
# }
# </style>
# <link crossorigin="anonymous" href="https://fonts.googleapis.com/css?family=Lato%3A400%2C400italic%2C700%2C700italic%7CNoto+Serif%3A400%2C400italic%2C700%2C700italic&amp;subset=latin%2Clatin-ext" id="dyad-2-fonts-css" media="all" rel="stylesheet"/>
# <link href="https://s0.wp.com/_static/??-eJyNj80OgjAQhF/IdSkkxovxWUpZa7XdNv0J4e2pcFBiNNxmsvNNZnEMoDxn4oyuQLBFG06oiSmaevghjyqlA36w+U6OEobS4zDJAVpMebK0I1cT2FuvnntKDau1GMagvPsiNi94qLUyG88bAzcrTfyHRqqDdJV6Wfe2L+jqLuLUdOIsurZ5zCp8dh4=?cssminify=yes" id="all-css-2-1" media="all" rel="stylesheet" type="text/css"/>
# <link href="https://s2.wp.com/wp-content/mu-plugins/global-print/global-print.css?m=1465851035h&amp;cssminify=yes" id="print-css-3-1" media="print" rel="stylesheet" type="text/css"/>
# <style id="jetpack-global-styles-frontend-style-inline-css">
# :root { --font-headings: unset; --font-base: unset; --font-headings-default: -apple-system,BlinkMacSystemFont,"Segoe UI",Roboto,Oxygen-Sans,Ubuntu,Cantarell,"Helvetica Neue",sans-serif; --font-base-default: -apple-system,BlinkMacSystemFont,"Segoe UI",Roboto,Oxygen-Sans,Ubuntu,Cantarell,"Helvetica Neue",sans-serif;}
# </style>
# <link href="https://s1.wp.com/_static/??-eJxti0EKgCAQAD+ULUaJl+gtJqbG6opr9P3o0CHqNAzMwFmEpdxcbpAOUfDwMTMU4iY2NLECB1Nj9g97y9zB/8Vko0GB5Oktn6kFlxxDGMEjrQbvYEmzVHIclNZy2i9lFDfR?cssminify=yes" id="all-css-6-1" media="all" rel="stylesheet" type="text/css"/>
# <script id="wpcom-actionbar-placeholder-js-extra">
# var actionbardata = {"siteID":"163927570","siteName":"\uc2a4\ud30c\ud06c \ucf54\ub9ac\uc544","siteURL":"https:\/\/sparkkorea.com","icon":"<img alt='' src='https:\/\/s2.wp.com\/i\/logo\/wpcom-gray-white.png' class='avatar avatar-50' height='50' width='50' \/>","canManageOptions":"","canCustomizeSite":"","isFollowing":"","themeSlug":"pub\/dyad-2","signupURL":"https:\/\/wordpress.com\/start\/","loginURL":"https:\/\/wordpress.com\/log-in?redirect_to=https%3A%2F%2Fsparkkorea.com%2F%ED%80%B4%EC%A6%88%2F&signup_flow=account&domain=sparkkorea.com","themeURL":"https:\/\/wordpress.com\/theme\/dyad-2\/","xhrURL":"https:\/\/sparkkorea.com\/wp-admin\/admin-ajax.php","nonce":"e8f65ee91c","isSingular":"1","isFolded":"","isLoggedIn":"","isMobile":"","subscribeNonce":"<input type=\"hidden\" id=\"_wpnonce\" name=\"_wpnonce\" value=\"14dc55fb7b\" \/>","referer":"https:\/\/sparkkorea.com\/%ED%80%B4%EC%A6%88\/","canFollow":"","feedID":"97558616","statusMessage":"","customizeLink":"https:\/\/sparkkorea.wordpress.com\/wp-admin\/customize.php?url=https%3A%2F%2Fsparkkorea.wordpress.com%2F%25ED%2580%25B4%25EC%25A6%2588%2F","postID":"102","shortlink":"https:\/\/wp.me\/Pb5P34-1E","canEditPost":"","editLink":"https:\/\/wordpress.com\/page\/sparkkorea.com\/102","statsLink":"https:\/\/wordpress.com\/stats\/post\/102\/sparkkorea.com","i18n":{"view":"\uc0ac\uc774\ud2b8 \ubcf4\uae30","follow":"\ud314\ub85c\uc6b0","following":"\ud314\ub85c\uc6b0\uc911","edit":"\ud3b8\uc9d1","login":"\ub85c\uadf8\uc778","signup":"\uac00\uc785","customize":"\uc0ac\uc6a9\uc790 \uc815\uc758\ud558\uae30","report":"\uc774 \ucf58\ud150\uce20 \uc2e0\uace0\ud558\uae30","themeInfo":"\ud14c\ub9c8 \uac00\uc838\uc624\uae30: Dyad 2","shortlink":"\ub2e8\ucd95 \ub9c1\ud06c \ubcf5\uc0ac","copied":"\ubcf5\uc0ac\ub428","followedText":"\uc774 \uc0ac\uc774\ud2b8\uc758 \uc0c8 \uae00\uc774 \uc774\uc81c <a href=\"https:\/\/wordpress.com\/\">\ub274\uc2a4\ud53c\ub4dc<\/a>\uc5d0 \ud45c\uc2dc\ub429\ub2c8\ub2e4.","foldBar":"\uc774 \ud45c\uc2dc\uc904 \ucd95\uc18c","unfoldBar":"\uc774 \ud45c\uc2dc\uc904 \ud655\uc7a5","editSubs":"\uad6c\ub3c5 \uad00\ub9ac","viewReader":"\ub9ac\ub354\uc5d0\uc11c \uc0ac\uc774\ud2b8 \ubcf4\uae30","viewReadPost":"View post in Reader","subscribe":"\uac00\uc785\ud558\uae30","enterEmail":"\uc774\uba54\uc77c \uc8fc\uc18c \uc785\ub825","followers":"","alreadyUser":"\uc774\ubbf8 \uc6cc\ub4dc\ud504\ub808\uc2a4\ub2f7\ucef4 \uacc4\uc815\uc744 \uac16\uace0 \uacc4\uc138\uc694? <a href=\"https:\/\/wordpress.com\/log-in?redirect_to=https%3A%2F%2Fsparkkorea.com%2F%ED%80%B4%EC%A6%88%2F&signup_flow=account&domain=sparkkorea.com\">\uc9c0\uae08 \ub85c\uadf8\uc778\ud558\uc138\uc694.<\/a>","stats":"\ud1b5\uacc4"}};
# </script>
# <script src="https://s2.wp.com/_static/??-eJyFzUEKwkAMheELmQ5DocWFeJZaY8kwyYxJBu3traBQV67e4v/ghUeFuYijeEgWajFnNJsW7JIdwm/lcqGM0Ax1A+JAcitfRzLndkV7w3RvqOtnOib5i4Bp0clxj3fPmh2qlue6tTOf4hDHPvbDeEwvhOVG7A==" type="text/javascript"></script>
# <script type="text/javascript">
# 	window.addEventListener( 'DOMContentLoaded', function() {
# 		rltInitialize( {"token":null,"iframeOrigins":["https:\/\/widgets.wp.com"]} );
# 	} );
# </script>
# <link href="https://sparkkorea.wordpress.com/xmlrpc.php?rsd" rel="EditURI" title="RSD" type="application/rsd+xml"/>
# <link href="https://s1.wp.com/wp-includes/wlwmanifest.xml" rel="wlwmanifest" type="application/wlwmanifest+xml"/>
# <meta content="WordPress.com" name="generator"/>
# <link href="https://sparkkorea.com/%ed%80%b4%ec%a6%88/" rel="canonical"/>
# <link href="https://wp.me/Pb5P34-1E" rel="shortlink"/>
# <link href="https://public-api.wordpress.com/oembed/?format=json&amp;url=https%3A%2F%2Fsparkkorea.com%2F%25ed%2580%25b4%25ec%25a6%2588%2F&amp;for=wpcom-auto-discovery" rel="alternate" type="application/json+oembed"/><link href="https://public-api.wordpress.com/oembed/?format=xml&amp;url=https%3A%2F%2Fsparkkorea.com%2F%25ed%2580%25b4%25ec%25a6%2588%2F&amp;for=wpcom-auto-discovery" rel="alternate" type="application/xml+oembed"/>
# <!-- Jetpack Open Graph Tags -->
# <meta content="article" property="og:type"/>
# <meta content="퀴즈" property="og:title"/>
# <meta content="https://sparkkorea.com/%ed%80%b4%ec%a6%88/" property="og:url"/>
# <meta content="메인 설문 준비중 Spark 퀴즈 6/13 Spark 심화과정 6/13 Spark 기본과정 6/18 Spark [MAP_FILTER] 6/18 Spark GroupBy 심화 6/25 Spark RDD 실전 분석 6/27 Spark RDD 실전 분석2" property="og:description"/>
# <meta content="2019-07-08T09:35:27+00:00" property="article:published_time"/>
# <meta content="2020-03-20T09:42:15+00:00" property="article:modified_time"/>
# <meta content="스파크 코리아" property="og:site_name"/>
# <meta content="https://s0.wp.com/i/blank.jpg" property="og:image"/>
# <meta content="ko_KR" property="og:locale"/>
# <meta content="@wordpressdotcom" name="twitter:site"/>
# <meta content="퀴즈" name="twitter:text:title"/>
# <meta content="summary" name="twitter:card"/>
# <meta content="https://www.facebook.com/WordPresscom" property="article:publisher"/>
# <!-- End Jetpack Open Graph Tags -->
# <link href="https://s1.wp.com/i/favicon.ico" rel="shortcut icon" sizes="16x16 24x24 32x32 48x48" type="image/x-icon"/>
# <link href="https://s1.wp.com/i/favicon.ico" rel="icon" sizes="16x16 24x24 32x32 48x48" type="image/x-icon"/>
# <link href="https://s2.wp.com/i/webclip.png" rel="apple-touch-icon"/>
# <link href="https://sparkkorea.com/osd.xml" rel="search" title="스파크 코리아" type="application/opensearchdescription+xml"/>
# <link href="https://s1.wp.com/opensearch.xml" rel="search" title="WordPress.com" type="application/opensearchdescription+xml"/>
# <meta content="스파크 코리아" name="application-name"/><meta content="width=device-width;height=device-height" name="msapplication-window"/><meta content="스파크코리아 자료공유" name="msapplication-tooltip"/><meta content="name=구독;action-uri=https://sparkkorea.com/feed/;icon-uri=https://s1.wp.com/i/favicon.ico" name="msapplication-task"/><meta content="name=무료 블로그 등록;action-uri=http://wordpress.com/signup/;icon-uri=https://s1.wp.com/i/favicon.ico" name="msapplication-task"/><meta content="name=WordPress.com 지원;action-uri=http://support.wordpress.com/;icon-uri=https://s1.wp.com/i/favicon.ico" name="msapplication-task"/><meta content="name=WordPress.com 포럼;action-uri=http://forums.wordpress.com/;icon-uri=https://s1.wp.com/i/favicon.ico" name="msapplication-task"/><meta content="메인 설문 준비중 Spark 퀴즈 6/13 Spark 심화과정 6/13 Spark 기본과정 6/18 Spark [MAP_FILTER] 6/18 Spark GroupBy 심화 6/25 Spark RDD 실전 분석 6/27 Spark RDD 실전 분석2" name="description"/>
# </link></link></meta></meta></head>
# <body class="page-template-default page page-id-102 wp-embed-responsive customizer-styles-applied is-singular no-js highlander-enabled highlander-light">
# <div class="hfeed site" id="page">
# <a class="skip-link screen-reader-text" href="#content">컨텐츠로 건너뛰기</a>
# <header class="site-header" id="masthead" role="banner">
# <div class="site-branding">
# <h1 class="site-title">
# <a href="https://sparkkorea.com/" rel="home">
# 					스파크 코리아				</a>
# </h1>
# <p class="site-description">스파크코리아 자료공유</p>
# </div><!-- .site-branding -->
# <nav class="main-navigation" id="site-navigation" role="navigation">
# <button aria-controls="primary-menu" aria-expanded="false" class="menu-toggle">메뉴</button>
# <div class="primary-menu"><ul class="menu" id="primary-menu"><li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-27" id="menu-item-27"><a href="https://sparkkorea.com/%ec%9e%90%eb%a3%8c%ec%8b%a4/">자료실</a></li>
# <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-264" id="menu-item-264"><a href="https://sparkkorea.com/%ec%84%a4%eb%ac%b8-2/">설문s</a></li>
# <li class="menu-item menu-item-type-post_type menu-item-object-page current-menu-item page_item page-item-102 current_page_item menu-item-382" id="menu-item-382"><a aria-current="page" href="https://sparkkorea.com/%ed%80%b4%ec%a6%88/">퀴즈</a></li>
# <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-383" id="menu-item-383"><a href="https://sparkkorea.com/%ed%85%8c%ec%8a%a4%ed%8a%b8/">테스트</a></li>
# <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-397" id="menu-item-397"><a href="https://sparkkorea.com/%ec%84%a4%eb%ac%b8/">학생퀴즈</a></li>
# </ul></div> </nav>
# </header><!-- #masthead -->
# <div class="site-inner">
# <div class="site-content" id="content">
# <main class="content-area" id="primary" role="main">
# <article class="post-102 page type-page status-publish hentry" id="post-102">
# <div class="entry-inner">
# <header class="entry-header">
# <h1 class="entry-title">퀴즈</h1> </header><!-- .entry-header -->
# <div class="entry-content">
# <div class="class_general_main" id="id_general_main">
# <h1> 메인 </h1>
# <a href="#"> 설문 준비중 </a>
# <p></p>
# </div>
# <div class="class_spark_quiz" id="id_spark_quiz">
# <h1>Spark 퀴즈 </h1>
# <a href="https://forms.gle/Fw49w9GhWQChDcZm7"> 6/13 Spark 심화과정 </a>
# <p></p>
# <a href="https://forms.gle/G4TcXm3fKuHLHA6D6"> 6/13 Spark 기본과정 </a>
# <p></p>
# <a href="https://forms.gle/M8gr1kC2ubA3UDVp8"> 6/18 Spark [MAP_FILTER] </a>
# <p></p>
# <a href="https://forms.gle/h8w5mZ4MNaPLCPbi6"> 6/18 Spark GroupBy 심화 </a>
# <p></p>
# <a href="https://forms.gle/q5yL6QHfueDLM5w27"> 6/25 Spark RDD 실전 분석 </a>
# <p></p>
# <a href="https://forms.gle/Gxb4y6LfVYiaLu4M7"> 6/27 Spark RDD 실전 분석2 </a>
# <p></p>
# </div>
# <div class="sharedaddy sd-like-enabled sd-sharing-enabled" id="jp-post-flair"><div class="sharedaddy sd-sharing-enabled"><div class="robots-nocontent sd-block sd-social sd-social-icon-text sd-sharing"><h3 class="sd-title">이 글 공유하기:</h3><div class="sd-content"><ul><li class="share-twitter"><a class="share-twitter sd-button share-icon" data-shared="sharing-twitter-102" href="https://sparkkorea.com/%ed%80%b4%ec%a6%88/?share=twitter" rel="nofollow noopener noreferrer" target="_blank" title="트위터로 공유하기"><span>트위터</span></a></li><li class="share-facebook"><a class="share-facebook sd-button share-icon" data-shared="sharing-facebook-102" href="https://sparkkorea.com/%ed%80%b4%ec%a6%88/?share=facebook" rel="nofollow noopener noreferrer" target="_blank" title="페이스북에 공유하려면 클릭하세요."><span>Facebook</span></a></li><li class="share-end"></li></ul></div></div></div><div class="sharedaddy sd-block sd-like jetpack-likes-widget-wrapper jetpack-likes-widget-unloaded" data-name="like-post-frame-163927570-102-60754201240cd" data-src="//widgets.wp.com/likes/index.html?ver=20210317#blog_id=163927570&amp;post_id=102&amp;origin=sparkkorea.wordpress.com&amp;obj_id=163927570-102-60754201240cd&amp;domain=sparkkorea.com" id="like-post-wrapper-163927570-102-60754201240cd"><h3 class="sd-title">이것이 좋아요:</h3><div class="likes-widget-placeholder post-likes-widget-placeholder" style="height: 55px;"><span class="button"><span>좋아하기</span></span> <span class="loading">가져오는 중...</span></div><span class="sd-text-color"></span><a class="sd-link-color"></a></div></div> </div><!-- .entry-content -->
# </div><!-- .entry-inner -->
# </article><!-- #post-## -->
# </main><!-- #main -->
# </div><!-- #content -->
# <footer class="site-footer" id="colophon" role="contentinfo">
# <div class="footer-bottom-info">
# <div class="site-info">
# <a href="https://wordpress.com/?ref=footer_segment_business" rel="nofollow">A WordPress.com Website.</a>
# </div><!-- .site-info -->
# </div><!-- .footer-bottom-info -->
# </footer><!-- #colophon -->
# </div><!-- .site-inner -->
# </div><!-- #page -->
# <!-- -->
# <script id="grofiles-cards-js" src="//0.gravatar.com/js/gprofiles.js?ver=202115y"></script>
# <script id="wpgroho-js-extra">
# var WPGroHo = {"my_hash":""};
# </script>
# <script src="https://s1.wp.com/wp-content/mu-plugins/gravatar-hovercards/wpgroho.js?m=1610363240h" type="text/javascript"></script>
# <script>
# 		// Initialize and attach hovercards to all gravatars
# 		( function() {
# 			function init() {
# 				if ( typeof Gravatar === 'undefined' ) {
# 					return;
# 				}
#
# 				if ( typeof Gravatar.init !== 'function' ) {
# 					return;
# 				}
#
# 				Gravatar.profile_cb = function ( hash, id ) {
# 					WPGroHo.syncProfileData( hash, id );
# 				};
#
# 				Gravatar.my_hash = WPGroHo.my_hash;
# 				Gravatar.init( 'body', '#wp-admin-bar-my-account' );
# 			}
#
# 			if ( document.readyState !== 'loading' ) {
# 				init();
# 			} else {
# 				document.addEventListener( 'DOMContentLoaded', init );
# 			}
# 		} )();
# 	</script>
# <div style="display:none">
# </div>
# <script>
# window.addEventListener( "load", function( event ) {
# 	var link = document.createElement( "link" );
# 	link.href = "https://s0.wp.com/wp-content/mu-plugins/actionbar/actionbar.css?v=20201002";
# 	link.type = "text/css";
# 	link.rel = "stylesheet";
# 	document.head.appendChild( link );
#
# 	var script = document.createElement( "script" );
# 	script.src = "https://s0.wp.com/wp-content/mu-plugins/actionbar/actionbar.js?v=20201002";
# 	script.defer = true;
# 	document.body.appendChild( script );
# } );
# </script>
# <script type="text/javascript">
# 		window.WPCOM_sharing_counts = {"https:\/\/sparkkorea.com\/%ed%80%b4%ec%a6%88\/":102};
# 	</script>
# <script id="comment-like-js-extra">
# var comment_like_text = {"loading":"\uac00\uc838\uc624\ub294 \uc911..."};
# </script>
# <script id="sharing-js-js-extra">
# var sharing_js_options = {"lang":"en","counts":"1","is_stats_active":"1"};
# </script>
# <script src="https://s2.wp.com/_static/??-" type="text/javascript"></script>
# <script type="text/javascript">
# var windowOpen;
# 			( function () {
# 				function matches( el, sel ) {
# 					return !! (
# 						el.matches && el.matches( sel ) ||
# 						el.msMatchesSelector && el.msMatchesSelector( sel )
# 					);
# 				}
#
# 				document.body.addEventListener( 'click', function ( event ) {
# 					if ( ! event.target ) {
# 						return;
# 					}
#
# 					var el;
# 					if ( matches( event.target, 'a.share-twitter' ) ) {
# 						el = event.target;
# 					} else if ( event.target.parentNode && matches( event.target.parentNode, 'a.share-twitter' ) ) {
# 						el = event.target.parentNode;
# 					}
#
# 					if ( el ) {
# 						event.preventDefault();
#
# 						// If there's another sharing window open, close it.
# 						if ( typeof windowOpen !== 'undefined' ) {
# 							windowOpen.close();
# 						}
# 						windowOpen = window.open( el.getAttribute( 'href' ), 'wpcomtwitter', 'menubar=1,resizable=1,width=600,height=350' );
# 						return false;
# 					}
# 				} );
# 			} )();
# var windowOpen;
# 			( function () {
# 				function matches( el, sel ) {
# 					return !! (
# 						el.matches && el.matches( sel ) ||
# 						el.msMatchesSelector && el.msMatchesSelector( sel )
# 					);
# 				}
#
# 				document.body.addEventListener( 'click', function ( event ) {
# 					if ( ! event.target ) {
# 						return;
# 					}
#
# 					var el;
# 					if ( matches( event.target, 'a.share-facebook' ) ) {
# 						el = event.target;
# 					} else if ( event.target.parentNode && matches( event.target.parentNode, 'a.share-facebook' ) ) {
# 						el = event.target.parentNode;
# 					}
#
# 					if ( el ) {
# 						event.preventDefault();
#
# 						// If there's another sharing window open, close it.
# 						if ( typeof windowOpen !== 'undefined' ) {
# 							windowOpen.close();
# 						}
# 						windowOpen = window.open( el.getAttribute( 'href' ), 'wpcomfacebook', 'menubar=1,resizable=1,width=600,height=400' );
# 						return false;
# 					}
# 				} );
# 			} )();
# </script>
# <script type="text/javascript">
# // <![CDATA[
# (function() {
# try{
#   if ( window.external &&'msIsSiteMode' in window.external) {
#     if (window.external.msIsSiteMode()) {
#       var jl = document.createElement('script');
#       jl.type='text/javascript';
#       jl.async=true;
#       jl.src='/wp-content/plugins/ie-sitemode/custom-jumplist.php';
#       var s = document.getElementsByTagName('script')[0];
#       s.parentNode.insertBefore(jl, s);
#     }
#   }
# }catch(e){}
# })();
# // ]]>
# </script> <iframe id="likes-master" name="likes-master" scrolling="no" src="https://widgets.wp.com/likes/master.html?ver=20210317#ver=20210317&amp;lang=ko&amp;origin=https://sparkkorea.com" style="display:none;"></iframe>
# <div id="likes-other-gravatars"><div class="likes-text"><span>%d</span> 블로거가 이것을 좋아합니다:</div><ul class="wpl-avatars sd-like-gravatars"></ul></div>
# <script defer="" src="//stats.wp.com/w.js?61"></script> <script type="text/javascript">
# _tkq = window._tkq || [];
# _stq = window._stq || [];
# _tkq.push(['storeContext', {'blog_id':'163927570','blog_tz':'9','user_lang':'ko','blog_lang':'ko','user_id':'0'}]);
# _stq.push(['view', {'blog':'163927570','v':'wpcom','tz':'9','user_id':'0','post':'102','subd':'sparkkorea'}]);
# _stq.push(['extra', {'crypt':''}]);
# _stq.push([ 'clickTrackerInit', '163927570', '102' ]);
# 	</script>
# <noscript><img alt="" src="https://pixel.wp.com/b.gif?v=noscript" style="height:1px;width:1px;overflow:hidden;position:absolute;bottom:1px;"/></noscript>
# <script>
# if ( 'object' === typeof wpcom_mobile_user_agent_info ) {
#
# 	wpcom_mobile_user_agent_info.init();
# 	var mobileStatsQueryString = "";
#
# 	if( false !== wpcom_mobile_user_agent_info.matchedPlatformName )
# 		mobileStatsQueryString += "&x_" + 'mobile_platforms' + '=' + wpcom_mobile_user_agent_info.matchedPlatformName;
#
# 	if( false !== wpcom_mobile_user_agent_info.matchedUserAgentName )
# 		mobileStatsQueryString += "&x_" + 'mobile_devices' + '=' + wpcom_mobile_user_agent_info.matchedUserAgentName;
#
# 	if( wpcom_mobile_user_agent_info.isIPad() )
# 		mobileStatsQueryString += "&x_" + 'ipad_views' + '=' + 'views';
#
# 	if( "" != mobileStatsQueryString ) {
# 		new Image().src = document.location.protocol + '//pixel.wp.com/g.gif?v=wpcom-no-pv' + mobileStatsQueryString + '&baba=' + Math.random();
# 	}
#
# }
# </script>
# </body>
# </html>

# %% [markdown]
# # 태그값 접근하기

# %%
targetParent = htmlObj.find(name="div", attrs = {"id":"id_spark_quiz"})
targetParent
# Out:
# <div class="class_spark_quiz" id="id_spark_quiz">
# <h1>Spark 퀴즈 </h1>
# <a href="https://forms.gle/Fw49w9GhWQChDcZm7"> 6/13 Spark 심화과정 </a>
# <p></p>
# <a href="https://forms.gle/G4TcXm3fKuHLHA6D6"> 6/13 Spark 기본과정 </a>
# <p></p>
# <a href="https://forms.gle/M8gr1kC2ubA3UDVp8"> 6/18 Spark [MAP_FILTER] </a>
# <p></p>
# <a href="https://forms.gle/h8w5mZ4MNaPLCPbi6"> 6/18 Spark GroupBy 심화 </a>
# <p></p>
# <a href="https://forms.gle/q5yL6QHfueDLM5w27"> 6/25 Spark RDD 실전 분석 </a>
# <p></p>
# <a href="https://forms.gle/Gxb4y6LfVYiaLu4M7"> 6/27 Spark RDD 실전 분석2 </a>
# <p></p>
# </div>

# %%
value = [] # 타이틀 값을 넣어줄 리스트
link = [] # 링크 값을 넣어줄 리스트
aTags = targetParent.findAll(name="a") # 태그 A로 시작하는 것을 모두 찾아줌


for i in range(0, len(aTags)):
    title = aTags[i].text     # A태그 안의 내용을 Title변수에 담음
    value.append(title)       # title변수를 value리스트에 추가함
    link2 = aTags[i].attrs["href"]  # A태그 안의 링크를 link2변숭 ㅔ담음
    link.append(link2)              # link2 변수를 link변수에 담음
    
pd.DataFrame(zip (value, link), columns=["퀴즈타이틀","링크"])  # zip을 사용하여 2가지 배열을 하나의 데이터프레임 형식으로 출력함
# Out:
#                        퀴즈타이틀                                   링크
# 0           6/13 Spark 심화과정   https://forms.gle/Fw49w9GhWQChDcZm7
# 1           6/13 Spark 기본과정   https://forms.gle/G4TcXm3fKuHLHA6D6
# 2   6/18 Spark [MAP_FILTER]   https://forms.gle/M8gr1kC2ubA3UDVp8
# 3     6/18 Spark GroupBy 심화   https://forms.gle/h8w5mZ4MNaPLCPbi6
# 4      6/25 Spark RDD 실전 분석   https://forms.gle/q5yL6QHfueDLM5w27
# 5     6/27 Spark RDD 실전 분석2   https://forms.gle/Gxb4y6LfVYiaLu4M7

# %%
value = []
link = []
aTags = targetParent.findAll(name="a")
aTags

for i in range(0, len(aTags)):
    aTags[i].text
# Out:
# [<a href="https://forms.gle/Fw49w9GhWQChDcZm7"> 6/13 Spark 심화과정 </a>,
#  <a href="https://forms.gle/G4TcXm3fKuHLHA6D6"> 6/13 Spark 기본과정 </a>,
#  <a href="https://forms.gle/M8gr1kC2ubA3UDVp8"> 6/18 Spark [MAP_FILTER] </a>,
#  <a href="https://forms.gle/h8w5mZ4MNaPLCPbi6"> 6/18 Spark GroupBy 심화 </a>,
#  <a href="https://forms.gle/q5yL6QHfueDLM5w27"> 6/25 Spark RDD 실전 분석 </a>,
#  <a href="https://forms.gle/Gxb4y6LfVYiaLu4M7"> 6/27 Spark RDD 실전 분석2 </a>]

# %% [markdown]
# # 테이블 스크랩

# %%
import requests, bs4
import pandas as pd

#웹페이지 html 소스 가져오기
resp = requests.get("https://sparkkorea.com/테스트/")
resp.encoding='utf-8'
html = resp.text
htmlObj = bs4.BeautifulSoup(html, 'html.parser')
htmlObj
# Out:
# <!DOCTYPE html>
#
# <html lang="ko-KR">
# <head>
# <meta charset="utf-8"/>
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <link href="http://gmpg.org/xfn/11" rel="profile"/>
# <link href="https://sparkkorea.com/xmlrpc.php" rel="pingback"/>
# <title>테스트 – 스파크 코리아</title>
# <meta content="max-image-preview:large" name="robots">
# <meta content="QRZVgHsoL23RuwmgmXNuXfO-mUaxCkdvhP2rRvLT270" name="google-site-verification">
# <!-- Async WordPress.com Remote Login -->
# <script id="wpcom_remote_login_js">
# var wpcom_remote_login_extra_auth = '';
# function wpcom_remote_login_remove_dom_node_id( element_id ) {
# 	var dom_node = document.getElementById( element_id );
# 	if ( dom_node ) { dom_node.parentNode.removeChild( dom_node ); }
# }
# function wpcom_remote_login_remove_dom_node_classes( class_name ) {
# 	var dom_nodes = document.querySelectorAll( '.' + class_name );
# 	for ( var i = 0; i < dom_nodes.length; i++ ) {
# 		dom_nodes[ i ].parentNode.removeChild( dom_nodes[ i ] );
# 	}
# }
# function wpcom_remote_login_final_cleanup() {
# 	wpcom_remote_login_remove_dom_node_classes( "wpcom_remote_login_msg" );
# 	wpcom_remote_login_remove_dom_node_id( "wpcom_remote_login_key" );
# 	wpcom_remote_login_remove_dom_node_id( "wpcom_remote_login_validate" );
# 	wpcom_remote_login_remove_dom_node_id( "wpcom_remote_login_js" );
# 	wpcom_remote_login_remove_dom_node_id( "wpcom_request_access_iframe" );
# 	wpcom_remote_login_remove_dom_node_id( "wpcom_request_access_styles" );
# }
#
# // Watch for messages back from the remote login
# window.addEventListener( "message", function( e ) {
# 	if ( e.origin === "https://r-login.wordpress.com" ) {
# 		var data = {};
# 		try {
# 			data = JSON.parse( e.data );
# 		} catch( e ) {
# 			wpcom_remote_login_final_cleanup();
# 			return;
# 		}
#
# 		if ( data.msg === 'LOGIN' ) {
# 			// Clean up the login check iframe
# 			wpcom_remote_login_remove_dom_node_id( "wpcom_remote_login_key" );
#
# 			var id_regex = new RegExp( /^[0-9]+$/ );
# 			var token_regex = new RegExp( /^.*|.*|.*$/ );
# 			if (
# 				token_regex.test( data.token )
# 				&& id_regex.test( data.wpcomid )
# 			) {
# 				// We have everything we need to ask for a login
# 				var script = document.createElement( "script" );
# 				script.setAttribute( "id", "wpcom_remote_login_validate" );
# 				script.src = '/remote-login.php?wpcom_remote_login=validate'
# 					+ '&wpcomid=' + data.wpcomid
# 					+ '&token=' + encodeURIComponent( data.token )
# 					+ '&host=' + window.location.protocol
# 						+ '//' + window.location.hostname;
# 				document.body.appendChild( script );
# 			}
#
# 			return;
# 		}
#
# 		// Safari ITP, not logged in, so redirect
# 		if ( data.msg === 'LOGIN-REDIRECT' ) {
# 			window.location = 'https://wordpress.com/log-in?redirect_to=' + window.location.href;
# 			return;
# 		}
#
# 		// Safari ITP, storage access failed, remove the request
# 		if ( data.msg === 'LOGIN-REMOVE' ) {
# 			var css_zap = 'html { -webkit-transition: margin-top 1s; transition: margin-top 1s; } /* 9001 */ html { margin-top: 0 !important; } * html body { margin-top: 0 !important; } @media screen and ( max-width: 782px ) { html { margin-top: 0 !important; } * html body { margin-top: 0 !important; } }';
# 			var style_zap = document.createElement( 'style' );
# 			style_zap.type = 'text/css';
# 			style_zap.appendChild( document.createTextNode( css_zap ) );
# 			document.body.appendChild( style_zap );
#
# 			var e = document.getElementById( 'wpcom_request_access_iframe' );
# 			e.parentNode.removeChild( e );
#
# 			document.cookie = 'wordpress_com_login_access=denied; path=/; max-age=31536000';
#
# 			return;
# 		}
#
# 		// Safari ITP
# 		if ( data.msg === 'REQUEST_ACCESS' ) {
# 			console.log( 'request access: safari' );
#
# 			// Check ITP iframe enable/disable knob
# 			if ( wpcom_remote_login_extra_auth !== 'safari_itp_iframe' ) {
# 				return;
# 			}
#
# 			// If we are in a "private window" there is no ITP.
# 			var private_window = false;
# 			try {
# 				var opendb = window.openDatabase( null, null, null, null );
# 			} catch( e ) {
# 				private_window = true;
# 			}
#
# 			if ( private_window ) {
# 				console.log( 'private window' );
# 				return;
# 			}
#
# 			var iframe = document.createElement( 'iframe' );
# 			iframe.id = 'wpcom_request_access_iframe';
# 			iframe.setAttribute( 'scrolling', 'no' );
# 			iframe.setAttribute( 'sandbox', 'allow-storage-access-by-user-activation allow-scripts allow-same-origin allow-top-navigation-by-user-activation' );
# 			iframe.src = 'https://r-login.wordpress.com/remote-login.php?wpcom_remote_login=request_access&origin=' + encodeURIComponent( data.origin ) + '&wpcomid=' + encodeURIComponent( data.wpcomid );
#
# 			var css = 'html { -webkit-transition: margin-top 1s; transition: margin-top 1s; } /* 9001 */ html { margin-top: 46px !important; } * html body { margin-top: 46px !important; } @media screen and ( max-width: 660px ) { html { margin-top: 71px !important; } * html body { margin-top: 71px !important; } #wpcom_request_access_iframe { display: block; height: 71px !important; } } #wpcom_request_access_iframe { border: 0px; height: 46px; position: fixed; top: 0; left: 0; width: 100%; min-width: 100%; z-index: 99999; background: #23282d; } ';
#
# 			var style = document.createElement( 'style' );
# 			style.type = 'text/css';
# 			style.id = 'wpcom_request_access_styles';
# 			style.appendChild( document.createTextNode( css ) );
# 			document.body.appendChild( style );
#
# 			document.body.appendChild( iframe );
# 		}
#
# 		if ( data.msg === 'DONE' ) {
# 			wpcom_remote_login_final_cleanup();
# 		}
# 	}
# }, false );
#
# // Inject the remote login iframe after the page has had a chance to load
# // more critical resources
# window.addEventListener( "DOMContentLoaded", function( e ) {
# 	var iframe = document.createElement( "iframe" );
# 	iframe.style.display = "none";
# 	iframe.setAttribute( "scrolling", "no" );
# 	iframe.setAttribute( "id", "wpcom_remote_login_key" );
# 	iframe.src = "https://r-login.wordpress.com/remote-login.php"
# 		+ "?wpcom_remote_login=key"
# 		+ "&origin=aHR0cHM6Ly9zcGFya2tvcmVhLmNvbQ%3D%3D"
# 		+ "&wpcomid=163927570"
# 		+ "&time=1618303280";
# 	document.body.appendChild( iframe );
# }, false );
# </script>
# <link href="//s2.wp.com" rel="dns-prefetch">
# <link href="//sparkkorea.wordpress.com" rel="dns-prefetch">
# <link href="//s0.wp.com" rel="dns-prefetch"/>
# <link href="//wordpress.com" rel="dns-prefetch"/>
# <link href="//fonts.googleapis.com" rel="dns-prefetch"/>
# <link href="https://sparkkorea.com/feed/" rel="alternate" title="스파크 코리아 » 피드" type="application/rss+xml"/>
# <link href="https://sparkkorea.com/comments/feed/" rel="alternate" title="스파크 코리아 » 댓글 피드" type="application/rss+xml"/>
# <script type="text/javascript">
# 		/* <![CDATA[ */
# 		function addLoadEvent(func) {
# 			var oldonload = window.onload;
# 			if (typeof window.onload != 'function') {
# 				window.onload = func;
# 			} else {
# 				window.onload = function () {
# 					oldonload();
# 					func();
# 				}
# 			}
# 		}
# 		/* ]]> */
# 	</script>
# <script type="text/javascript">
# 			window._wpemojiSettings = {"baseUrl":"https:\/\/s0.wp.com\/wp-content\/mu-plugins\/wpcom-smileys\/twemoji\/2\/72x72\/","ext":".png","svgUrl":"https:\/\/s0.wp.com\/wp-content\/mu-plugins\/wpcom-smileys\/twemoji\/2\/svg\/","svgExt":".svg","source":{"concatemoji":"https:\/\/s0.wp.com\/wp-includes\/js\/wp-emoji-release.min.js?m=1612197847h&ver=5.7.1-RC1-50691"}};
# 			!function(e,a,t){var n,r,o,i=a.createElement("canvas"),p=i.getContext&&i.getContext("2d");function s(e,t){var a=String.fromCharCode;p.clearRect(0,0,i.width,i.height),p.fillText(a.apply(this,e),0,0);e=i.toDataURL();return p.clearRect(0,0,i.width,i.height),p.fillText(a.apply(this,t),0,0),e===i.toDataURL()}function c(e){var t=a.createElement("script");t.src=e,t.defer=t.type="text/javascript",a.getElementsByTagName("head")[0].appendChild(t)}for(o=Array("flag","emoji"),t.supports={everything:!0,everythingExceptFlag:!0},r=0;r<o.length;r++)t.supports[o[r]]=function(e){if(!p||!p.fillText)return!1;switch(p.textBaseline="top",p.font="600 32px Arial",e){case"flag":return s([127987,65039,8205,9895,65039],[127987,65039,8203,9895,65039])?!1:!s([55356,56826,55356,56819],[55356,56826,8203,55356,56819])&&!s([55356,57332,56128,56423,56128,56418,56128,56421,56128,56430,56128,56423,56128,56447],[55356,57332,8203,56128,56423,8203,56128,56418,8203,56128,56421,8203,56128,56430,8203,56128,56423,8203,56128,56447]);case"emoji":return!s([55357,56424,8205,55356,57212],[55357,56424,8203,55356,57212])}return!1}(o[r]),t.supports.everything=t.supports.everything&&t.supports[o[r]],"flag"!==o[r]&&(t.supports.everythingExceptFlag=t.supports.everythingExceptFlag&&t.supports[o[r]]);t.supports.everythingExceptFlag=t.supports.everythingExceptFlag&&!t.supports.flag,t.DOMReady=!1,t.readyCallback=function(){t.DOMReady=!0},t.supports.everything||(n=function(){t.readyCallback()},a.addEventListener?(a.addEventListener("DOMContentLoaded",n,!1),e.addEventListener("load",n,!1)):(e.attachEvent("onload",n),a.attachEvent("onreadystatechange",function(){"complete"===a.readyState&&t.readyCallback()})),(n=t.source||{}).concatemoji?c(n.concatemoji):n.wpemoji&&n.twemoji&&(c(n.twemoji),c(n.wpemoji)))}(window,document,window._wpemojiSettings);
# 		</script>
# <style type="text/css">
# img.wp-smiley,
# img.emoji {
# 	display: inline !important;
# 	border: none !important;
# 	box-shadow: none !important;
# 	height: 1em !important;
# 	width: 1em !important;
# 	margin: 0 .07em !important;
# 	vertical-align: -0.1em !important;
# 	background: none !important;
# 	padding: 0 !important;
# }
# </style>
# <link href="https://s1.wp.com/_static/??-?cssminify=yes" id="all-css-0-1" media="all" rel="stylesheet" type="text/css"/>
# <style id="wp-block-library-inline-css">
# .has-text-align-justify {
# 	text-align:justify;
# }
# </style>
# <link crossorigin="anonymous" href="https://fonts.googleapis.com/css?family=Lato%3A400%2C400italic%2C700%2C700italic%7CNoto+Serif%3A400%2C400italic%2C700%2C700italic&amp;subset=latin%2Clatin-ext" id="dyad-2-fonts-css" media="all" rel="stylesheet"/>
# <link href="https://s0.wp.com/_static/??-eJyNj80OgjAQhF/IdSkkxovxWUpZa7XdNv0J4e2pcFBiNNxmsvNNZnEMoDxn4oyuQLBFG06oiSmaevghjyqlA36w+U6OEobS4zDJAVpMebK0I1cT2FuvnntKDau1GMagvPsiNi94qLUyG88bAzcrTfyHRqqDdJV6Wfe2L+jqLuLUdOIsurZ5zCp8dh4=?cssminify=yes" id="all-css-2-1" media="all" rel="stylesheet" type="text/css"/>
# <link href="https://s2.wp.com/wp-content/mu-plugins/global-print/global-print.css?m=1465851035h&amp;cssminify=yes" id="print-css-3-1" media="print" rel="stylesheet" type="text/css"/>
# <style id="jetpack-global-styles-frontend-style-inline-css">
# :root { --font-headings: unset; --font-base: unset; --font-headings-default: -apple-system,BlinkMacSystemFont,"Segoe UI",Roboto,Oxygen-Sans,Ubuntu,Cantarell,"Helvetica Neue",sans-serif; --font-base-default: -apple-system,BlinkMacSystemFont,"Segoe UI",Roboto,Oxygen-Sans,Ubuntu,Cantarell,"Helvetica Neue",sans-serif;}
# </style>
# <link href="https://s1.wp.com/_static/??-eJxti0EKgCAQAD+ULUaJl+gtJqbG6opr9P3o0CHqNAzMwFmEpdxcbpAOUfDwMTMU4iY2NLECB1Nj9g97y9zB/8Vko0GB5Oktn6kFlxxDGMEjrQbvYEmzVHIclNZy2i9lFDfR?cssminify=yes" id="all-css-6-1" media="all" rel="stylesheet" type="text/css"/>
# <script id="wpcom-actionbar-placeholder-js-extra">
# var actionbardata = {"siteID":"163927570","siteName":"\uc2a4\ud30c\ud06c \ucf54\ub9ac\uc544","siteURL":"https:\/\/sparkkorea.com","icon":"<img alt='' src='https:\/\/s2.wp.com\/i\/logo\/wpcom-gray-white.png' class='avatar avatar-50' height='50' width='50' \/>","canManageOptions":"","canCustomizeSite":"","isFollowing":"","themeSlug":"pub\/dyad-2","signupURL":"https:\/\/wordpress.com\/start\/","loginURL":"https:\/\/wordpress.com\/log-in?redirect_to=https%3A%2F%2Fsparkkorea.com%2F%ED%85%8C%EC%8A%A4%ED%8A%B8%2F&signup_flow=account&domain=sparkkorea.com","themeURL":"https:\/\/wordpress.com\/theme\/dyad-2\/","xhrURL":"https:\/\/sparkkorea.com\/wp-admin\/admin-ajax.php","nonce":"e8f65ee91c","isSingular":"1","isFolded":"","isLoggedIn":"","isMobile":"","subscribeNonce":"<input type=\"hidden\" id=\"_wpnonce\" name=\"_wpnonce\" value=\"14dc55fb7b\" \/>","referer":"https:\/\/sparkkorea.com\/%ED%85%8C%EC%8A%A4%ED%8A%B8\/","canFollow":"","feedID":"97558616","statusMessage":"","customizeLink":"https:\/\/sparkkorea.wordpress.com\/wp-admin\/customize.php?url=https%3A%2F%2Fsparkkorea.wordpress.com%2F%25ED%2585%258C%25EC%258A%25A4%25ED%258A%25B8%2F","postID":"114","shortlink":"https:\/\/wp.me\/Pb5P34-1Q","canEditPost":"","editLink":"https:\/\/wordpress.com\/page\/sparkkorea.com\/114","statsLink":"https:\/\/wordpress.com\/stats\/post\/114\/sparkkorea.com","i18n":{"view":"\uc0ac\uc774\ud2b8 \ubcf4\uae30","follow":"\ud314\ub85c\uc6b0","following":"\ud314\ub85c\uc6b0\uc911","edit":"\ud3b8\uc9d1","login":"\ub85c\uadf8\uc778","signup":"\uac00\uc785","customize":"\uc0ac\uc6a9\uc790 \uc815\uc758\ud558\uae30","report":"\uc774 \ucf58\ud150\uce20 \uc2e0\uace0\ud558\uae30","themeInfo":"\ud14c\ub9c8 \uac00\uc838\uc624\uae30: Dyad 2","shortlink":"\ub2e8\ucd95 \ub9c1\ud06c \ubcf5\uc0ac","copied":"\ubcf5\uc0ac\ub428","followedText":"\uc774 \uc0ac\uc774\ud2b8\uc758 \uc0c8 \uae00\uc774 \uc774\uc81c <a href=\"https:\/\/wordpress.com\/\">\ub274\uc2a4\ud53c\ub4dc<\/a>\uc5d0 \ud45c\uc2dc\ub429\ub2c8\ub2e4.","foldBar":"\uc774 \ud45c\uc2dc\uc904 \ucd95\uc18c","unfoldBar":"\uc774 \ud45c\uc2dc\uc904 \ud655\uc7a5","editSubs":"\uad6c\ub3c5 \uad00\ub9ac","viewReader":"\ub9ac\ub354\uc5d0\uc11c \uc0ac\uc774\ud2b8 \ubcf4\uae30","viewReadPost":"View post in Reader","subscribe":"\uac00\uc785\ud558\uae30","enterEmail":"\uc774\uba54\uc77c \uc8fc\uc18c \uc785\ub825","followers":"","alreadyUser":"\uc774\ubbf8 \uc6cc\ub4dc\ud504\ub808\uc2a4\ub2f7\ucef4 \uacc4\uc815\uc744 \uac16\uace0 \uacc4\uc138\uc694? <a href=\"https:\/\/wordpress.com\/log-in?redirect_to=https%3A%2F%2Fsparkkorea.com%2F%ED%85%8C%EC%8A%A4%ED%8A%B8%2F&signup_flow=account&domain=sparkkorea.com\">\uc9c0\uae08 \ub85c\uadf8\uc778\ud558\uc138\uc694.<\/a>","stats":"\ud1b5\uacc4"}};
# </script>
# <script src="https://s2.wp.com/_static/??-eJyFzUEKwkAMheELmQ5DocWFeJZaY8kwyYxJBu3traBQV67e4v/ghUeFuYijeEgWajFnNJsW7JIdwm/lcqGM0Ax1A+JAcitfRzLndkV7w3RvqOtnOib5i4Bp0clxj3fPmh2qlue6tTOf4hDHPvbDeEwvhOVG7A==" type="text/javascript"></script>
# <script type="text/javascript">
# 	window.addEventListener( 'DOMContentLoaded', function() {
# 		rltInitialize( {"token":null,"iframeOrigins":["https:\/\/widgets.wp.com"]} );
# 	} );
# </script>
# <link href="https://sparkkorea.wordpress.com/xmlrpc.php?rsd" rel="EditURI" title="RSD" type="application/rsd+xml"/>
# <link href="https://s1.wp.com/wp-includes/wlwmanifest.xml" rel="wlwmanifest" type="application/wlwmanifest+xml"/>
# <meta content="WordPress.com" name="generator"/>
# <link href="https://sparkkorea.com/%ed%85%8c%ec%8a%a4%ed%8a%b8/" rel="canonical"/>
# <link href="https://wp.me/Pb5P34-1Q" rel="shortlink"/>
# <link href="https://public-api.wordpress.com/oembed/?format=json&amp;url=https%3A%2F%2Fsparkkorea.com%2F%25ed%2585%258c%25ec%258a%25a4%25ed%258a%25b8%2F&amp;for=wpcom-auto-discovery" rel="alternate" type="application/json+oembed"/><link href="https://public-api.wordpress.com/oembed/?format=xml&amp;url=https%3A%2F%2Fsparkkorea.com%2F%25ed%2585%258c%25ec%258a%25a4%25ed%258a%25b8%2F&amp;for=wpcom-auto-discovery" rel="alternate" type="application/xml+oembed"/>
# <!-- Jetpack Open Graph Tags -->
# <meta content="article" property="og:type"/>
# <meta content="테스트" property="og:title"/>
# <meta content="https://sparkkorea.com/%ed%85%8c%ec%8a%a4%ed%8a%b8/" property="og:url"/>
# <meta content="학번 이름 101 김효관 102 이순신 103 김어진" property="og:description"/>
# <meta content="2019-07-11T12:47:37+00:00" property="article:published_time"/>
# <meta content="2019-07-11T13:33:47+00:00" property="article:modified_time"/>
# <meta content="스파크 코리아" property="og:site_name"/>
# <meta content="https://s0.wp.com/i/blank.jpg" property="og:image"/>
# <meta content="ko_KR" property="og:locale"/>
# <meta content="@wordpressdotcom" name="twitter:site"/>
# <meta content="테스트" name="twitter:text:title"/>
# <meta content="summary" name="twitter:card"/>
# <meta content="https://www.facebook.com/WordPresscom" property="article:publisher"/>
# <!-- End Jetpack Open Graph Tags -->
# <link href="https://s1.wp.com/i/favicon.ico" rel="shortcut icon" sizes="16x16 24x24 32x32 48x48" type="image/x-icon"/>
# <link href="https://s1.wp.com/i/favicon.ico" rel="icon" sizes="16x16 24x24 32x32 48x48" type="image/x-icon"/>
# <link href="https://s2.wp.com/i/webclip.png" rel="apple-touch-icon"/>
# <link href="https://sparkkorea.com/osd.xml" rel="search" title="스파크 코리아" type="application/opensearchdescription+xml"/>
# <link href="https://s1.wp.com/opensearch.xml" rel="search" title="WordPress.com" type="application/opensearchdescription+xml"/>
# <meta content="스파크 코리아" name="application-name"/><meta content="width=device-width;height=device-height" name="msapplication-window"/><meta content="스파크코리아 자료공유" name="msapplication-tooltip"/><meta content="name=구독;action-uri=https://sparkkorea.com/feed/;icon-uri=https://s1.wp.com/i/favicon.ico" name="msapplication-task"/><meta content="name=무료 블로그 등록;action-uri=http://wordpress.com/signup/;icon-uri=https://s1.wp.com/i/favicon.ico" name="msapplication-task"/><meta content="name=WordPress.com 지원;action-uri=http://support.wordpress.com/;icon-uri=https://s1.wp.com/i/favicon.ico" name="msapplication-task"/><meta content="name=WordPress.com 포럼;action-uri=http://forums.wordpress.com/;icon-uri=https://s1.wp.com/i/favicon.ico" name="msapplication-task"/><meta content="학번 이름 101 김효관 102 이순신 103 김어진" name="description"/>
# </link></link></meta></meta></head>
# <body class="page-template-default page page-id-114 wp-embed-responsive customizer-styles-applied is-singular no-js highlander-enabled highlander-light">
# <div class="hfeed site" id="page">
# <a class="skip-link screen-reader-text" href="#content">컨텐츠로 건너뛰기</a>
# <header class="site-header" id="masthead" role="banner">
# <div class="site-branding">
# <h1 class="site-title">
# <a href="https://sparkkorea.com/" rel="home">
# 					스파크 코리아				</a>
# </h1>
# <p class="site-description">스파크코리아 자료공유</p>
# </div><!-- .site-branding -->
# <nav class="main-navigation" id="site-navigation" role="navigation">
# <button aria-controls="primary-menu" aria-expanded="false" class="menu-toggle">메뉴</button>
# <div class="primary-menu"><ul class="menu" id="primary-menu"><li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-27" id="menu-item-27"><a href="https://sparkkorea.com/%ec%9e%90%eb%a3%8c%ec%8b%a4/">자료실</a></li>
# <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-264" id="menu-item-264"><a href="https://sparkkorea.com/%ec%84%a4%eb%ac%b8-2/">설문s</a></li>
# <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-382" id="menu-item-382"><a href="https://sparkkorea.com/%ed%80%b4%ec%a6%88/">퀴즈</a></li>
# <li class="menu-item menu-item-type-post_type menu-item-object-page current-menu-item page_item page-item-114 current_page_item menu-item-383" id="menu-item-383"><a aria-current="page" href="https://sparkkorea.com/%ed%85%8c%ec%8a%a4%ed%8a%b8/">테스트</a></li>
# <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-397" id="menu-item-397"><a href="https://sparkkorea.com/%ec%84%a4%eb%ac%b8/">학생퀴즈</a></li>
# </ul></div> </nav>
# </header><!-- #masthead -->
# <div class="site-inner">
# <div class="site-content" id="content">
# <main class="content-area" id="primary" role="main">
# <article class="post-114 page type-page status-publish hentry" id="post-114">
# <div class="entry-inner">
# <header class="entry-header">
# <h1 class="entry-title">테스트</h1> </header><!-- .entry-header -->
# <div class="entry-content">
# <table class="type07" id="test_table">
# <thead>
# <tr>
# <th scope="cols">학번</th>
# <th scope="cols">이름</th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <td>101</td>
# <td>김효관</td>
# </tr>
# <tr>
# <td>102</td>
# <td>이순신</td>
# </tr>
# <tr>
# <td>103</td>
# <td>김어진</td>
# </tr>
# </tbody>
# </table>
# <p></p>
# <div class="sharedaddy sd-like-enabled sd-sharing-enabled" id="jp-post-flair"><div class="sharedaddy sd-sharing-enabled"><div class="robots-nocontent sd-block sd-social sd-social-icon-text sd-sharing"><h3 class="sd-title">이 글 공유하기:</h3><div class="sd-content"><ul><li class="share-twitter"><a class="share-twitter sd-button share-icon" data-shared="sharing-twitter-114" href="https://sparkkorea.com/%ed%85%8c%ec%8a%a4%ed%8a%b8/?share=twitter" rel="nofollow noopener noreferrer" target="_blank" title="트위터로 공유하기"><span>트위터</span></a></li><li class="share-facebook"><a class="share-facebook sd-button share-icon" data-shared="sharing-facebook-114" href="https://sparkkorea.com/%ed%85%8c%ec%8a%a4%ed%8a%b8/?share=facebook" rel="nofollow noopener noreferrer" target="_blank" title="페이스북에 공유하려면 클릭하세요."><span>Facebook</span></a></li><li class="share-end"></li></ul></div></div></div><div class="sharedaddy sd-block sd-like jetpack-likes-widget-wrapper jetpack-likes-widget-unloaded" data-name="like-post-frame-163927570-114-607559303b803" data-src="//widgets.wp.com/likes/index.html?ver=20210317#blog_id=163927570&amp;post_id=114&amp;origin=sparkkorea.wordpress.com&amp;obj_id=163927570-114-607559303b803&amp;domain=sparkkorea.com" id="like-post-wrapper-163927570-114-607559303b803"><h3 class="sd-title">이것이 좋아요:</h3><div class="likes-widget-placeholder post-likes-widget-placeholder" style="height: 55px;"><span class="button"><span>좋아하기</span></span> <span class="loading">가져오는 중...</span></div><span class="sd-text-color"></span><a class="sd-link-color"></a></div></div> </div><!-- .entry-content -->
# </div><!-- .entry-inner -->
# </article><!-- #post-## -->
# </main><!-- #main -->
# </div><!-- #content -->
# <footer class="site-footer" id="colophon" role="contentinfo">
# <div class="footer-bottom-info">
# <div class="site-info">
# <a href="https://wordpress.com/?ref=footer_segment_business" rel="nofollow">A WordPress.com Website.</a>
# </div><!-- .site-info -->
# </div><!-- .footer-bottom-info -->
# </footer><!-- #colophon -->
# </div><!-- .site-inner -->
# </div><!-- #page -->
# <!-- -->
# <script id="grofiles-cards-js" src="//0.gravatar.com/js/gprofiles.js?ver=202115y"></script>
# <script id="wpgroho-js-extra">
# var WPGroHo = {"my_hash":""};
# </script>
# <script src="https://s1.wp.com/wp-content/mu-plugins/gravatar-hovercards/wpgroho.js?m=1610363240h" type="text/javascript"></script>
# <script>
# 		// Initialize and attach hovercards to all gravatars
# 		( function() {
# 			function init() {
# 				if ( typeof Gravatar === 'undefined' ) {
# 					return;
# 				}
#
# 				if ( typeof Gravatar.init !== 'function' ) {
# 					return;
# 				}
#
# 				Gravatar.profile_cb = function ( hash, id ) {
# 					WPGroHo.syncProfileData( hash, id );
# 				};
#
# 				Gravatar.my_hash = WPGroHo.my_hash;
# 				Gravatar.init( 'body', '#wp-admin-bar-my-account' );
# 			}
#
# 			if ( document.readyState !== 'loading' ) {
# 				init();
# 			} else {
# 				document.addEventListener( 'DOMContentLoaded', init );
# 			}
# 		} )();
# 	</script>
# <div style="display:none">
# </div>
# <script>
# window.addEventListener( "load", function( event ) {
# 	var link = document.createElement( "link" );
# 	link.href = "https://s0.wp.com/wp-content/mu-plugins/actionbar/actionbar.css?v=20201002";
# 	link.type = "text/css";
# 	link.rel = "stylesheet";
# 	document.head.appendChild( link );
#
# 	var script = document.createElement( "script" );
# 	script.src = "https://s0.wp.com/wp-content/mu-plugins/actionbar/actionbar.js?v=20201002";
# 	script.defer = true;
# 	document.body.appendChild( script );
# } );
# </script>
# <script type="text/javascript">
# 		window.WPCOM_sharing_counts = {"https:\/\/sparkkorea.com\/%ed%85%8c%ec%8a%a4%ed%8a%b8\/":114};
# 	</script>
# <script id="comment-like-js-extra">
# var comment_like_text = {"loading":"\uac00\uc838\uc624\ub294 \uc911..."};
# </script>
# <script id="sharing-js-js-extra">
# var sharing_js_options = {"lang":"en","counts":"1","is_stats_active":"1"};
# </script>
# <script src="https://s2.wp.com/_static/??-" type="text/javascript"></script>
# <script type="text/javascript">
# var windowOpen;
# 			( function () {
# 				function matches( el, sel ) {
# 					return !! (
# 						el.matches && el.matches( sel ) ||
# 						el.msMatchesSelector && el.msMatchesSelector( sel )
# 					);
# 				}
#
# 				document.body.addEventListener( 'click', function ( event ) {
# 					if ( ! event.target ) {
# 						return;
# 					}
#
# 					var el;
# 					if ( matches( event.target, 'a.share-twitter' ) ) {
# 						el = event.target;
# 					} else if ( event.target.parentNode && matches( event.target.parentNode, 'a.share-twitter' ) ) {
# 						el = event.target.parentNode;
# 					}
#
# 					if ( el ) {
# 						event.preventDefault();
#
# 						// If there's another sharing window open, close it.
# 						if ( typeof windowOpen !== 'undefined' ) {
# 							windowOpen.close();
# 						}
# 						windowOpen = window.open( el.getAttribute( 'href' ), 'wpcomtwitter', 'menubar=1,resizable=1,width=600,height=350' );
# 						return false;
# 					}
# 				} );
# 			} )();
# var windowOpen;
# 			( function () {
# 				function matches( el, sel ) {
# 					return !! (
# 						el.matches && el.matches( sel ) ||
# 						el.msMatchesSelector && el.msMatchesSelector( sel )
# 					);
# 				}
#
# 				document.body.addEventListener( 'click', function ( event ) {
# 					if ( ! event.target ) {
# 						return;
# 					}
#
# 					var el;
# 					if ( matches( event.target, 'a.share-facebook' ) ) {
# 						el = event.target;
# 					} else if ( event.target.parentNode && matches( event.target.parentNode, 'a.share-facebook' ) ) {
# 						el = event.target.parentNode;
# 					}
#
# 					if ( el ) {
# 						event.preventDefault();
#
# 						// If there's another sharing window open, close it.
# 						if ( typeof windowOpen !== 'undefined' ) {
# 							windowOpen.close();
# 						}
# 						windowOpen = window.open( el.getAttribute( 'href' ), 'wpcomfacebook', 'menubar=1,resizable=1,width=600,height=400' );
# 						return false;
# 					}
# 				} );
# 			} )();
# </script>
# <script type="text/javascript">
# // <![CDATA[
# (function() {
# try{
#   if ( window.external &&'msIsSiteMode' in window.external) {
#     if (window.external.msIsSiteMode()) {
#       var jl = document.createElement('script');
#       jl.type='text/javascript';
#       jl.async=true;
#       jl.src='/wp-content/plugins/ie-sitemode/custom-jumplist.php';
#       var s = document.getElementsByTagName('script')[0];
#       s.parentNode.insertBefore(jl, s);
#     }
#   }
# }catch(e){}
# })();
# // ]]>
# </script> <iframe id="likes-master" name="likes-master" scrolling="no" src="https://widgets.wp.com/likes/master.html?ver=20210317#ver=20210317&amp;lang=ko&amp;origin=https://sparkkorea.com" style="display:none;"></iframe>
# <div id="likes-other-gravatars"><div class="likes-text"><span>%d</span> 블로거가 이것을 좋아합니다:</div><ul class="wpl-avatars sd-like-gravatars"></ul></div>
# <script defer="" src="//stats.wp.com/w.js?61"></script> <script type="text/javascript">
# _tkq = window._tkq || [];
# _stq = window._stq || [];
# _tkq.push(['storeContext', {'blog_id':'163927570','blog_tz':'9','user_lang':'ko','blog_lang':'ko','user_id':'0'}]);
# _stq.push(['view', {'blog':'163927570','v':'wpcom','tz':'9','user_id':'0','post':'114','subd':'sparkkorea'}]);
# _stq.push(['extra', {'crypt':''}]);
# _stq.push([ 'clickTrackerInit', '163927570', '114' ]);
# 	</script>
# <noscript><img alt="" src="https://pixel.wp.com/b.gif?v=noscript" style="height:1px;width:1px;overflow:hidden;position:absolute;bottom:1px;"/></noscript>
# <script>
# if ( 'object' === typeof wpcom_mobile_user_agent_info ) {
#
# 	wpcom_mobile_user_agent_info.init();
# 	var mobileStatsQueryString = "";
#
# 	if( false !== wpcom_mobile_user_agent_info.matchedPlatformName )
# 		mobileStatsQueryString += "&x_" + 'mobile_platforms' + '=' + wpcom_mobile_user_agent_info.matchedPlatformName;
#
# 	if( false !== wpcom_mobile_user_agent_info.matchedUserAgentName )
# 		mobileStatsQueryString += "&x_" + 'mobile_devices' + '=' + wpcom_mobile_user_agent_info.matchedUserAgentName;
#
# 	if( wpcom_mobile_user_agent_info.isIPad() )
# 		mobileStatsQueryString += "&x_" + 'ipad_views' + '=' + 'views';
#
# 	if( "" != mobileStatsQueryString ) {
# 		new Image().src = document.location.protocol + '//pixel.wp.com/g.gif?v=wpcom-no-pv' + mobileStatsQueryString + '&baba=' + Math.random();
# 	}
#
# }
# </script>
# </body>
# </html>

# %%
columnList = []
rowList = []
tableTag = htmlObj.find(name="table", attrs={"id":"test_table"})
tbodyTag = tableTag.find(name="tbody")
trs = tbodyTag.find_all(name="tr")
for i in range(0, len(trs)):
    
    eachTr = trs[i]
    tds = eachTr.find_all("td")
    
    for j in range(0, len(tds)):
        td = tds[j].text
        
        
        columnList.append(td)
    rowList.append(columnList)
    columnList = []
table = pd.DataFrame(rowList, columns=["학번","이름"])
table
# Out:
#     학번   이름
# 0  101  김효관
# 1  102  이순신
# 2  103  김어진

# %%
from bs4 import BeautifulSoup # 태그를 이쁘게 쓰게해준다
import requests # 웹페이지에 접속요청

# %%
url = "https://www.alpha.co.kr/product/productList.do?categoryCode=001002010002010"
headers = {'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10.14; rv:71.0) Gecko/20100101 Firefox/71.0'}
data=requests.get(url,headers=headers)
data.text
resp = requests.get(url)
resp.encoding = 'utf-8'

# %%
html = resp.text

htmlObj = BeautifulSoup(html, "html.parser")
htmlObj
# Out:
# <!DOCTYPE html>
#
# <html class="no-js" lang="ko">
# <head>
# <meta charset="utf-8"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="kr" http-equiv="content-language">
# <meta content="no" http-equiv="imagetoolbar">
# <meta content="9cec591ce4928523c417a3f85fac520ac3aaba8c" name="naver-site-verification"/>
# <title>문구는 ART다! 알파본사공식 쇼핑몰</title>
# <meta content="문구는 ART다! 알파본사공식 쇼핑몰" name="title"/>
# <meta content="본사공식쇼핑몰,랭키닷컴1위,문구,사무용품,미술화방,최다상품보유,기업할인,후불결제,ok캐쉬백,상품권결제" name="description"/>
# <meta content="문구 ArtMall" name="copyright"/>
# <meta content="width=1440" name="viewport"/>
# <meta content="331039979d96e0ce500f0e2771a74e12f28a9a3f" name="naver-site-verification"/>
# <meta content="9uHjIClZWIOsnQd9o3-cEWl0AvU61QTX5ncMAzNRdvs" name="google-site-verification"/>
# <meta content="UCMTbh3yN7YIiKYH73h9QtRh59_CMzHmG2Mi_9aJKeY" name="google-site-verification"/>
# <meta content="https://www.alpha.co.kr/image/plan/alpha.jpg" property="og:image"/>
# <meta content="문구는 ART다! 알파본사공식 쇼핑몰" property="og:title"/>
# <meta content="본사공식쇼핑몰,랭키닷컴1위,문구,사무용품,미술화방,최다상품보유,기업할인,후불결제,ok캐쉬백,상품권결제" property="og:description"/>
# <link href="https://www.alpha.co.kr" rel="author"/>
# <link href="https://epasscni.com" rel="publisher"/>
# <link href="https://www.alpha.co.kr/image/plan/mobile_icon.png" rel="apple-touch-icon-precomposed"/>
# <link href="https://www.alpha.co.kr/image/plan/mobile_icon.png" rel="shortcut icon"/>
# <script>document.documentElement.className = document.documentElement.className.replace('no-js', 'js');</script>
# <link href="/common/css/normalize-3.0.2.css" rel="stylesheet"/>
# <!-- <link rel="stylesheet" href="/common/css/epass.base-0.1.css" /> -->
# <link href="/common/css/style.css" rel="stylesheet"/><!-- less compiled -->
# <link href="/common/css/additional.css" rel="stylesheet"/><!-- additional -->
# <link href="/common/css/main.css" rel="stylesheet"/><!-- mainpage custom -->
# <script src="/common/js/vendor/modernizr.custom.2.8.3.min.js"></script>
# <script src="https://vtag19.midas-i.com/vat-tag?cmp_no=3069&amp;depth=1"></script>
# <script src="https://ajax.googleapis.com/ajax/libs/jquery/1.9.0/jquery.min.js"></script>
# <link crossorigin="anonymous" href="https://use.fontawesome.com/releases/v5.6.3/css/all.css" integrity="sha384-UHRtZLI+pbxtHCWp1t77Bi1L4ZtiqrqD80Kn4Z8NTSRyMA2Fd33n5dQ8lWUE00s/" rel="stylesheet"/>
# <script charset="UTF-8" src="https://pay.naver.com/customer/js/naverPayButton.js" type="text/javascript"></script>
# <script src="/common/js/naver.js"></script>
# <script src="https://wcs.naver.net/wcslog.js" type="text/javascript"> </script>
# <script type="text/javascript">
# if (!wcs_add) var wcs_add={};
# wcs_add["wa"] = "s_15f44a07ae08";
# wcs.inflow("alpha.co.kr");
# wcs_do();
# </script>
# <script>
# // google analytics
# (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
# (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
# m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
# })(window,document,'script','//www.google-analytics.com/analytics.js','ga');
#
# ga('create', 'UA-6690877-1', 'auto');
# ga('send', 'pageview');
# </script>
# <!-- Global site tag (gtag.js) - Google Analytics -->
# <script async="" src="https://www.googletagmanager.com/gtag/js?id=UA-113563662-1"></script>
# <script>
#   window.dataLayer = window.dataLayer || [];
#   function gtag(){dataLayer.push(arguments);}
#   gtag('js', new Date());
#
#   gtag('config', 'UA-113563662-1');
# </script>
# <!--[if (gte IE 6)&(lte IE 8)]>
#     <script src="/common/js/vendor/jquery-1.11.2.min.js"></script>
# <![endif]-->
# <!--[if (gt IE 8)|!(IE)]> <!--> <script src="/common/js/vendor/jquery-2.1.3.min.js"></script> <!--<![endif]-->
# <script>
# var _jQueryUrl = (location.protocol == 'https:') ? 'https://ajax.googleapis.com/ajax/libs/jquery/1.11.2/jquery.min.js' : 'http://ajax.googleapis.com/ajax/libs/jquery/1.11.2/jquery.min.js';
# window.jQuery || document.write('<script src="' + _jQueryUrl + '"><\/script>')
# </script>
# <style type="text/css">
# <!--
# @font-face {
#     font-family: NG;
#     font-weight: normal;
#     src:url('/common/fonts/NanumGothic.eot');
#     src:local(※), url('/common/fonts/NanumGothic.woff') format('woff');
# }
# @font-face {
#     font-family: NGB;
#     font-weight: bold;
#     src:url('/common/fonts/NanumGothicExtraBold.eot');
#     src:local(※), url('/common/fonts/NanumGothicExtraBold.woff') format('woff');
# }
# -->
# </style>
# <script>
# $.isLoginWeb = false;
# $.Resource = {
#     domainWeb: 'https://www.alpha.co.kr',
#     domainSsl: 'https://www.alpha.co.kr'
# };
#
#
#
# /*
#
#   if(document.location.protocol == 'http:'){
#
#     document.location.href = document.location.href.replace('http:', 'https:');
#
# }else if(document.location.protocol == 'https:'){
#
#         console.log('https');
# }
#
# */
# </script>
# <script src="//cdnjs.cloudflare.com/ajax/libs/blueimp-md5/2.10.0/js/md5.min.js"></script>
# <script type="text/javascript">
#
# 	(function(w,d,n,s,e,o) {
# 		w[n]=w[n]||function(){(w[n].q=w[n].q||[]).push(arguments)};
# 		e=d.createElement(s);e.async=1;e.charset='utf-8';e.src='//static.recopick.com/dist/production.min.js';
# 		o=d.getElementsByTagName(s)[0];o.parentNode.insertBefore(e,o);
# 	})(window, document, 'recoPick', 'script');
#
# 	recoPick('service', 'alpha.co.kr');
# 	recoPick('setMID', md5("")  );
# 	recoPick('setUserInfo',{ birthyear:calcAge(""), gender:""});
# 	//recoPick('sendLog', window.location.pathname);
#
#
# 	function calcAge(birth) {
# 		var birthdayy = "";
# 		if(birth != null || birth != "undefined"){
# 			var birthdayy = birth.substr(0, 4);
# 		}
# 		return birthdayy;
# 	}
#
# </script>
# <script src="https://t1.daumcdn.net/mapjsapi/bundle/postcode/prod/postcode.v2.js"></script>
# </meta></meta></head><body class="page-list">
# <!-- page : basket -->
# <div id="skipNavigation">
# <a href="#contents">컨텐츠 바로가기</a>
# </div>
# <div id="container">
# <!-- container -->
# <h1 class="sr-only">알파몰</h1>
# <link href="/common/css/new2019_half_style.css" rel="stylesheet">
# <!-- 메인 로고 CLASS -->
# <!--// 메인 로고 CLASS -->
# <div class="" id="header"><!-- header -->
# <!-- -->
# <!-- 변경 날개배너 ---------------------------------------------------------------------------------------------------------->
# <style>
#
#     /*검색  테스트용*/
#     .serch_layer_2016 .position02 { display:none !important;}
#     .serch_layer_2016 .position03 { display:none !important;}
#     .serch_layer_2016 .position04 { display:none !important;}
#
# 	.serch_layer_2016 {
# 		margin: 0;
# 		position: absolute;
# 		top: 34px;
# 		left: 0px;
# 		background-color: #FFF;
# 		z-index: 9999999;}
#
#     .serch_layer_2016 .position01 {
#         position: absolute;
#         top: 0px !important;
#         left: 0;
#         margin:0px !important;
#         border: 2px solid #0067b4 !important;
#         background-color: #FFF;
#         width: 318px !important;
#         height:initial;
#         font-size: 13px;
#         z-index: 9999;
# 		padding:10px 0 !important;
# 		box-sizing:border-box;
#     }
#
#     .serch_layer_2016 .box .close {
#         margin:0px;
#         position: absolute;
#         top: 0px !important;
#         left: 258px !important;
#         width: 60px ;
#         height: 60px;
#         border: 2px solid #0067b4 !important;
#         background-color: #FFF;
#         /* box-shadow: 3px 3px 5px rgba(0, 0, 0, 0.2); */
#         z-index: 999999; font-size:0px !important;
# 		padding:0;
#     }
#
#
# 	.serch_layer_2016 .position01 dt {
# 		margin: 0;
# 		padding: 3px 20px 6px 20px;
# 		display: inline-block;
# 		line-height:inherit;
# 		width: 50px;
# 		height: 14px;
# 		overflow: hidden;}
#
#
#     .serch_layer_2016 .box .close img {
# 		position:absolute; top:0; left:0;
# 		-webkit-transform: translate(8%,5%); -ms-transform: translate(8%,5%); transform: translate(8%,5%);}
#
#
# .serch_layer_2016 .box .close {left:316px !important; display:none;}
#     /*검색  테스트용*/
#
# </style>
# <style>
# 	.GnB2021 {width:100%; min-width:1280px; margin:0 auto; font-size:0;}
# 	.GnB2021 dl {margin:0; vertical-align:middle;}
# 	.GnB2021 dt {margin:0; display:inline-block; font-size:12px; vertical-align:middle;}
#
#
# 	.GnB2021 .menu {width:1280px; margin:0 auto; vertical-align:top; padding:0; box-sizing:border-box;}
# 	.GnB2021 .menu div {margin:0; display:inline-block; font-size:12px;}
#
# 	.GnB2021 .menu .left {width:112px; background-color:#F00;}
# 	.GnB2021 .menu .left img {display:block;}
#
# 	.GnB2021 .menu .right {width:-webkit-calc(100% - 112px); width:calc(100% - 112px); }
# 	.GnB2021 .menu .right span {display:block; height:60%;}
# 	.GnB2021 .menu .right span:last-child {height:40%;}
# 	.GnB2021 .menu .right nav {float:left; width:25%; height:85px; color:#FFF;  text-align:center; border-right:1px solid #d8d8d8; box-sizing:border-box;}
# 	.GnB2021 .menu .right nav a {padding:10px 2%; line-height:30px; color:#FFF;}
# 	.GnB2021 .menu .right nav a:hover { background-color:rgba( 255, 255, 255, 0.9 ); color:#000;}
#
# 	.GnB2021 .menu .right nav:first-child {border-left:1px solid #d8d8d8; box-sizing:border-box;}
# 	.GnB2021 .menu .right nav:first-child span:first-child a:hover { background-color:rgba( 255, 255, 255, 0); color:#000;}
#
# 	.GnB2021 .menu2 {width:1280px; margin:0 auto; padding:10px 0px; box-sizing:border-box; position:relative;}
# 	.GnB2021 .menu2 span {display:inline-block; margin-right:30px; position:relative; top:0px;}
# 	.GnB2021 .menu2 span:hover {font-weight:bold; cursor:pointer; color:#455bff;}
# 	.GnB2021 .menu2 span:last-child {margin:0;}
# 	.GnB2021 .menu2 .left {}
# 	.GnB2021 .menu2 .right {position:absolute; top:18px; right:0px;}
#
# 	.GnB2021 .menu2 dt:first-child	 {margin-right:20px;}
# 	.GnB2021 .menu2 dt:last-child {text-align:right;}
#
# 	.GnB2021 .menu2 .service ul {
# 		margin: 0;
# 		padding: 0;
# 		list-style: none;
# 		width:100%;
# 		font-size:12px;}
#
# 	.GnB2021 .menu2 .service ul::after {
# 		display: block;
# 		clear: both;
# 		content: '';}
#
# 	.GnB2021 .menu2 .service ul li {
# 		padding-bottom:10px;}
#
# 	.GnB2021 .menu2 .service ul li:hover {
# 		background-color: rgba(255,255,255,.3);}
#
# 	.GnB2021 .menu2 .service ul ul {
# 		visibility: hidden;
# 		opacity: 0;
# 		position: absolute;
# 		top:100%;
# 		right:-1px;
# 		background-color:#fff;
# 		color:#999 !important;
# 		font-weight:normal !important;
# 		width:100px;
# 		box-sizing:border-box;
# 		border:1px solid #d8d8d8;
# 		text-align:left;
# 		padding:15px 15px;}
#
# 	.GnB2021 .menu2 .service ul li:hover > ul {
# 		visibility: visible;
# 		opacity: 1;
# 		transition: .2s ease-in-out;
# 		z-index:1;}
#
# 	.GnB2021 .menu2 .service ul li ul li {
# 		padding:0;
# 		text-align:center;}
#
# 	.GnB2021 .menu2 .service ul li ul li span {
# 		padding:5px 0;
# 		border-bottom:0px solid #CCC;
# 		display: block !important;
# 		margin-right: 0px !important;}
#
# 	.GnB2021 .menu2  .gnbicon {width:110px; height:30px; background-color:#fd6600; border-radius:15px; position:relative;}
# 	.GnB2021 .menu2  .gnbicon:hover {background-color:#34558b; transition: all 0.3s;}
#
# 	.gnbicon a {width:auto; height:30px; display:block;}
#
# 	.GnB2021 .menu2  .gnbicon .active img {display:none !important;}
#
# 	.GnB2021 .menu2  .gnbicon .active {background-color:#34558b; border-radius:15px;}
#
# 	.GnB2021 .menu2  .gnbicon> a:after {
# 		position: absolute;
# 		left: 10px;
# 		top: 9px;
# 		display: block;
# 		height: 2px;
# 		width: 10px;
# 		background: #fff;
# 		content: "";
# 		-webkit-transition: all 0.1s ease-out;
# 		-moz-transition: all 0.1s ease-out;
# 		-ms-transition: all 0.1s ease-out;
# 		-o-transition: all 0.1s ease-out;
# 		transition: all 0.1s ease-out;}
#
#
#
# 	.GnB2021 .menu2  .gnbicon> a:before {
# 		position: absolute;
# 		left: 10px;
# 		top: 19px;
# 		display: block;
# 		width: 10px;
# 		height: 2px;
# 		background: #fff;
# 		content: "";
# 		-webkit-transition: all 0.1s ease-out;
# 		-moz-transition: all 0.1s ease-out;
# 		-ms-transition: all 0.1s ease-out;
# 		-o-transition: all 0.1s ease-out;
# 		transition: all 0.1s ease-out;	}
#
# 	.togglerCategory.active:after {
# 		-webkit-transform: rotate(45deg);
# 		-moz-transform: rotate(45deg);
# 		-ms-transform: rotate(45deg);
# 		-o-transform: rotate(45deg);
# 		transform: rotate(45deg);
# 		top: 14px !important;}
#
# 	.togglerCategory.active:before {
# 		-webkit-transform: rotate(-45deg);
# 		-moz-transform: rotate(-45deg);
# 		-ms-transform: rotate(-45deg);
# 		-o-transform: rotate(-45deg);
# 		transform: rotate(-45deg);
# 		top: 14px !important;}
#
#
#
# 	.GnB2021 .menu3 {width:1280px; margin:0 auto; padding:15px 0px; box-sizing:border-box; position:relative;}
#
# 	.GnB2021 .menu3 .logo {margin-right: 20px;}
#
# 	.GnB2021 .menu3 .serch_box {
# 		margin-right:40px; border-bottom:2px solid #455bff; box-sizing:border-box; height:36px; position:relative;
# 		width:-webkit-calc(45% - 260px);
# 		width:calc(45% - 260px);}
#
# 	.GnB2021 .menu3 .serch_box input {
# 			width:-webkit-calc(100% - 30px);
# 			width:calc(100% - 30px);
# 			height: 34px;
# 			padding:0;
# 			border:0px solid #000;
# 			outline: none;}
#
# 	.GnB2021 .menu3 .login_box {
# 		width:auto;}
#
# 	.GnB2021 .menu3 .login_box span {
# 		padding:0 10px; font-size:12px; border-right:1px solid #d8d8d8;}
#
#
# 	.GnB2021 .menu3 .login_box span:first-child {
# 		padding-left:0px;}
#
# 	.GnB2021 .menu3 .login_box span:last-child {
# 		border-right:0px}
#
# 	.GnB2021 .menu3 .log_s {position: absolute; top:20px; right:0px; font-size: 0;}
#
# 	.GnB2021 .menu3 .log_s span {padding-left:14px;}
#
#
# 	.navbg00 {background-color:#fd6000;}
# 	.navbg01 {background-color:#34558b;}
# 	.navbg02 {background-color:#005353;}
# 	.navbg03 {background-color:#92006e;}
#
# </style>
# <div class="GnB2021">
# <style>
# 		.top_banner {display: block; position: relative;}
# 		.top_banner .banner_bg {text-align: center;position: absolute;overflow: hidden; top:0; left:0; width:100%; height:80px; align:center;}
# 		.top_banner .banner_bg div {width:50%; height: 100%;float: left;clear: right;}
# 		.top_banner .banner_wrap {text-align: center;position: relative; margin: 0px auto; z-index:14; align:center;}
# 	</style>
# <div class="top_banner">
# <div class="banner_bg">
# <div style="background-color: #3db8c3;"></div>
# <div style="background-color: #e8fef1;"></div>
# </div>
# <div class="banner_wrap"><img border="0" height="80" src="https://www.alpha.co.kr/common/img/2021/20201324_toplinebanner.png" usemap="#Map962"/>
# <map name="Map962">
# <area coords="4,5,634,74" href="https://www.alpha.co.kr/product/productList.do?categoryCode=001009004001012" onfocus="this.blur()" shape="rect" style="border:none; outline:none; outline-style:none; -moz-outline-style:none;"/>
# <area coords="643,5,1276,73" href="https://www.alpha.co.kr/totalSearch/totalSearchFinal.do?totalSearchType=TOTAL&amp;totalSearchText=+%EB%8B%A8%EB%8F%85+%ED%95%A0%EC%9D%B8%ED%8A%B9%EA%B0%80&amp;akcPageNum=&amp;akcCurrentPageNum=&amp;productTotal=" onfocus="this.blur()" shape="rect" style="border:none; outline:none; outline-style:none; -moz-outline-style:none;"/>
# </map>
# </div>
# </div>
# <div class="menu3">
# <dl>
# <dt class="logo">
# <a href="https://www.alpha.co.kr/index.do"><img src="https://www.alpha.co.kr/common/img/top_logo2.jpg"/></a>
# </dt>
# <dt class="serch_box">
# <form action="https://www.alpha.co.kr/totalSearch/totalSearchFinal.do" id="searchCommForm" name="searchCommForm">
# <input name="totalSearchType" type="hidden" value="TOTAL"/>
# <input autocomplete="off" class="totalSearchTextClass" id="totalSearchText" name="totalSearchText" onkeypress="javascript:if(event.keyCode == 13) { totalSearch();return false;}; " placeholder="" title="검색어 입력" type="text" value=""/>
# <input class="akcPageNum" id="akcPageNum" name="akcPageNum" type="hidden">
# <input class="akcCurrentPageNum" id="akcCurrentPageNum" name="akcCurrentPageNum" type="hidden"/>
# <input class="productTotal" id="productTotal" name="productTotal" type="hidden"/>
# </input></form>
# <div class="serch_layer_2016 akcDivClass" id="akcDiv" name="akcDiv"></div>
# <span style="position:absolute; top:5px; right:0;">
# <a href="javascript:totalSearch();">
# <img src="https://m.alpha.co.kr/allNewCommon/img/icon_002.jpg" width="20"/><em style="font-size:0px;">찾기</em>
# </a>
# </span>
# </dt>
# <dt class="login_box">
# <span>
# <a href="javascript:goUrl('', 'Y', '', 'N');" id="topLogin">로그인</a>
# </span>
# <span>
# <a href="https://www.alpha.co.kr/member/join/joinStep1.do">회원가입</a>
# </span>
# <span>
# <a href="https://www.alpha.co.kr/order/cart/cartProduct.do?IS_MEMBER=false&amp;searchPickupYn=N">장바구니</a>
# </span>
# <span><a href="https://www.alpha.co.kr/customer/customerMain/customerMain.do">고객센터</a></span>
# </dt>
# <dt class="log_s">
# <span>
# <a href="https://www.alpha.co.kr/alphaB2B.do" target="new">
# <img border="0" src="/common/img/2021/N_logs_1.jpg"/>
# </a>
# </span>
# <span>
# <a href="http://pensaf.dowebi.net" target="new">
# <img border="0" src="/common/img/2021/N_logs_3.jpg"/>
# </a>
# </span>
# <span>
# <a href="http://munguart.co.kr/sub01/sub04.php?device=" target="new">
# <img border="0" src="/common/img/2021/N_logs_4.jpg"/>
# </a>
# </span>
# <span>
# <a href="http://www.alpha114.co.kr" target="new">
# <img border="0" src="/common/img/2021/N_logs_2.jpg"/>
# </a>
# </span>
# </dt>
# </dl>
# </div>
# <div class="line1"></div>
# <div class="menu">
# <div class="left">
# <a href="/plan/planProductForm.do?PS_IDX=1636"><img src="/common/img/2021/Namdaemun.png"/></a>
# </div>
# <div class="right">
# <nav style="width:13%;">
# <span style="background-color:#ffdd00;"><a href="https://www.alpha.co.kr/edumate/index.do"><img src="/common/img/2021/sub2_logo_1.png"/></a></span>
# <span class="navbg00">
# <a href="https://www.alpha.co.kr/edumate/index.do">창의교육용품</a>
# </span>
# </nav>
# <nav style="width:34%;">
# <span><a href="https://www.alpha.co.kr/alphaOffice/index.do"><img src="/common/img/2021/sub2_logo_2.png"/></a></span>
# <span class="navbg01">
# <a href="javascript:goSubMenuUrl('001001005001001');">필기류</a>
# <a href="javascript:goSubMenuUrl('001001001001001');">문구사무</a>
# <a href="javascript:goSubMenuUrl('001002');">전산디지털/가전</a>
# <a href="javascript:goSubMenuUrl('001001002002001');">사무기기</a>
# <a href="javascript:goSubMenuUrl('001004001');">생활.식품.편의</a>
# </span>
# </nav>
# <nav style="width:33%;">
# <span><a href="https://www.alpha.co.kr/alphaart/index.do"><img src="/common/img/2021/sub2_logo_3.png"/></a></span>
# <span class="navbg02">
# <a href="javascript:goSubMenuUrl('004001016001');">미술재료</a>
# <a href="javascript:goSubMenuUrl('004002001001');">건축제도</a>
# <a href="javascript:goSubMenuUrl('004003001001');">전문지류</a>
# <a href="javascript:goSubMenuUrl('004004001001');">취미.생활.DIY</a>
# <a href="https://www.alpha.co.kr/index/photoFrame.do">그림액자</a>
# </span>
# </nav>
# <nav style="width:20%;">
# <span><a href="https://www.alpha.co.kr/penast/index.do"><img src="/common/img/2021/sub2_logo_4.png"/></a></span>
# <span class="navbg03">
# <a href="javascript:goSubMenuUrl('003001028001');">명품필기</a>
# <a href="javascript:goSubMenuUrl('003002015001');">다이어리</a>
# <a href="javascript:goSubMenuUrl('003003001001');">데스크용품</a>
# </span>
# </nav>
# </div>
# </div>
# <div class="line1"></div>
# <div class="menu2">
# <dl>
# <dt class="gnbicon">
# <a class="togglerCategory" href="#!" id="togglerCategory2">
# <img src="https://www.alpha.co.kr/common/img/2021/gnbicon.png"/> <span style="display:block; position:absolute; top:8px; right:12px; font-weight:bold; color:#FFF;">전체카테고리</span>
# </a>
# </dt>
# <dt>
# <span>
# <a href="/plan/planList.do">쇼핑기획전</a>
# </span>
# <span>
# <a href="/plan/planProductForm.do?PS_IDX=107">익스프레스샵</a>
# </span>
# <!--
#                 <span>
#                 	<a href="/plan/brandPlanList.do">브랜드관</a>
#                 </span>
#                 -->
# <span>
# <a href="/plan/planProductForm.do?PS_IDX=1400">알파마트</a>
# </span>
# <span>
# <a href="/plan/planProductForm.do?PS_IDX=903">꽃배달</a>
# </span>
# <span>
# <a href="/display/product/salesBestSub.do"><b>베스트 100</b></a>
# </span>
# <span style=" margin-left:10px;">
# <a href="/plan/planProductForm.do?PS_IDX=1682">
# <font style="position:absolute; top:-4px; left:-20px;"><img src="/common/img/2021/n.png"/></font>
# <b style="color:#ff0000;">월간특가</b>
# </a>
# </span>
# <span style=" margin-left:10px;">
# <a href="/plan/planProductForm.do?PS_IDX=1646">
# <font style="position:absolute; top:-4px; left:-20px;"><img src="/common/img/2021/n.png"/></font>
# <b style="color:#ff0000;">OUTLET</b>
# <!--<b style="background-color:#ff0000; border-radius:10px; color:#FFF; font-size:12px; padding:2px 5px; position:relative; top:-1px; left:3px;">~ 80%</b>-->
# </a>
# </span>
# </dt>
# <dt class="right">
# <span><a href="https://www.alpha.co.kr/customer/serviceInfo/massQuote/massQuoteInfo.do">대량견적문의</a></span>
# <span><a href="https://www.alpha.co.kr/couponAndSave/couponEventList.do">할인쿠폰</a></span>
# <span class="service">
# <ul>
# <li>마이알파  ▼
#                             <ul>
# <li>
# <span><a href="https://www.alpha.co.kr/mypage/subMain/subMainView.do">주문관리</a></span>
# <span><a href="/mypage/memberCategory/memberCategoryList.do">활동관리</a></span>
# <span><a href="/mypage/savePoint/savePointList.do">적립금/쿠폰</a></span>
# <span><a href="/mypage/estimate/massEstimateList.do">견적관리</a></span>
# <span><a href="/mypage/grade/gradeInfo.do">회원정보</a></span>
# </li>
# </ul>
# </li>
# </ul>
# </span>
# </dt>
# </dl>
# </div>
# <div class="line1"></div>
# </div>
# </div>
# <div class="renewal_skyscraper-a js-stickr left" id="skyscraperA"><!-- skyscraper -->
# <ul class="reset">
# <!-- <li class="item">
#             <a href="#!" class="border"><img src="/common/img/common/skyscraper_01.png" alt="" /></a>
#         </li> -->
# <!-- <li class="item stickr-toggle"> -->
# <li class="item">
# <a class="border" href="javascript:goskyCraperUrl('301', 'S', '1')"><img alt="상품 바로가기" onerror="this.src='/common/img/noimage/162.png'" src="/image/display/2020/03/12/383bc5b8-85af-479a-a8eb-d3630e6bcace.jpg"/></a>
# </li>
# <!-- <li class="item stickr-toggle"> -->
# <li class="item">
# <a class="border" href="javascript:goskyCraperUrl('302', 'S', '2')"><img alt="상품 바로가기" onerror="this.src='/common/img/noimage/162.png'" src="/image/display/2019/09/18/8e71f9fc-f946-4f9e-a205-486aad5ce2b3.jpg"/></a>
# </li>
# <!-- <li class="item stickr-toggle"> -->
# <li class="item">
# <a class="border" href="javascript:goskyCraperUrl('351', 'B', '3')"><img alt="상품 바로가기" onerror="this.src='/common/img/noimage/162.png'" src="/image/display/2021/03/30/cf732bf9-9159-4076-881c-b1f4c719fb0e.png"/></a>
# </li>
# </ul>
# </div><!-- // skyscraper --><script src="/common/js/jquery-rolling.js"></script>
# <script type="text/javascript">
#
# $(function() {
#
#     //$("#totalSearchText").val("")
#     //$("#totalSearchText").focus();
#
#     var headerClass = "";
#
#      // NeCe 일때 right값 조절
#      if(headerClass == "penast"){
#
#         $(".top_banner_adzone").css("right", 250);
#         $('body').addClass("page-penast");
#
#      }else if(headerClass == "edumate"){
#
#         $('body').addClass("page-edumate");
#
#      }else if(headerClass == "art"){
#
#         $('body').addClass("page-art");
#
#      }else if(headerClass == "living"){
#
#         $('body').addClass("page-living");
#
#      }else if(headerClass == "digital"){
#
#         $('body').addClass("page-digital");
#
#      }else{
#          //$('body').addClass("page-main-2");
#      }
#
#      // 시작페이지로 버튼 숨김처리
#     if(navigator.userAgent.indexOf("MSIE") == -1 && navigator.userAgent.indexOf("Trident") == -1)
#     {
#         $("#setHomePage").remove();
#     }
#
#     // 즐겨찾기
#     addBookMark = function()
#     {
#         if(navigator.userAgent.indexOf("MSIE") > -1 || navigator.userAgent.indexOf("Trident") > -1)
#         {
#             window.external.AddFavorite(location.href, "알파몰"); //IE
#         }
#         else
#         {
#             alert('Ctrl+D 키를 누르면 즐겨찾기에 추가하실 수 있습니다.');
#         }
#     }
#
#     // 바탕화면 바로가기 추가
#     goBaroLink = function()
#     {
#         var popupObj = new Object();
#         popupObj.url = $.Resource.domainWeb + "/desktopicon/desktopiconPopup.html";
#         popupObj.popupName = "baroPopup";
#         popupObj.width = "350";
#         popupObj.height = "201";
#         popupObj.scrollbars = "no";
#
#         customPopup(popupObj);
#     }
#
#     // 통합검색 검색어링크 542
#     totalSearch = function ()
#     {
#         if($("#totalSearchText").val() == null || $("#totalSearchText").val() == ""){
# 			location.href ="";
#             return;
#         }
#
#         var str = $("#totalSearchText").val();
#         var regExp = /[\{\}\[\]\/?.,;:|\)*~`!^_+<>@#$%&\\\=\(\'\"]/gi;
#
#         if(regExp.test(str))
#         {
#             var t = str.replace(regExp, " ");
#             $("#totalSearchText").val(t);
#         }
#
#         var $searchCommForm = $("#searchCommForm");
#         $searchCommForm.attr({"action":"https://www.alpha.co.kr/totalSearch/totalSearchFinal.do", "target":"_self", "method":"get"}).submit();
#     };
#
#     goMainURL = function(val)
#     {
#         var url = "";
#
#         if(val == '002')
#         {
#             url = "/edumate/index.do";
#         }
#         else if(val == '003')
#         {
#             url = "/penast/index.do";
#         }
#         else if(val == '004')
#         {
#             url = "/alphaart/index.do";
#         }
#         else if(val == '005')
#         {
#             url = "/alpha/index.do";
#         }
#         else if(val == '008')
#         {
#             url = "/living/index.do";
#         }
#         else if(val == '009')
#         {
#             url = "/indexEquipment/index.do";
#         }
#         else
#         {
#             url = "/index.do";
#         }
#         location.href = $.Resource.domainWeb + url;
#     }
#
#     barcodeMouseOver = function()
#     {
#         $('#barcodePop').css("display","block");
#     }
#
#     barcodeMouseOut = function()
#     {
#         $('#barcodePop').css("display","none");
#     }
#
# });
#
# function checkboxSessionSet(){
#
#     var Testt = sessionStorage.getItem('checkboxSession');
#     var checkboxResult = "";
#
#     if(Testt == 'close'){
#         sessionStorage.removeItem('checkboxSession');
#          checkboxResult = 'open';
#          sessionStorage.setItem('checkboxSession',checkboxResult);
#          $('#hamburger').prop("checked", false);
#
#     }else{
#         sessionStorage.removeItem('checkboxSession');
#          checkboxResult = 'close';
#          sessionStorage.setItem('checkboxSession',checkboxResult);
#          $('#hamburger').prop("checked", true);
#
#     }
# }
#
# </script><h1 class="sr-only">알파몰</h1>
# <div id="wrap">
# <!-- wrap -->
# <div id="contents">
# <!-- contents -->
# <h2 class="sr-only">컨텐츠 영역</h2>
# <div id="aside"><!-- aside -->
# <div class="lnb-a" id="lnb"><!-- lnb -->
# <h3 class="subject">전산 디지털/가전<span class="semantic"> - 메뉴</span></h3>
# <ul class="d1"><!-- d1 -->
# <li class="d1">
# <a class="d1" href="javascript:;"><span>컴퓨터 액세서리 </span></a>
# <ul class="d2"><!-- d2 -->
# <li class="d2">
# <a class="d2" href="javascript:goSubMenuUrl('')"><span>USB메모리</span></a>
# <div class="d3">
# <span aria-hidden="true" class="arrow"><em></em></span>
# <ul class="d3">
# <li class="d3"><a class="d3" href="javascript:goSubMenuUrl('001002012001002')"><span>16GB</span></a></li>
# <li class="d3"><a class="d3" href="javascript:goSubMenuUrl('001002012001003')"><span>32GB</span></a></li>
# <li class="d3"><a class="d3" href="javascript:goSubMenuUrl('001002012001004')"><span>64GB</span></a></li>
# <li class="d3"><a class="d3" href="javascript:goSubMenuUrl('001002012001005')"><span>128GB</span></a></li>
# <li class="d3"><a class="d3" href="javascript:goSubMenuUrl('001002012001016')"><span>256GB</span></a></li>
# <li class="d3"><a class="d3" href="javascript:goSubMenuUrl('001002012001014')"><span>USB허브</span></a></li>
# <li class="d3"><a class="d3" href="javascript:goSubMenuUrl('001002012001007')"><span>카드리더기</span></a></li>
# </ul>
# </div>
# </li>
# <li class="d2">
# <a class="d2" href="javascript:goSubMenuUrl('001002012002002')"><span>메모리 카드</span></a>
# <div class="d3">
# <span aria-hidden="true" class="arrow"><em></em></span>
# <ul class="d3">
# <li class="d3"><a class="d3" href="javascript:goSubMenuUrl('001002012002002')"><span>마이크로SDHC 16GB</span></a></li>
# <li class="d3"><a class="d3" href="javascript:goSubMenuUrl('001002012002003')"><span>마이크로SDHC 32GB</span></a></li>
# <li class="d3"><a class="d3" href="javascript:goSubMenuUrl('001002012002004')"><span>마이크로SDXC 64GB</span></a></li>
# <li class="d3"><a class="d3" href="javascript:goSubMenuUrl('001002012002005')"><span>마이크로SDXC 128GB</span></a></li>
# <li class="d3"><a class="d3" href="javascript:goSubMenuUrl('001002012002017')"><span>마이크로SDXC 256GB</span></a></li>
# <li class="d3"><a class="d3" href="javascript:goSubMenuUrl('001002012002007')"><span>SDHC 16GB</span></a></li>
# <li class="d3"><a class="d3" href="javascript:goSubMenuUrl('001002012002008')"><span>SDHC 32GB</span></a></li>
# <li class="d3"><a class="d3" href="javascript:goSubMenuUrl('001002012002009')"><span>SDXC 64GB</span></a></li>
# </ul>
# </div>
# </li>
# <li class="d2">
# <a class="d2" href="javascript:goSubMenuUrl('001002012003009')"><span>하드디스크/ODD</span></a>
# <div class="d3">
# <span aria-hidden="true" class="arrow"><em></em></span>
# <ul class="d3">
# <li class="d3"><a class="d3" href="javascript:goSubMenuUrl('001002012003009')"><span>SSD</span></a></li>
# <li class="d3"><a class="d3" href="javascript:goSubMenuUrl('001002012003004')"><span>외장하드 2.5“ (~1TB)</span></a></li>
# <li class="d3"><a class="d3" href="javascript:goSubMenuUrl('001002012003007')"><span>외장하드 2.5“ (1TB)</span></a></li>
# <li class="d3"><a class="d3" href="javascript:goSubMenuUrl('001002012003005')"><span>외장하드 2.5“ (1TB~)</span></a></li>
# <li class="d3"><a class="d3" href="javascript:goSubMenuUrl('001002012003001')"><span>HDD 도킹스테이션</span></a></li>
# <li class="d3"><a class="d3" href="javascript:goSubMenuUrl('001002012003002')"><span>HDD 케이스</span></a></li>
# <li class="d3"><a class="d3" href="javascript:goSubMenuUrl('001002012003006')"><span>외장하드 3.5“</span></a></li>
# <li class="d3"><a class="d3" href="javascript:goSubMenuUrl('001002012003008')"><span>내장형 하드</span></a></li>
# <li class="d3"><a class="d3" href="javascript:goSubMenuUrl('001002012003010')"><span>NAS/DAS</span></a></li>
# </ul>
# </div>
# </li>
# <li class="d2">
# <a class="d2" href="javascript:goSubMenuUrl('001002012004001')"><span>CD/DVD</span></a>
# <div class="d3">
# <span aria-hidden="true" class="arrow"><em></em></span>
# <ul class="d3">
# <li class="d3"><a class="d3" href="javascript:goSubMenuUrl('001002012004001')"><span>CD-R/DVD/블루레이</span></a></li>
# <li class="d3"><a class="d3" href="javascript:goSubMenuUrl('001002012004002')"><span>ODD/보관용품</span></a></li>
# </ul>
# </div>
# </li>
# <li class="d2">
# <a class="d2" href="javascript:goSubMenuUrl('001002012005001')"><span>마우스</span></a>
# <div class="d3">
# <span aria-hidden="true" class="arrow"><em></em></span>
# <ul class="d3">
# <li class="d3"><a class="d3" href="javascript:goSubMenuUrl('001002012005001')"><span>유선 일반마우스</span></a></li>
# <li class="d3"><a class="d3" href="javascript:goSubMenuUrl('001002012005003')"><span>무선 일반마우스</span></a></li>
# <li class="d3"><a class="d3" href="javascript:goSubMenuUrl('001002012005009')"><span>버티컬 마우스</span></a></li>
# <li class="d3"><a class="d3" href="javascript:goSubMenuUrl('001002012005010')"><span>무소음 마우스</span></a></li>
# <li class="d3"><a class="d3" href="javascript:goSubMenuUrl('001002012005008')"><span>게이밍 마우스</span></a></li>
# <li class="d3"><a class="d3" href="javascript:goSubMenuUrl('001002012005002')"><span>마우스패드</span></a></li>
# <li class="d3"><a class="d3" href="javascript:goSubMenuUrl('001002012005006')"><span>타블렛</span></a></li>
# </ul>
# </div>
# </li>
# <li class="d2">
# <a class="d2" href="javascript:goSubMenuUrl('001002012006002')"><span>키보드</span></a>
# <div class="d3">
# <span aria-hidden="true" class="arrow"><em></em></span>
# <ul class="d3">
# <li class="d3"><a class="d3" href="javascript:goSubMenuUrl('001002012006002')"><span>유선 키보드</span></a></li>
# <li class="d3"><a class="d3" href="javascript:goSubMenuUrl('001002012006004')"><span>무선 키보드</span></a></li>
# <li class="d3"><a class="d3" href="javascript:goSubMenuUrl('001002012006009')"><span>무소음 키보드</span></a></li>
# <li class="d3"><a class="d3" href="javascript:goSubMenuUrl('001002012006008')"><span>키보드마우스 세트</span></a></li>
# <li class="d3"><a class="d3" href="javascript:goSubMenuUrl('001002012006007')"><span>기계식 키보드</span></a></li>
# <li class="d3"><a class="d3" href="javascript:goSubMenuUrl('001002012006003')"><span>키보드 악세사리</span></a></li>
# </ul>
# </div>
# </li>
# <li class="d2">
# <a class="d2" href="javascript:goSubMenuUrl('001002012007001')"><span>소프트웨어</span></a>
# <div class="d3">
# <span aria-hidden="true" class="arrow"><em></em></span>
# <ul class="d3">
# <li class="d3"><a class="d3" href="javascript:goSubMenuUrl('001002012007001')"><span>운영체제(OS)</span></a></li>
# <li class="d3"><a class="d3" href="javascript:goSubMenuUrl('001002012007002')"><span>보안</span></a></li>
# <li class="d3"><a class="d3" href="javascript:goSubMenuUrl('001002012007005')"><span>유틸리티</span></a></li>
# <li class="d3"><a class="d3" href="javascript:goSubMenuUrl('001002012007008')"><span>MS Office</span></a></li>
# <li class="d3"><a class="d3" href="javascript:goSubMenuUrl('001002012007009')"><span>한글 Office</span></a></li>
# <li class="d3"><a class="d3" href="javascript:goSubMenuUrl('001002012007010')"><span>그래픽/디자인</span></a></li>
# </ul>
# </div>
# </li>
# <li class="d2">
# <a class="d2" href="javascript:goSubMenuUrl('001002012008001')"><span>기타/청소용품</span></a>
# <div class="d3">
# <span aria-hidden="true" class="arrow"><em></em></span>
# <ul class="d3">
# <li class="d3"><a class="d3" href="javascript:goSubMenuUrl('001002012008001')"><span>청소/정리용품</span></a></li>
# <li class="d3"><a class="d3" href="javascript:goSubMenuUrl('001002012008002')"><span>기타용품</span></a></li>
# </ul>
# </div>
# </li>
# <li class="d2">
# <a class="d2" href="javascript:goSubMenuUrl('001002012009001')"><span>케이블</span></a>
# <div class="d3">
# <span aria-hidden="true" class="arrow"><em></em></span>
# <ul class="d3">
# <li class="d3"><a class="d3" href="javascript:goSubMenuUrl('001002012009001')"><span>USB케이블</span></a></li>
# <li class="d3"><a class="d3" href="javascript:goSubMenuUrl('001002012009002')"><span>LAN케이블</span></a></li>
# <li class="d3"><a class="d3" href="javascript:goSubMenuUrl('001002012009003')"><span>영상 케이블</span></a></li>
# <li class="d3"><a class="d3" href="javascript:goSubMenuUrl('001002012009004')"><span>음성 케이블</span></a></li>
# <li class="d3"><a class="d3" href="javascript:goSubMenuUrl('001002012009005')"><span>기타 케이블</span></a></li>
# <li class="d3"><a class="d3" href="javascript:goSubMenuUrl('001002012009006')"><span>몰드</span></a></li>
# </ul>
# </div>
# </li>
# <li class="d2">
# <a class="d2" href="javascript:goSubMenuUrl('001002012010001')"><span>네트웍용품</span></a>
# <div class="d3">
# <span aria-hidden="true" class="arrow"><em></em></span>
# <ul class="d3">
# <li class="d3"><a class="d3" href="javascript:goSubMenuUrl('001002012010001')"><span>유무선 허브</span></a></li>
# <li class="d3"><a class="d3" href="javascript:goSubMenuUrl('001002012010002')"><span>유무선 공유기</span></a></li>
# <li class="d3"><a class="d3" href="javascript:goSubMenuUrl('001002012010007')"><span>유무선 랜카드</span></a></li>
# <li class="d3"><a class="d3" href="javascript:goSubMenuUrl('001002012010003')"><span>변환기/분배기</span></a></li>
# <li class="d3"><a class="d3" href="javascript:goSubMenuUrl('001002012010004')"><span>랜 설치용품</span></a></li>
# <li class="d3"><a class="d3" href="javascript:goSubMenuUrl('001002012010005')"><span>커플러/젠더/컨버터</span></a></li>
# </ul>
# </div>
# </li>
# </ul>
# </li>
# <li class="d1">
# <a class="d1" href="javascript:;"><span>컴퓨터/모니터</span></a>
# <ul class="d2"><!-- d2 -->
# <li class="d2">
# <a class="d2" href="javascript:goSubMenuUrl('001002010002010')"><span>노트북</span></a>
# <div class="d3">
# <span aria-hidden="true" class="arrow"><em></em></span>
# <ul class="d3">
# <li class="d3"><a class="d3" href="javascript:goSubMenuUrl('001002010002010')"><span>애플</span></a></li>
# <li class="d3"><a class="d3" href="javascript:goSubMenuUrl('001002010002005')"><span>삼성</span></a></li>
# <li class="d3"><a class="d3" href="javascript:goSubMenuUrl('001002010002004')"><span>LG</span></a></li>
# <li class="d3"><a class="d3" href="javascript:goSubMenuUrl('001002010002006')"><span>HP</span></a></li>
# <li class="d3"><a class="d3" href="javascript:goSubMenuUrl('001002010002008')"><span>기타 브랜드</span></a></li>
# </ul>
# </div>
# </li>
# <li class="d2">
# <a class="d2" href="javascript:goSubMenuUrl('001002010004001')"><span>데스크탑</span></a>
# <div class="d3">
# <span aria-hidden="true" class="arrow"><em></em></span>
# <ul class="d3">
# <li class="d3"><a class="d3" href="javascript:goSubMenuUrl('001002010004001')"><span>삼성</span></a></li>
# <li class="d3"><a class="d3" href="javascript:goSubMenuUrl('001002010004010')"><span>HP</span></a></li>
# <li class="d3"><a class="d3" href="javascript:goSubMenuUrl('001002010004012')"><span>DELL</span></a></li>
# <li class="d3"><a class="d3" href="javascript:goSubMenuUrl('001002010004014')"><span>기타 브랜드</span></a></li>
# </ul>
# </div>
# </li>
# <li class="d2">
# <a class="d2" href="javascript:goSubMenuUrl('001002010006003')"><span>모니터</span></a>
# <div class="d3">
# <span aria-hidden="true" class="arrow"><em></em></span>
# <ul class="d3">
# <li class="d3"><a class="d3" href="javascript:goSubMenuUrl('001002010006003')"><span>LED 20~22형</span></a></li>
# <li class="d3"><a class="d3" href="javascript:goSubMenuUrl('001002010006005')"><span>LED 23~24형</span></a></li>
# <li class="d3"><a class="d3" href="javascript:goSubMenuUrl('001002010006006')"><span>LED 24형 이상</span></a></li>
# <li class="d3"><a class="d3" href="javascript:goSubMenuUrl('001002010006008')"><span>LED 디지털액자</span></a></li>
# </ul>
# </div>
# </li>
# <li class="d2">
# <a class="d2" href="javascript:goSubMenuUrl('001002010003011')"><span>노트북액세서리</span></a>
# <div class="d3">
# <span aria-hidden="true" class="arrow"><em></em></span>
# <ul class="d3">
# <li class="d3"><a class="d3" href="javascript:goSubMenuUrl('001002010003011')"><span>노트북 키스킨</span></a></li>
# <li class="d3"><a class="d3" href="javascript:goSubMenuUrl('001002010003010')"><span>노트북 쿨러</span></a></li>
# <li class="d3"><a class="d3" href="javascript:goSubMenuUrl('001002010003001')"><span>노트북 받침대</span></a></li>
# <li class="d3"><a class="d3" href="javascript:goSubMenuUrl('001002010003002')"><span>노트북 가방 (스킨/파우치)</span></a></li>
# <li class="d3"><a class="d3" href="javascript:goSubMenuUrl('001002010003003')"><span>노트북 가방 (서류형)</span></a></li>
# <li class="d3"><a class="d3" href="javascript:goSubMenuUrl('001002010003004')"><span>노트북 가방 (배낭형)</span></a></li>
# <li class="d3"><a class="d3" href="javascript:goSubMenuUrl('001002010003005')"><span>노트북 필름 (일반용)</span></a></li>
# <li class="d3"><a class="d3" href="javascript:goSubMenuUrl('001002010003006')"><span>노트북 아답터/배터리</span></a></li>
# <li class="d3"><a class="d3" href="javascript:goSubMenuUrl('001002010003007')"><span>노트북 필름 (정보보호용)</span></a></li>
# <li class="d3"><a class="d3" href="javascript:goSubMenuUrl('001002010003008')"><span>노트북 보안장치</span></a></li>
# <li class="d3"><a class="d3" href="javascript:goSubMenuUrl('001002010003009')"><span>기타 액세서리</span></a></li>
# </ul>
# </div>
# </li>
# <li class="d2">
# <a class="d2" href="javascript:goSubMenuUrl('001002010007001')"><span>모니터 액세서리</span></a>
# <div class="d3">
# <span aria-hidden="true" class="arrow"><em></em></span>
# <ul class="d3">
# <li class="d3"><a class="d3" href="javascript:goSubMenuUrl('001002010007001')"><span>모니터 받침대</span></a></li>
# <li class="d3"><a class="d3" href="javascript:goSubMenuUrl('001002010007003')"><span>모니터 암</span></a></li>
# <li class="d3"><a class="d3" href="javascript:goSubMenuUrl('001002010007004')"><span>모니터 보안기/필름</span></a></li>
# </ul>
# </div>
# </li>
# <li class="d2">
# <a class="d2" href="javascript:goSubMenuUrl('001002010005006')"><span>컴퓨터 부품</span></a>
# <div class="d3">
# <span aria-hidden="true" class="arrow"><em></em></span>
# <ul class="d3">
# <li class="d3"><a class="d3" href="javascript:goSubMenuUrl('001002010005006')"><span>CPU</span></a></li>
# <li class="d3"><a class="d3" href="javascript:goSubMenuUrl('001002010005003')"><span>DDR메모리</span></a></li>
# <li class="d3"><a class="d3" href="javascript:goSubMenuUrl('001002010005001')"><span>그래픽카드</span></a></li>
# <li class="d3"><a class="d3" href="javascript:goSubMenuUrl('001002010005009')"><span>메인보드</span></a></li>
# <li class="d3"><a class="d3" href="javascript:goSubMenuUrl('001002010005005')"><span>사운드카드</span></a></li>
# <li class="d3"><a class="d3" href="javascript:goSubMenuUrl('001002010005007')"><span>쿨링팬/방열/구리스</span></a></li>
# <li class="d3"><a class="d3" href="javascript:goSubMenuUrl('001002010005008')"><span>케이스</span></a></li>
# <li class="d3"><a class="d3" href="javascript:goSubMenuUrl('001002010005010')"><span>파워</span></a></li>
# </ul>
# </div>
# </li>
# </ul>
# </li>
# <li class="d1">
# <a class="d1" href="javascript:;"><span>프린터/복합기</span></a>
# <ul class="d2"><!-- d2 -->
# <li class="d2">
# <a class="d2" href="javascript:goSubMenuUrl('001002013001001')"><span>잉크젯 프린터</span></a>
# <div class="d3">
# <span aria-hidden="true" class="arrow"><em></em></span>
# <ul class="d3">
# <li class="d3"><a class="d3" href="javascript:goSubMenuUrl('001002013001001')"><span>캐논 프린터</span></a></li>
# <li class="d3"><a class="d3" href="javascript:goSubMenuUrl('001002013001003')"><span>엡손 프린터</span></a></li>
# <li class="d3"><a class="d3" href="javascript:goSubMenuUrl('001002013001004')"><span>포토 프린터</span></a></li>
# <li class="d3"><a class="d3" href="javascript:goSubMenuUrl('001002013001002')"><span>기타 브랜드</span></a></li>
# </ul>
# </div>
# </li>
# <li class="d2">
# <a class="d2" href="javascript:goSubMenuUrl('001002013002001')"><span>잉크젯 복합기</span></a>
# <div class="d3">
# <span aria-hidden="true" class="arrow"><em></em></span>
# <ul class="d3">
# <li class="d3"><a class="d3" href="javascript:goSubMenuUrl('001002013002001')"><span>캐논 복합기</span></a></li>
# <li class="d3"><a class="d3" href="javascript:goSubMenuUrl('001002013002002')"><span>엡손 복합기</span></a></li>
# <li class="d3"><a class="d3" href="javascript:goSubMenuUrl('001002013002003')"><span>기타 복합기</span></a></li>
# </ul>
# </div>
# </li>
# <li class="d2">
# <a class="d2" href="javascript:goSubMenuUrl('001002013003002')"><span>레이저 프린터</span></a>
# <div class="d3">
# <span aria-hidden="true" class="arrow"><em></em></span>
# <ul class="d3">
# <li class="d3"><a class="d3" href="javascript:goSubMenuUrl('001002013003002')"><span>HP 프린터</span></a></li>
# <li class="d3"><a class="d3" href="javascript:goSubMenuUrl('001002013003003')"><span>삼성 프린터</span></a></li>
# <li class="d3"><a class="d3" href="javascript:goSubMenuUrl('001002013003007')"><span>캐논 프린터</span></a></li>
# <li class="d3"><a class="d3" href="javascript:goSubMenuUrl('001002013003001')"><span>기타 프린터</span></a></li>
# </ul>
# </div>
# </li>
# <li class="d2">
# <a class="d2" href="javascript:goSubMenuUrl('001002013004001')"><span>레이저 복합기</span></a>
# <div class="d3">
# <span aria-hidden="true" class="arrow"><em></em></span>
# <ul class="d3">
# <li class="d3"><a class="d3" href="javascript:goSubMenuUrl('001002013004001')"><span>HP 복합기</span></a></li>
# <li class="d3"><a class="d3" href="javascript:goSubMenuUrl('001002013004002')"><span>삼성 복합기</span></a></li>
# <li class="d3"><a class="d3" href="javascript:goSubMenuUrl('001002013004003')"><span>캐논 복합기</span></a></li>
# <li class="d3"><a class="d3" href="javascript:goSubMenuUrl('001002013004006')"><span>기타 복합기</span></a></li>
# </ul>
# </div>
# </li>
# <li class="d2">
# <a class="d2" href="javascript:goSubMenuUrl('001002013005014')"><span>스캐너/기타 프린터</span></a>
# <div class="d3">
# <span aria-hidden="true" class="arrow"><em></em></span>
# <ul class="d3">
# <li class="d3"><a class="d3" href="javascript:goSubMenuUrl('001002013005014')"><span>평판 스캐너</span></a></li>
# <li class="d3"><a class="d3" href="javascript:goSubMenuUrl('001002013005007')"><span>바코드 스캐너</span></a></li>
# <li class="d3"><a class="d3" href="javascript:goSubMenuUrl('001002013005011')"><span>휴대용 스캐너</span></a></li>
# <li class="d3"><a class="d3" href="javascript:goSubMenuUrl('001002013005017')"><span>라벨프린터</span></a></li>
# <li class="d3"><a class="d3" href="javascript:goSubMenuUrl('001002013005002')"><span>3D프린터</span></a></li>
# </ul>
# </div>
# </li>
# </ul>
# </li>
# <li class="d1">
# <a class="d1" href="javascript:;"><span>잉크/토너</span></a>
# <ul class="d2"><!-- d2 -->
# <li class="d2">
# <a class="d2" href="javascript:goSubMenuUrl('001002014002001')"><span>잉크</span></a>
# <div class="d3">
# <span aria-hidden="true" class="arrow"><em></em></span>
# <ul class="d3">
# <li class="d3"><a class="d3" href="javascript:goSubMenuUrl('001002014002001')"><span>HP 잉크</span></a></li>
# <li class="d3"><a class="d3" href="javascript:goSubMenuUrl('001002014002002')"><span>캐논 잉크</span></a></li>
# <li class="d3"><a class="d3" href="javascript:goSubMenuUrl('001002014002003')"><span>삼성 잉크</span></a></li>
# <li class="d3"><a class="d3" href="javascript:goSubMenuUrl('001002014002004')"><span>엡손 잉크</span></a></li>
# <li class="d3"><a class="d3" href="javascript:goSubMenuUrl('001002014002005')"><span>기타 잉크</span></a></li>
# </ul>
# </div>
# </li>
# <li class="d2">
# <a class="d2" href="javascript:goSubMenuUrl('001002014003001')"><span>토너</span></a>
# <div class="d3">
# <span aria-hidden="true" class="arrow"><em></em></span>
# <ul class="d3">
# <li class="d3"><a class="d3" href="javascript:goSubMenuUrl('001002014003001')"><span>HP 토너</span></a></li>
# <li class="d3"><a class="d3" href="javascript:goSubMenuUrl('001002014003002')"><span>캐논 토너</span></a></li>
# <li class="d3"><a class="d3" href="javascript:goSubMenuUrl('001002014003003')"><span>삼성 토너</span></a></li>
# <li class="d3"><a class="d3" href="javascript:goSubMenuUrl('001002014003004')"><span>엡손 토너</span></a></li>
# <li class="d3"><a class="d3" href="javascript:goSubMenuUrl('001002014003005')"><span>신도리코 토너</span></a></li>
# <li class="d3"><a class="d3" href="javascript:goSubMenuUrl('001002014003006')"><span>기타 토너</span></a></li>
# <li class="d3"><a class="d3" href="javascript:goSubMenuUrl('001002014003008')"><span>제록스 토너</span></a></li>
# <li class="d3"><a class="d3" href="javascript:goSubMenuUrl('001002014003009')"><span>OKI 토너</span></a></li>
# <li class="d3"><a class="d3" href="javascript:goSubMenuUrl('001002014003010')"><span>청호 토너</span></a></li>
# <li class="d3"><a class="d3" href="javascript:goSubMenuUrl('001002014003011')"><span>브라더 토너</span></a></li>
# </ul>
# </div>
# </li>
# <li class="d2">
# <a class="d2" href="javascript:goSubMenuUrl('001002014001002')"><span>O.A전용지</span></a>
# <div class="d3">
# <span aria-hidden="true" class="arrow"><em></em></span>
# <ul class="d3">
# <li class="d3"><a class="d3" href="javascript:goSubMenuUrl('001002014001002')"><span>잉크젯 전용지</span></a></li>
# <li class="d3"><a class="d3" href="javascript:goSubMenuUrl('001002014001003')"><span>레이저 전용지</span></a></li>
# <li class="d3"><a class="d3" href="javascript:goSubMenuUrl('001002014001001')"><span>포토용지</span></a></li>
# <li class="d3"><a class="d3" href="javascript:goSubMenuUrl('001002014001004')"><span>플로터 용지(롤)</span></a></li>
# <li class="d3"><a class="d3" href="javascript:goSubMenuUrl('001002014001005')"><span>기타 OA용지</span></a></li>
# </ul>
# </div>
# </li>
# </ul>
# </li>
# <li class="d1">
# <a class="d1" href="javascript:;"><span>소형가전</span></a>
# <ul class="d2"><!-- d2 -->
# <li class="d2">
# <a class="d2" href="javascript:goSubMenuUrl('001002001001007')"><span>건강/의료가전</span></a>
# <div class="d3">
# <span aria-hidden="true" class="arrow"><em></em></span>
# <ul class="d3">
# <li class="d3"><a class="d3" href="javascript:goSubMenuUrl('001002001001007')"><span>헬스케어용품</span></a></li>
# <li class="d3"><a class="d3" href="javascript:goSubMenuUrl('001002001001006')"><span>안마기</span></a></li>
# </ul>
# </div>
# </li>
# <li class="d2">
# <a class="d2" href="javascript:goSubMenuUrl('001002001002010')"><span>계절가전</span></a>
# <div class="d3">
# <span aria-hidden="true" class="arrow"><em></em></span>
# <ul class="d3">
# <li class="d3"><a class="d3" href="javascript:goSubMenuUrl('001002001002010')"><span>공기청정기</span></a></li>
# <li class="d3"><a class="d3" href="javascript:goSubMenuUrl('001002001002021')"><span>휴대용 선풍기</span></a></li>
# <li class="d3"><a class="d3" href="javascript:goSubMenuUrl('001002001002005')"><span>탁상용 선풍기</span></a></li>
# <li class="d3"><a class="d3" href="javascript:goSubMenuUrl('001002001002001')"><span>스탠드형 선풍기</span></a></li>
# <li class="d3"><a class="d3" href="javascript:goSubMenuUrl('001002001002007')"><span>써큘레이터</span></a></li>
# <li class="d3"><a class="d3" href="javascript:goSubMenuUrl('001002001002009')"><span>기타 여름가전</span></a></li>
# <li class="d3"><a class="d3" href="javascript:goSubMenuUrl('001002001002012')"><span>가습기</span></a></li>
# <li class="d3"><a class="d3" href="javascript:goSubMenuUrl('001002001002019')"><span>전기매트/온수매트/방석</span></a></li>
# <li class="d3"><a class="d3" href="javascript:goSubMenuUrl('001002001002018')"><span>전기히터/온풍기</span></a></li>
# ...
#                 <p class="badge"><span class="icon nth-child-1"><em>공정거래위원회</em></span><span class="icon nth-child-2"><em>ECO</em></span><span class="icon nth-child-3"><em>Norton </em></span></p>
#             </div>
#             <div class="col pull-right cert">
#                 <p>온라인디지털콘텐츠산업발전법에 의한 콘텐츠보호안내<a href="javascript:;" class="service" onclick="window.open('https://pgweb.uplus.co.kr/pg/wmp/mertadmin/jsp/mertservice/s_escrowYn.jsp?mertid=alphamall1','mertservice','width=340, height=260, scrollbars=no')" title="새 창 열림"><span class="icon service-able"><em>서비스가입사실확인</em></span></a></p>
#                 <p>고객님의 안전거래를 위해 현금 등으로 모든 거래 결제 시 저희 쇼핑몰에서 가입한 <br />LG U+전자결제의 매매보호(에스크로)서비스를 이용하실 수 있습니다.</p>
#                 <p>결제대금예치업 등록번호 : 02-006-0001</p>
#             </div>
#         </div>
#     </div>
# -->
# <!-- 하단 ------------------------------------------------------------------------------------------------------------------------------------------------------->
# <div class="new_bottom2019">
# <div class="line1"></div>
# <!--
# 		<div class="alpha_ad">
# 			알파몰은  오피스 환경에 최적화된 전문쇼핑몰 입니다
# 		</div>
# 		-->
# <div class="menu">
# <div class="left">
# <a href="http://www.alpha114.co.kr/ko/pc/index.do">회사소개</a>
# <!--<a href="http://www.mungustyle.co.kr/webzine/announce/nwz_announce_sub1p.asp?s_kind=wza_14">채용안내</a>-->
# <a href="https://www.alpha.co.kr/customer/useInfo/accessInfo.do">이용약관</a>
# <a class="color2" href="https://www.alpha.co.kr/customer/useInfo/personInfo.do"><b>개인정보취급방침</b></a>
# <a href="http://www.alpha114.co.kr/ko/pc/chain/appeal.do">체인점개설문의</a>
# <a href="https://www.alpha.co.kr/event/advertisement.do">광고신청</a>
# <a href="https://www.alpha.co.kr/customer/customerMain/customerMain.do">고객센터</a>
# </div>
# <div class="right">
# <a href="https://www.alpha.co.kr/scm/">협력사 SCM</a>
# <a href="https://www.alpha.co.kr/alphaB2BIndex.do">체인점 B2B</a>
# <a class="bg1 color1" href="https://www.alpha.co.kr/customer/chain/chainSearchList.do">
#                    가맹점 검색   </a>
# </div>
# </div>
# <div class="line1"> </div>
# <div class="info">
# <dl>
# <dt style="width: 20% !important;">
# <img src="/common/img/2020/bottom_logo.jpg"/>
# </dt>
# <dt style="width: 26% !important;">
#                 	입점문의: <a href="https://www.alpha.co.kr/partner/partnerAsk.do"><b class="color2">입점문의하기</b></a><br/>
# 					고객만족센터 : 1811-0096 <a href="https://www.alpha.co.kr/customer/customerMain/customerMain.do">(바로가기)</a><br/>
# 					FAX : 02-718-0194<br/>
# 					개인정보보호관리책임자 : 김영진 / 우병길<br/>
# <a class="service" href="javascript:;" onclick="window.open('https://pgweb.uplus.co.kr/pg/wmp/mertadmin/jsp/mertservice/s_escrowYn.jsp?mertid=alphamall1','mertservice','width=340, height=260, scrollbars=no')" title="새 창 열림"><b>온라인디지털콘텐츠산업발전법에 의한 콘텐츠보호안내</b></a><br/>
#
#                     대표메일 : <a class="mail" href="mailto:admin0@alpha.co.kr" style="color:#333 !important;" target="_blank">admin0@alpha.co.kr</a>
# </dt>
# <dt style="width:20%;">
# 					사업자등록번호 : 106-81-27494<br/>
# 					통신판매업신고 : 용산구청 제 02663호  <br/>
# 					주소 : 서울 용산구 청파로 56 알파빌딩<br/><br/>
# <font style="font-size:9px;">법인명 (상호) : 알파(주)   대표이사 : 이종호</font>
# </dt>
# <dt style="width:30%;">
# 고객님의 안전거래를 위해 현금 등으로 모든 거래 결제시<br>알파에서 가입한 lg u+ 매매보호(에스크로) 서비스를 이용하실 수 있습니다
# 결제대금 예치등록번호 <a href="https://pgweb.uplus.co.kr/ms/escrow/s_escrowYn.do?mertid=alphamall1">02-006-0001</a>
# <br><br>
# <img src="/common/img/2020/bottom_icon.jpg"/>
# </br></br></br></dt>
# </dl>
# </div>
# </div>
# <!-- 하단 ------------------------------------------------------------------------------------------------------------------------------------------------------->
# <script type="text/javascript">
#     endalert = function() {
# 		alert("준비중입니다. \nadmin0@alpha.co.kr 로 보내주시기 바랍니다");
# 	}
#     </script>
# <!-- // footer --><form id="dataForm" name="dataForm">
# <input name="cPage" type="hidden" value=""/>
# <input name="productCode" type="hidden" value=""/>
# <input id="pageSize" name="pageSize" type="hidden" value="20"/>
# <input id="ORDER_COL" name="ORDER_COL" type="hidden" value="md"/>
# <input id="viewType" name="viewType" type="hidden" value=""/>
# <input name="searchBrand" type="hidden" value=""/>
# <input id="searchDirectType" name="searchDirectType" type="hidden" value=""/>
# <input name="categoryCode" type="hidden" value="001002010002010"/>
# </form>
# <script type="text/javascript">
# $(function () {
#
#     /* lnb active */
#     var sort2 = "3";
#     var sort3 = "2";
#     var sort4 = "1";
#     var sort5 = "1";
#
#     if("" == "755" )
#     {
#     	$.params.lnb = [-1, -1, -1]; // lnb activate
#     }else{
#
#
#     	if("001" != "001" )
#         {
#     		$.params.lnb = [sort2-1, sort3-1, sort4-1]; // lnb activate
#         }else{
#         	$.params.lnb = [sort3-1, sort4-1, sort5-1]; // lnb activate
#         }
#     }
# });
# </script>
# <!-- ui -->
# <script src="/common/js/plugins.js"></script>
# <script src="/common/js/epass.base-0.3.js"></script>
# <script src="/common/js/min/epass.comboBoxr-0.1.min.js"></script>
# <script src="/common/js/min/epass.productSlidr-0.1.min.js"></script>
# <script src="/common/js/min/epass.toggleSlidr-0.1.min.js"></script>
# <script src="/common/js/min/epass.fxSlider-0.4.min.js"></script>
# <script src="/common/js/min/epass.stickr-0.1.min.js"></script>
# <script src="/common/js/epass.datepickr-0.4.js"></script>
# <script src="/common/js/ui.breadcrumb.js"></script>
# <!-- <script src="/common/js/min/ui.min.js"></script> -->
# <script src="/common/js/ui.js"></script>
# <!-- component -->
# <script src="/common/js/plugins/jquery.ajax.js"></script>
# <script src="/common/js/plugins/jquery.validate.js"></script>
# <script src="/common/js/order/cartProduct.js"></script>
# <script src="/common/js/product/product.js"></script>
# <script src="/common/js/order/order.js"></script>
# <script src="/common/js/common.js"></script>
# <script src="/common/js/commonPopup.js"></script>
# <script src="/common/js/plugins/webtoolkit.base64.js"></script>
# <script src="https://t1.daumcdn.net/mapjsapi/bundle/postcode/prod/postcode.v2.js"></script>
# <!-- custom  -->
# <script src="/common/js/akc.js"></script><script type="text/javascript">
# $(function () {
#
# 	var categoryCode = '001002010002010'; //카테고리코드
#     if("" == "755" )
#     {
#         // 서울대병원 아래 해당 카테고리 외 카테고리는 접근불가
#     	if(categoryCode.substring(0,9) == "001001001" || categoryCode.substring(0,9) == "001001002" || categoryCode.substring(0,9) == "001001003"
#             || categoryCode.substring(0,9) == "001001004" || categoryCode.substring(0,9) == "001001005" || categoryCode.substring(0,9) == "001001006"
#             || categoryCode.substring(0,9) == "001002012" || categoryCode.substring(0,9) == "001008001"
#             || categoryCode.substring(0,9) == "001012012" || categoryCode.substring(0,6) == "001011"  || categoryCode.substring(0,6) == "001013"
#             || categoryCode.substring(0,6) == "001014" || categoryCode.substring(0,6) == "001017" || categoryCode.substring(0,12) == "001015004002" ){
#         }else{
#             alert("분당서울대병원 계약카테고리가 아닙니다.");
#             history.go(-1);
#             return;
#         }
#     }
#
#     // comboBoxr
#     var $comboBrand = $('#brandSort .js-comboBoxr').eq(0),
#         $comboSort1 = $('#productSort .js-comboBoxr').eq(0),
#         $comboSort2 = $('#productSort .js-comboBoxr').eq(1),
#         $comboSort3 = $('#productSort .js-comboBoxr').eq(2),
#         $breadcrumb1 = $('#breadcrumb .holder .js-comboBoxr').eq(0),
#         $breadcrumb2 = $('#breadcrumb .holder .js-comboBoxr').eq(1),
#         $breadcrumb3 = $('#breadcrumb .holder .js-comboBoxr').eq(2);
#
#
#     $comboBrand.comboBoxr().init({
#         theme: 'dark'
#     });
#
#     $comboSort1.comboBoxr().init({
#         onChange : function(base){
#             var $dataForm = $("#dataForm");
#             $dataForm.find("input[name='cPage']").val(1);
#             $dataForm.find("input[name='searchDirectType']").val(base.$currentOption.val());
#             $dataForm.attr({"action":$.Resource.domainWeb+"/product/productList.do", "target":"_self", "method":"get"}).submit();
#         }
#     });
#
#     $comboSort2.comboBoxr().init({
#         onChange : function(base){
#             var $dataForm = $("#dataForm");
#             $dataForm.find("input[name='cPage']").val(1);
#             $dataForm.find("input[name='ORDER_COL']").val(base.$currentOption.val());
#             $dataForm.attr({"action":$.Resource.domainWeb+"/product/productList.do", "target":"_self", "method":"get"}).submit();
#         }
#     });
#
#     $comboSort3.comboBoxr().init({
#         onChange : function(base){
#             var $dataForm = $("#dataForm");
#             $dataForm.find("input[name='cPage']").val(1);
#             $dataForm.find("input[name='pageSize']").val(base.$currentOption.val());
#             $dataForm.attr({"action":$.Resource.domainWeb+"/product/productList.do", "target":"_self", "method":"get"}).submit();
#         }
#     });
#
#     // 하위카테고리 뿌려주기
#     if($("#searchCategory5").val() != ""){//5뎁스 선택값 있는 경우
#         $("#categoryNameSpan").html($("#searchCategory5 option:selected").text());
#         getSubCategoryUl("searchCategory5");
#     }else if($("#searchCategory4").val() != ""){//4뎁스 선택값 있는 경우
#         $("#categoryNameSpan").html($("#searchCategory4 option:selected").text());
#         getSubCategoryUl("searchCategory5");
#         var category3 = "001002010002010";
#         if (category3.substring(0, 3) == "002") {
#             $("#searchCategory5").hide();
#             $("#searchCategorySpan5").hide();
#         }else if(category3.substring(0, 3) == "003" || category3.substring(0, 3) == "004"){
#             $("#searchCategory5").hide();
#             $("#searchCategorySpan5").hide();
#
#         }
#     }else{//그외... 3뎁스까지만 선택된 경우 (default)
#         $("#categoryNameSpan").html($("#searchCategory3 option:selected").text());
#         getSubCategoryUl("searchCategory4");
#         var category3 = "001002010002010";
#         if (category3.substring(0, 3) == "002") {
#             $("#searchCategory5").hide();
#             $("#searchCategorySpan5").hide();
# 		}else if(category3.substring(0, 3) == "003" || category3.substring(0, 3) == "004"){
#             $("#searchCategory5").hide();
#             $("#searchCategorySpan5").hide();
#
# 		}
#
#     }
#
#     // 하위카테고리 목록
#     function getSubCategoryUl(targetCategory){
#         if($("#"+ targetCategory +" option").length > 1){//하위카테고리가 있는 경우에만 show
#             $("#subCategoryDiv").show();
#             $("#"+ targetCategory +" option").each(function(i, item){
#                 if(item.value != ""){
#                     var categoryStr = "<li><a href=\""+ $.Resource.domainWeb +"/product/productList.do?categoryCode="+ item.value +"\"><span>"+ item.text +"</span></a></li>"
#                     $("#subCategoryUl").append(categoryStr);
#                 }
#             });
#         }
#     }
#
#     //Paging
#     // 페이지 이동
#     goPage = function (cPage)
#     {
#         if($("#list").hasClass("list"))
#         {
#             $("#viewType").val("list");
#         }
#         else
#         {
#             $("#viewType").val("image");
#         }
#
#         var $dataForm = $("#dataForm");
#         $dataForm.find("input[name='cPage']").val(cPage);
#         $dataForm.attr({"action": $.Resource.domainWeb + "/product/productList.do", "target":"_self", "method":"get"}).submit();
#     };
#
#     goBrandSearch = function(val)
#     {
#         var $dataForm = $("#dataForm");
#         $dataForm.find("input[name='cPage']").val(1);
#         $dataForm.find("input[name='searchBrand']").val(val);
#         $dataForm.attr({"action":$.Resource.domainWeb+"/product/productList.do", "target":"_self", "method":"get"}).submit();
#     }
#
#     /**
#     *
#     * 공통 function 으로 사용하기 위해 product.js 로 이전,
#     * 2015-07-23, 이상준
#     *
#     goDetail = function (pCode, adultCheck)
#     {
#         var adultcheck_confirm = '';
#         var $dataForm = $("#dataForm");
#         $dataForm.find("input[name='productCode']").val(pCode);
#
#         if(adultCheck == 'Y' && adultcheck_confirm != 'confirm'){
#             if(confirm('미성년자 구매불가상품입니다. 성인인증 후 열람하실 수 있습니다. 계속하시겠습니까?')){
#                 fnAdultCheckPopup();
#             }
#         }
#         else{
#             $dataForm.attr({"action": $.Resource.domainWeb + "/product/productView.do", "target":"_self", "method":"get"}).submit();
#         }
#     }
#     */
#
#     $('#sliderSectionList').productSlidr({
#         // autoPlay: false,
#         visibleLength: 3,
#         sliderHeight: '472px',
#         navPrev: '#prevSectionList',
#         navNext: '#nextSectionList'
#     });
#
#     // add product list badge
#     $('.list-product .item, .list-product-b .item').addBadge({
#         target: '.thumb'
#     });
#
#     $(".brand-all").click(function(e){
#         e.preventDefault();
#         $(".brand-all .icon").toggleClass("minus");
#         $(".brand-list").toggleClass("active");
#     });
#
#
# });
# </script>
# <form id="wingForm" name="wingForm"><input id="A_IDX" name="A_IDX" type="hidden" value=""/></form>
# <form id="wingForm2" name="wingForm2"><input id="A_IDX" name="A_IDX" type="hidden" value=""/></form>
# <!-- global vars. -->
# <script>
# $.params = ($.params !== undefined) ? $.params : []; //for parameters
#
# var totalCategoryList = ""; // 카테고리 전체보기 html
#
#
#
# $.params.categoryHtml = "/cateHtml/cate_mall_2018.html";
# </script>
# <script>
# $(function () {
#
# 	// 메뉴 이동처리
#     goSubMenuUrl = function(categoryCode)
#     {
#         location.href =  $.Resource.domainSsl + "/product/productList.do?categoryCode="+categoryCode;
#     };
#
#     // 미니샵 메뉴 이동처리
#     goMiniSubMenuUrl = function(categoryCode, V_IDX)
#     {
#         location.href =  $.Resource.domainSsl + "/miniShop/miniShopProductList.do?categoryCode="+categoryCode+"&V_IDX="+V_IDX;
#     };
#
#     goSubMain = function(categoryCode)
#     {
#         location.href =  $.Resource.domainSsl + "/subMainIndex.do?categoryCode="+categoryCode;
#     };
#
#     goskyCraperUrl = function(idx, type, count)
#     {
#
#     	if(idx == '')
# 		{
#     		alert('등록된 정보가 없습니다.');
# 		}
#     	else
# 		{
#     		var $frm = $("#wingForm");
#
#     		var target = '_self';
#             if(type == 'B')
#             {
#                   target = '_blank';
#             }
#
#     		if($frm.context==document){
#     			var $frm = $("#wingForm2");
#     			$("#wingForm2 #A_IDX").val(idx);
#     		}else{
#     			$("#wingForm #A_IDX").val(idx);
#     		}
#
#     		$frm.target = target;
#     		if(count == null){
#     			count = "1";
#     		}
#     		var bannercode = "WB"+ count;
#     		goBannerTracking('/modifySkyCraper.do', bannercode, $frm);
#
#             //$frm.attr({"action": $.Resource.domainWeb + "/modifySkyCraper.do", "target":target, "method":"post"}).submit();
# 		}
#
#     };
#
#    /* var _ua = (navigator.userAgent || navigator.vendor || window.opera);
#     if (_ua.indexOf("Firefox") < 0 && typeof document.oncontextmenu == 'object') {
#         document.oncontextmenu = function(e) {
#            alert("오른쪽 버튼을 이용할 수 없습니다.");
#            return false;
#         };
#     }*/
# });
#
# // google analytics
# (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
# (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
# m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
# })(window,document,'script','//www.google-analytics.com/analytics.js','ga');
#
# ga('create', 'UA-6690877-1', 'auto');
# ga('send', 'pageview');
# </script>
# <script src="https://wcs.naver.net/wcslog.js" type="text/javascript"></script> <script type="text/javascript"> if(!wcs_add) var wcs_add = {}; wcs_add["wa"] = "2eb5ade4b04a20"; wcs_do(); </script>
# <script type="text/javascript">
# /* <![CDATA[ */
# var google_conversion_id = 835056324;
# var google_custom_params = window.google_tag_params;
# var google_remarketing_only = true;
# /* ]]> */
# </script>
# <script src="//www.googleadservices.com/pagead/conversion.js" type="text/javascript">
# </script>
# <noscript>
# <div style="display:inline;">
# <img alt="" height="1" src="//googleads.g.doubleclick.net/pagead/viewthroughconversion/835056324/?guid=ON&amp;script=0" style="border-style:none;" width="1">
# </img></div>
# </noscript>
# </body>
# </html>

# %%
targetValue = htmlObj.find_all(name="p",attrs = {"class":"name"})
targetValue
# Out:
# [<p class="name">[애플] 맥북프로 16인치 (2.3GHZ 8core i9/16GB/1TB 터치바)</p>,
#  <p class="name">[애플] Macbook Pro 13형 M1 8코어/8GB 메모리/512GB 실버</p>,
#  <p class="name">[애플] 맥북에어 13형 M1 8코어/8GB/7코어 그래픽/256GB 실버</p>,
#  <p class="name" style="white-space: normal; text-align: left; word-wrap: break-word; display: -webkit-box; -webkit-line-clamp: 2; -webkit-box-orient: vertical;">
#  													[애플] 맥북프로 16인치 (2.3GHZ 8core i9/16GB/1TB 터치바)</p>,
#  <p class="name" style="white-space: normal; text-align: left; word-wrap: break-word; display: -webkit-box; -webkit-line-clamp: 2; -webkit-box-orient: vertical;">
#  													[애플] Macbook Pro 13형 M1 8코어/8GB 메모리/512GB 실버</p>,
#  <p class="name" style="white-space: normal; text-align: left; word-wrap: break-word; display: -webkit-box; -webkit-line-clamp: 2; -webkit-box-orient: vertical;">
#  													[애플] 맥북에어 13형 M1 8코어/8GB/7코어 그래픽/256GB 실버</p>,
#  <p class="name" style="white-space: normal; text-align: left; word-wrap: break-word; display: -webkit-box; -webkit-line-clamp: 2; -webkit-box-orient: vertical;">
#  													[애플] Macbook Pro 13형 M1 8코어/8GB 메모리/256GB 실버</p>,
#  <p class="name" style="white-space: normal; text-align: left; word-wrap: break-word; display: -webkit-box; -webkit-line-clamp: 2; -webkit-box-orient: vertical;">
#  													[애플] Macbook Pro 13형 M1 8코어/8GB 메모리/256GB 스페이스 그레이</p>,
#  <p class="name" style="white-space: normal; text-align: left; word-wrap: break-word; display: -webkit-box; -webkit-line-clamp: 2; -webkit-box-orient: vertical;">
#  													[애플] 맥북에어 13형 M1 8코어/8GB/8코어 그래픽/512GB 실버</p>,
#  <p class="name" style="white-space: normal; text-align: left; word-wrap: break-word; display: -webkit-box; -webkit-line-clamp: 2; -webkit-box-orient: vertical;">
#  													[애플] 맥북에어 13형 M1 8코어/8GB/7코어 그래픽/256GB 골드</p>,
#  <p class="name" style="white-space: normal; text-align: left; word-wrap: break-word; display: -webkit-box; -webkit-line-clamp: 2; -webkit-box-orient: vertical;">
#  													[애플] 맥북에어 13형 M1 8코어/8GB/8코어 그래픽/512GB 스페이스 그레이</p>,
#  <p class="name" style="white-space: normal; text-align: left; word-wrap: break-word; display: -webkit-box; -webkit-line-clamp: 2; -webkit-box-orient: vertical;">
#  													[애플] Macbook Pro 13형 M1 8코어/8GB 메모리/512GB 스페이스 그레이</p>,
#  <p class="name" style="white-space: normal; text-align: left; word-wrap: break-word; display: -webkit-box; -webkit-line-clamp: 2; -webkit-box-orient: vertical;">
#  													[애플] 맥북에어 13형 M1 8코어/8GB/8코어 그래픽/512GB 골드</p>]

# %%
pClass = targetValue[0].find(name="p",attrs = {"class":"name"})
pClass
