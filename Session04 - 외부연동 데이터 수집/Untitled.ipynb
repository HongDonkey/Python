# %% [markdown]
# # 1. 라이브러리 선언

# %%
import pandas as pd

# %% [markdown]
# # 2. 공공데이터 (파일데이터 불러오기)

# %%
pirLirUrl = "https://www.data.go.kr/cmm/cmm/fileDownload.do?atchFileId=FILE_000000002340074&fileDetailSn=1&dataNm=%ED%95%9C%EA%B5%AD%EC%A3%BC%ED%83%9D%EA%B8%88%EC%9C%B5%EA%B3%B5%EC%82%AC_%EC%A7%80%EC%97%AD%EB%B3%84%20PIR%20%EB%B0%8F%20LIR"

# %%
indata = pd.read_csv(pirLirUrl, encoding="ms949")
indata.tail()
# Out:
#        연도  월  전국PIR  서울PIR  부산PIR  대구PIR  인천PIR  광주PIR  대전PIR  울산PIR  ...  \
# 190  2020  1   4.47   5.44   4.84   5.16   4.39   4.76   4.52   4.11  ...
# 191  2020  2   4.45   5.02   5.04   4.92   4.49   4.52   4.36   3.90  ...
# 192  2020  3   4.76   5.12   5.22   5.20   4.76   5.04   4.74   4.11  ...
# 193  2020  4   4.83   4.95   5.67   5.91   4.78   5.41   5.40   4.44  ...
# 194  2020  5   4.56   4.88   7.01   5.44   4.56   3.16   4.72   5.77  ...
#
#      세종LIR  경기LIR  강원LIR  충북LIR  충남LIR  전북LIR  전남LIR  경북LIR  경남LIR  제주LIR
# 190   2.63   2.39   1.90   1.76   1.87   1.94   1.85   1.80   2.02   2.13
# 191   2.69   2.34   1.96   1.87   1.89   1.83   1.68   1.69   1.91   2.07
# 192   2.22   2.56   2.13   1.98   2.03   1.97   1.89   1.95   2.23   2.27
# 193   1.73   2.54   2.13   2.09   2.14   2.11   1.94   1.97   2.06   1.85
# 194   0.00   2.23   2.44   1.08   1.65   1.04   1.68   1.99   2.17   0.96
#
# [5 rows x 38 columns]

# %% [markdown]
# # 2번에 대한 실습 (공공데이터포털에서 한국감정원 오피스텔 동향조사 현황자료를 검색하여 데이터타입자료를 불러오세요)

# %%
import pandas as pd
#패키지 임포트

url = "https://www.data.go.kr/cmm/cmm/fileDownload.do?atchFileId=FILE_000000002312933&fileDetailSn=1&dataNm=%ED%95%9C%EA%B5%AD%EB%B6%80%EB%8F%99%EC%82%B0%EC%9B%90_%EC%98%A4%ED%94%BC%EC%8A%A4%ED%85%94%20%EC%A0%84%EC%84%B8%EA%B0%80%EA%B2%A9(%EC%9B%94%EB%B3%84)_20201014"
# 다운로드 링크를 url변수에 지정
indata = pd.read_csv(url, encoding="ms949")
# csv파일을 읽어올 링크와 인코딩 형식을 indata변수에 담음
indata
# 출력

# %% [markdown]
# # 국가통계포털 API데이터 불러오기 (횡단면 조회)

# %%
import pandas as pd

url = "https://kosis.kr/openapi/statisticsData.do?method=getList&apiKey=ZDBkZjU4MzlkOWQ3MDAzYTZkZDdhYjBjZDM0ZDE0MTY=&format=json&jsonVD=Y&userStatsId=hdk2006/101/DT_1B040A3/2/1/20210412145641&prdSe=M&newEstPrdCnt=1"
json = pd.DataFrame()
try:
    json = pd.read_json(url)
except Exception as e:
    print(e)
json

# %% [markdown]
# # 국가통계포털 API데이터 불러오기 (시계열 조회, 총인구수 * 서울특별시)

# %%
import pandas as pd
url = "https://kosis.kr/openapi/statisticsData.do?method=getList&apiKey=ZDBkZjU4MzlkOWQ3MDAzYTZkZDdhYjBjZDM0ZDE0MTY=&format=json&jsonVD=Y&userStatsId=hdk2006/101/DT_1B040A3/2/1/20210412150415_1&prdSe=M&newEstPrdCnt=3"
json = pd.DataFrame()
try:
    json = pd.read_json(url)
except Exception as e:
    print(e)
json

# %% [markdown]
# # 1행 82500 2008
# # 2행 72500 2010

# %%
columnList = [] 
rowList = []  # 리스트 선언

# %%
columnList.append("82500")
columnList.append("2008")  # 컬럼 리스트에 값 추가
rowList.append(columnList) # 로우 리스트에 컬럼리스트를 추가

# %%
columnList=[]  # 컬럼리스트 초기화
columnList.append("72500")
columnList.append("2010") #컬럼 리스트 값 추가
rowList.append(columnList)  # 로우 리스트에 컬럼리스트 추가

pd.DataFrame(rowList) # 출력
# Out:
#        0     1
# 0  82500  2008
# 1  72500  2010

# %%
pip install bs4
# Out:
# ...
#   Created wheel for bs4: filename=bs4-0.0.1-py3-none-any.whl size=1277 sha256=c0bc422d357093d8b975776ff47acabc53e7c5f2987206fd96626c8d161c300d
#   Stored in directory: c:\users\smart-20\appdata\local\pip\cache\wheels\75\78\21\68b124549c9bdc94f822c02fb9aa3578a669843f9767776bca
# Successfully built bs4
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import requests        # API 서비스에 연결
from lxml import html  # parse XML 사용
from bs4 import BeautifulSoup   # 정렬해주는 BeautifulSoup 사용
import pandas as pd

# %%
url="http://openapi.molit.go.kr/OpenAPI_ToolInstallPackage/service/rest/RTMSOBJSvc/getRTMSDataSvcAptTradeDev"
response = requests.get(url+queryParams)
response.encoding="utf-8"


xmlobj = BeautifulSoup(response.text,"lxml-xml") #parser
xmlobj

# %%
import requests        # API 서비스에 연결
from lxml import html  # parse XML 사용
from bs4 import BeautifulSoup   # 정렬해주는 BeautifulSoup 사용
import pandas as pd
from urllib.request import Request, urlopen
from urllib.parse import urlencode, quote_plus,unquote

API_Key = 'AT33s775KYpJOkUBJu0dxkJuUeIfDIOJRzAH084EQS3JN%2BzFjErLHuk%2FGZa9L4gBTSGCzeA69tI9PwLp7B37IQ%3D%3D' # 서비스 키
url="http://openapi.molit.go.kr/OpenAPI_ToolInstallPackage/service/rest/RTMSOBJSvc/getRTMSDataSvcAptTradeDev" # 실질적인 url 주소
queryParams = '?' + urlencode({          # 아래 3가지 요소를 합한 값
    quote_plus('ServiceKey') : API_Key,  # ServiceKey
    quote_plus('LAWD_CD'): '11110',      # LAWD_CD
    quote_plus('DEAL_YMD'):'201512'      # DEAL_YMD
})

response = requests.get("http://openapi.molit.go.kr/OpenAPI_ToolInstallPackage/service/rest/RTMSOBJSvc/getRTMSDataSvcAptTradeDev?serviceKey=AT33s775KYpJOkUBJu0dxkJuUeIfDIOJRzAH084EQS3JN%2BzFjErLHuk%2FGZa9L4gBTSGCzeA69tI9PwLp7B37IQ%3D%3D&pageNo=1&numOfRows=10&LAWD_CD=11110&DEAL_YMD=201512")
#response는 url?ServiceKey&pageNo=1&numOfRows=10(item의 규격)&LAWD_CD&DEAL_YMD 를 합한 값을 가져오는 변수
response.encoding='utf-8'     # response의 인코딩 형식 지정
pageSource = response.text
xmlobj = BeautifulSoup(pageSource,"lxml-xml") #태그와 내용을 모두 보여줌

rowList = []                    # 행 내용을 담을 빈 배열을 생성
columnList = []                 # 열 내용을 담을 빈 배열을 생성
rows = xmlobj.findAll('item')   # "items" 안에 모든 내용을 담을 rows라는 변수를 생성

for i in range(0, len(rows)): 
    columns = rows[i].findAll() # 하나의 "item"의 모든 내용을 담을 columns라는 변수를 생성
    
    for j in range(0, len(columns)):  
        columnValue = columns[j].text    # item의 태그를 제외한 내용만을 담는 columnValue생성
        columnList.append(columnValue)   # 내용들을 columnList에 추가함
    rowList.append(columnList)           # 하나의 "item"이 columnList에 추가가 완료 되면 하나의 행(rows)이 완성됨 
    columnList = []                      # 다음 "item"값들을 넣어주기 위해 columnList를 초기화
    
homePriceSeoul = pd.DataFrame(rowList)  # 만들어진 표를 homePriceSeoul 변수에 담음
homePriceSeoul                          # 출력

columnHead = []               #item의 태그만을 받아 제목으로 쓰기위해 빈 리스트 columnHead를 만들어줌
for i in range(0, len(columns)):
    eachColumns = columns[i]        # item 하나당 받은 태그의 내용을 eachColumns 변수에 넣어줌
    columnHead.append(eachColumns.name)  # eachColumns의 태그이름만을 columnHead에 추가해줌
homePriceSeoul.columns = columnHead # homePriceSeoul테이블의 columns
homePriceSeoul                      # 출력
# Out:
#          거래금액  건축년도     년      도로명 도로명건물본번호코드 도로명건물부번호코드 도로명시군구코드 도로명일련번호코드  \
# 0      82,500  2008  2015    사직로8길      00004      00000    11110        03
# 1      60,000  1981  2015  세종대로23길      00047      00000    11110        02
# 2     130,000  2004  2015    경희궁2길      00005      00005    11110        01
# 3     105,000  2004  2015    사직로8길      00024      00000    11110        05
# 4     120,000  2003  2015    사직로8길      00020      00000    11110        05
# 5      17,000  2014  2015      대학로      00047      00000    11110        05
# 6      17,000  2014  2015      대학로      00047      00000    11110        05
# 7      57,000  2006  2015   혜화로3가길      00030      00000    11110        01
# 8      44,000  1995  2015     창경궁로      00265      00000    11110        07
# 9      52,000  1995  2015     창경궁로      00265      00000    11110        07
#
#   도로명지상지하코드    도로명코드  ...                    아파트   월   일        일련번호    전용면적  \
# ...

# %%
# 혁중이 형이 짠 컬럼이름 정해주는 코드
# columnNameList = []
# for i in range(0, len(columns)):
#         eachColumn = columns[i]
#         columnNameList.append(eachColumn.name.strip())  # or text.strip() 공백제거
# housePriceData.columns = columnNameList
# housePriceData

# %% [markdown]
# # 금융 검색 후 “시도별 금융권 대출잔액 수준별 인구＂

# %%
import pandas as pd
#
url = "https://kosis.kr/openapi/statisticsData.do?method=getList&apiKey=ZDBkZjU4MzlkOWQ3MDAzYTZkZDdhYjBjZDM0ZDE0MTY=&format=json&jsonVD=Y&userStatsId=hdk2006/101/DT_1MA0028/2/1/20210412192956&prdSe=Y&newEstPrdCnt=1"
# 시도별 금융권 대출잔액 수준별 인구의 url을 변수로 지정
json = pd.DataFrame()
# DataFrame 형식으로 나타냄
try:
    json = pd.read_json(url)
# url의 자료를 json을 불러와서 나타냄
except Exception as e:
    print(e)
# 오류가 있다면 오류구문 출력
json
# 결과출력
# Out:
#                    TBL_NM  ITM_NM_ENG ITM_ID  ORG_ID  UNIT_NM_ENG C1_OBJ_NM  \
# 0     시도별 금융권 대출잔액 수준별 인구  Population   T001     101  1000Persons       시도별
# 1     시도별 금융권 대출잔액 수준별 인구  Population   T001     101  1000Persons       시도별
# 2     시도별 금융권 대출잔액 수준별 인구  Population   T001     101  1000Persons       시도별
# 3     시도별 금융권 대출잔액 수준별 인구  Population   T001     101  1000Persons       시도별
# 4     시도별 금융권 대출잔액 수준별 인구  Population   T001     101  1000Persons       시도별
# ...                   ...         ...    ...     ...          ...       ...
# 1183  시도별 금융권 대출잔액 수준별 인구  Population   T001     101  1000Persons       시도별
# 1184  시도별 금융권 대출잔액 수준별 인구  Population   T001     101  1000Persons       시도별
# 1185  시도별 금융권 대출잔액 수준별 인구  Population   T001     101  1000Persons       시도별
# 1186  시도별 금융권 대출잔액 수준별 인구  Population   T001     101  1000Persons       시도별
# 1187  시도별 금융권 대출잔액 수준별 인구  Population   T001     101  1000Persons       시도별
#
# ...

# %% [markdown]
# # 리스트에서 데이터프레임 생성하기

# %%
import pandas as pd
rowFirst = ["A01", 202015, 100]
rowSecond = ["A02", 202016, 110]
rowThird = ["A03",202017,120]

# %%
df1 = pd.DataFrame([rowFirst,rowThird,rowSecond])

# %%
df1.columns = ["RegionID" , "YEARWEEK", "QTY"]
columnNameList = df1

# %%
columnFirst = ["A0","A01","A01"]
columnSecond = [202015, 202016, 202017]
columnThird = [100,110,150]

# %%
df2 = pd.DataFrame(zip(columnFirst, columnSecond, columnThird),columns = columnNameList)

# %%
df2.columns = columnNameList

# %%
df2
# Out:
#   (A01, 202015, 100)  (A03, 202017, 120)  (A02, 202016, 110)
# 0                 A0              202015                 100
# 1                A01              202016                 110
# 2                A01              202017                 150

# %% [markdown]
# # 타겟 URL 선언 및 접속

# %%
from bs4 import BeautifulSoup # 태그를 이쁘게 쓰게해준다
import requests # 웹페이지에 접속요청

# %%
targetUrl = "https://sparkkorea.com/%ED%80%B4%EC%A6%88/"

# %%
resp = requests.get(targetUrl)
resp.encoding = 'utf-8'

# %%
html = resp.text

htmlObj = BeautifulSoup(html, "html.parser")

# %%
htmlObj
# Out:
# <!DOCTYPE html>
#
# <html lang="ko-KR">
# <head>
# <meta charset="utf-8"/>
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <link href="http://gmpg.org/xfn/11" rel="profile"/>
# <link href="https://sparkkorea.com/xmlrpc.php" rel="pingback"/>
# <title>퀴즈 – 스파크 코리아</title>
# <meta content="max-image-preview:large" name="robots">
# <meta content="QRZVgHsoL23RuwmgmXNuXfO-mUaxCkdvhP2rRvLT270" name="google-site-verification">
# <!-- Async WordPress.com Remote Login -->
# <script id="wpcom_remote_login_js">
# var wpcom_remote_login_extra_auth = '';
# function wpcom_remote_login_remove_dom_node_id( element_id ) {
# 	var dom_node = document.getElementById( element_id );
# 	if ( dom_node ) { dom_node.parentNode.removeChild( dom_node ); }
# }
# function wpcom_remote_login_remove_dom_node_classes( class_name ) {
# 	var dom_nodes = document.querySelectorAll( '.' + class_name );
# 	for ( var i = 0; i < dom_nodes.length; i++ ) {
# ...

# %% [markdown]
# # 태그값 접근하기

# %%
targetParent = htmlObj.find(name="div", attrs = {"id":"id_spark_quiz"})
targetParent
# Out:
# <div class="class_spark_quiz" id="id_spark_quiz">
# <h1>Spark 퀴즈 </h1>
# <a href="https://forms.gle/Fw49w9GhWQChDcZm7"> 6/13 Spark 심화과정 </a>
# <p></p>
# <a href="https://forms.gle/G4TcXm3fKuHLHA6D6"> 6/13 Spark 기본과정 </a>
# <p></p>
# <a href="https://forms.gle/M8gr1kC2ubA3UDVp8"> 6/18 Spark [MAP_FILTER] </a>
# <p></p>
# <a href="https://forms.gle/h8w5mZ4MNaPLCPbi6"> 6/18 Spark GroupBy 심화 </a>
# <p></p>
# <a href="https://forms.gle/q5yL6QHfueDLM5w27"> 6/25 Spark RDD 실전 분석 </a>
# <p></p>
# <a href="https://forms.gle/Gxb4y6LfVYiaLu4M7"> 6/27 Spark RDD 실전 분석2 </a>
# <p></p>
# </div>

# %%
value = [] # 타이틀 값을 넣어줄 리스트
link = [] # 링크 값을 넣어줄 리스트
aTags = targetParent.findAll(name="a") # 태그 A로 시작하는 것을 모두 찾아줌


for i in range(0, len(aTags)):
    title = aTags[i].text     # A태그 안의 내용을 Title변수에 담음
    value.append(title)       # title변수를 value리스트에 추가함
    link2 = aTags[i].attrs["href"]  # A태그 안의 링크를 link2변숭 ㅔ담음
    link.append(link2)              # link2 변수를 link변수에 담음
    
pd.DataFrame(zip (value, link), columns=["퀴즈타이틀","링크"])  # zip을 사용하여 2가지 배열을 하나의 데이터프레임 형식으로 출력함
# Out:
#                        퀴즈타이틀                                   링크
# 0           6/13 Spark 심화과정   https://forms.gle/Fw49w9GhWQChDcZm7
# 1           6/13 Spark 기본과정   https://forms.gle/G4TcXm3fKuHLHA6D6
# 2   6/18 Spark [MAP_FILTER]   https://forms.gle/M8gr1kC2ubA3UDVp8
# 3     6/18 Spark GroupBy 심화   https://forms.gle/h8w5mZ4MNaPLCPbi6
# 4      6/25 Spark RDD 실전 분석   https://forms.gle/q5yL6QHfueDLM5w27
# 5     6/27 Spark RDD 실전 분석2   https://forms.gle/Gxb4y6LfVYiaLu4M7

# %%
value = []
link = []
aTags = targetParent.findAll(name="a")
aTags

for i in range(0, len(aTags)):
    aTags[i].text
# Out:
# [<a href="https://forms.gle/Fw49w9GhWQChDcZm7"> 6/13 Spark 심화과정 </a>,
#  <a href="https://forms.gle/G4TcXm3fKuHLHA6D6"> 6/13 Spark 기본과정 </a>,
#  <a href="https://forms.gle/M8gr1kC2ubA3UDVp8"> 6/18 Spark [MAP_FILTER] </a>,
#  <a href="https://forms.gle/h8w5mZ4MNaPLCPbi6"> 6/18 Spark GroupBy 심화 </a>,
#  <a href="https://forms.gle/q5yL6QHfueDLM5w27"> 6/25 Spark RDD 실전 분석 </a>,
#  <a href="https://forms.gle/Gxb4y6LfVYiaLu4M7"> 6/27 Spark RDD 실전 분석2 </a>]

# %% [markdown]
# # 테이블 스크랩

# %%
import requests, bs4
import pandas as pd

#웹페이지 html 소스 가져오기
resp = requests.get("https://sparkkorea.com/테스트/")
resp.encoding='utf-8'
html = resp.text
htmlObj = bs4.BeautifulSoup(html, 'html.parser')
htmlObj
# Out:
# <!DOCTYPE html>
#
# <html lang="ko-KR">
# <head>
# <meta charset="utf-8"/>
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <link href="http://gmpg.org/xfn/11" rel="profile"/>
# <link href="https://sparkkorea.com/xmlrpc.php" rel="pingback"/>
# <title>테스트 – 스파크 코리아</title>
# <meta content="max-image-preview:large" name="robots">
# <meta content="QRZVgHsoL23RuwmgmXNuXfO-mUaxCkdvhP2rRvLT270" name="google-site-verification">
# <!-- Async WordPress.com Remote Login -->
# <script id="wpcom_remote_login_js">
# var wpcom_remote_login_extra_auth = '';
# function wpcom_remote_login_remove_dom_node_id( element_id ) {
# 	var dom_node = document.getElementById( element_id );
# 	if ( dom_node ) { dom_node.parentNode.removeChild( dom_node ); }
# }
# function wpcom_remote_login_remove_dom_node_classes( class_name ) {
# 	var dom_nodes = document.querySelectorAll( '.' + class_name );
# 	for ( var i = 0; i < dom_nodes.length; i++ ) {
# ...

# %%
columnList = []
rowList = []
tableTag = htmlObj.find(name="table", attrs={"id":"test_table"})
tbodyTag = tableTag.find(name="tbody")
trs = tbodyTag.find_all(name="tr")
for i in range(0, len(trs)):
    
    eachTr = trs[i]
    tds = eachTr.find_all("td")
    
    for j in range(0, len(tds)):
        td = tds[j].text
        
        
        columnList.append(td)
    rowList.append(columnList)
    columnList = []
table = pd.DataFrame(rowList, columns=["학번","이름"])
table
# Out:
#     학번   이름
# 0  101  김효관
# 1  102  이순신
# 2  103  김어진

# %%
from bs4 import BeautifulSoup # 태그를 이쁘게 쓰게해준다
import requests # 웹페이지에 접속요청
import requests, bs4
import pandas as pd

# %%
url = "https://www.alpha.co.kr/product/productList.do?categoryCode=001002010002010"
headers = {'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10.14; rv:71.0) Gecko/20100101 Firefox/71.0'}
data=requests.get(url,headers=headers)
data.text
resp = requests.get(url)
resp.encoding = 'utf-8'

# %%
html = resp.text
htmlObj = BeautifulSoup(html, "html.parser")
columnList = []
rowList = []

# %%
product = htmlObj.find_all(name="p",attrs = {"class":"name"})
price=htmlObj.find_all(name = "p",attrs = {"class":"price-before"})

# %%
for i in range(0, len(product)):
    eachProduct = product[i].text
    for j in range(0, len(price)):
        eachPrice = price[j].text
        columnList.append(eachProduct)
        rowList.append(columnList)
    columnList = []
table = pd.DataFrame(rowList)
table
# Out:
#                                                     0   \
# 0                                           1,630,000원
# 1                                           1,630,000원
# 2                                           1,630,000원
# 3                                           1,630,000원
# 4                                           1,630,000원
# ..                                                 ...
# 359  \r\n\t\t\t\t\t\t\t\t\t\t\t\t\t[애플] 맥북에어 13형 M1...
# 360  \r\n\t\t\t\t\t\t\t\t\t\t\t\t\t[애플] 맥북에어 13형 M1...
# 361  \r\n\t\t\t\t\t\t\t\t\t\t\t\t\t[애플] 맥북에어 13형 M1...
# 362  \r\n\t\t\t\t\t\t\t\t\t\t\t\t\t[애플] 맥북에어 13형 M1...
# 363  \r\n\t\t\t\t\t\t\t\t\t\t\t\t\t[애플] 맥북에어 13형 M1...
#
#                                                     1   \
# 0                                                 None
# 1                                                 None
# 2                                                 None
# 3                                                 None
# ...

# %%
eachProduct = product[2].text
eachProduct
# Out:
# '[애플] 맥북에어 13형 M1 8코어/8GB/7코어 그래픽/256GB 실버'

# %%
price=htmlObj.find_all(name = "p",attrs = {"class":"price-before"})
len(price)
# Out:
# 13

# %%
eachPrice = price[1].text

# %%
# <p class="price-before">1,630,000원</p>

# %% [markdown]
# # 동원홈페이지에서 냉동식품 부분의 링크를 가져와 데이터프레임 형식으로 만들기

# %%
from bs4 import BeautifulSoup # 태그를 이쁘게 쓰게해준다
import requests # 웹페이지에 접속요청
import requests, bs4
import pandas as pd

url = "https://www.dongwonmall.com/category/main.do?cate_id=0111005600010001"     # 데이터를 조회할 url (동원홈페이지)
headers = {'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10.14; rv:71.0) Gecko/20100101 Firefox/71.0'}
# 나는python으로 접속한게 아니라 user-agent를 바꿔서... Mac에서 접속한.... 일반 사용자다!
data=requests.get(url,headers=headers) # response가 200이 아닐 경우에 사용한다(response를 200으로 만들어줌) 
data.text  # url 코드 확인

resp = requests.get(url) # response가 200일 경우 그대로 사용
resp.encoding = "utf-8" # 한글 텍스트를 보기 위해 utf-8 형식으로 인코딩
resp.text   # url 코드 확인

html = resp.text # 조회하고 싶은 url의 코드를 가져옴
htmlObj = BeautifulSoup(html, "html.parser")  # Beautifulsoup를 사용하여 html을 태그 별로 나누어 보여줌


productList = []  # 제품정보를 받을 빈 리스트 생성
priceList = []   # 가격정보를 받을 빈 리스트 생성
product = htmlObj.find_all(name="span",attrs = {"class":"lktxt"}) # 태그가 span이고 아이디가 class:lktxt인 요소들을 가져옴


for i in range(0, len(product)):
    eachProduct=product[i].text # 제품정보의 내용들을 eachProduct 변수에담음
    renameProduct = eachProduct.replace("\n","") # 제품명 앞과 뒤에 "\n"이 붙어나오기 때문에 해당 문자열을 제거
    productList.append(renameProduct) # 이름을 수정한 제품정보를 productList에 담음
print(productList)  # 출력확인

priceInfo = htmlObj.find_all(name="div" ,attrs ={"class":"listtype_prc_wrap"}) # 태그가 div이고 아이디가 class:listtype_prc_wrap 요소들을 가져옴

for i in range(0,len(productList)):
    prc_new=priceInfo[i].find(name="span", attrs ={"class":"prc_new"}) # 태그가 span이고 아이디가 class:prc_new 요소들을 가져옴
    emPrice = prc_new.find(name="em") # 태그가 name인 요소들을 가져옴
    price = emPrice.text #price 변수에 가격이 포함된 내용을 담음
    priceList.append(price) # priceList에 가격을 추가해줌
print(priceList) # 출력확인
pd.DataFrame(zip (productList, priceList), columns=["상품명","가격"]) # 2 리스트를 DataFrame형식으로 출력하고 컬럼명은 상품명과 가격으로 지정

# %%
id="hol_jan"></tr><tr data-date="1609459200000" 
data-mask="1" 
id="tr1">
<th class="nw">1월 1일</th>
<td class="nw">금요일</td>
<td><a href="/holidays/south-korea/new-year-day">New Year's Day</a></td>
<td>Public Holiday</td></tr>

# %%
from bs4 import BeautifulSoup # 태그를 이쁘게 쓰게해준다
import requests # 웹페이지에 접속요청
import requests, bs4
import pandas as pd

url = "https://www.timeanddate.com/holidays/south-korea/"     # 데이터를 조회할 url
headers = {'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10.14; rv:71.0) Gecko/20100101 Firefox/71.0'}
# 나는python으로 접속한게 아니라 user-agent를 바꿔서... Mac에서 접속한.... 일반 사용자다!
data=requests.get(url,headers=headers) # response가 200이 아닐 경우에 사용한다(response를 200으로 만들어줌) 
resp = requests.get(url) # response가 200일 경우 그대로 사용
resp.encoding = "utf-8"  # 한글 텍스트를 보기 위해 utf-8 형식으로 인코딩

html = resp.text  # 조회하고 싶은 url의 코드를 가져옴

htmlObj = BeautifulSoup(html, "html.parser") # Beautifulsoup를 사용하여 html을 태그 별로 나누어 보여줌

tbody=htmlObj.find_all(name="table")  # table태그의 요소들을 가져옴
thbody=htmlObj.find_all(name = "th", attrs = {"class":"nw"}) # 태그가 th이고 아이디가 class=nw인 요소들을 가져옴
dateList = [] # 날짜정보를 받을 빈 리스트 생성
for i in range(0, len(thbody)):
    tDate=thbody[i].text  # 날짜 정보의 내용만을 tDate변수에 담음
    dateList.append(tDate) # dateList에 날짜 정보의 내용들을 차례로 담음
print(dateList) # 출력확인

weeksList=[] # 요일정보를 받을 빈 리스트 생성
nameList=[] # 기념일정보를 받을 빈 리스트 생성
typeList=[] # 국가지정공휴일정보를 받을 빈 리스트 생성
tdType = tbody[0].find_all(name="td") # td태그의 요소들을 tdType 변수에 담음
for i in range(0,len(tdType),+3): # 요일정보, 기념일정보, 국가지정공휴일정보가 반복되기 때문에 하나의 반복문으로 추출
# ex)   
# <td class="nw">금요일</td>,
# <td><a href="/holidays/south-korea/new-year-day">New Year's Day</a></td>,
# <td>Public Holiday</td>,
# <td class="nw">목요일</td>,
# <td><a href="/holidays/south-korea/seollal-holiday-1">Seollal Holiday</a></td>


    tdweeks=tdType[i].text     
    weeksList.append(tdweeks) # 요일정보를 weeksList에 담음
    
    
    tdname=tdType[i+1].text
    nameList.append(tdname) # 기념일정보를 nameList에 담음
    

    tdtype=tdType[i+2].text
    typeList.append(tdtype)  # 국가지정공휴일정보를 typeList에 담음
    
    
print(weeksList) # 출력확인
print(nameList) # 출력확인
print(typeList) # 출력확인
pd.DataFrame(zip (dateList, weeksList,nameList,typeList), columns=["Date","Weeks","Name","Type"]) # 4 리스트를 DataFrame형식으로 출력하고 컬럼명은 Date,Weeks,Name,Type 으로 지정
# Out:
# ['1월 1일', '2월 11일', '2월 12일', '2월 13일', '2월 14일', '3월 1일', '3월 20일', '4월 5일', '5월 1일', '5월 5일', '5월 8일', '5월 15일', '5월 19일', '6월 6일', '6월 21일', '7월 17일', '8월 15일', '9월 20일', '9월 21일', '9월 22일', '9월 23일', '10월 1일', '10월 3일', '10월 9일', '10월 31일', '12월 22일', '12월 24일', '12월 25일', '12월 31일']
# ['금요일', '목요일', '금요일', '토요일', '일요일', '월요일', '토요일', '월요일', '토요일', '수요일', '토요일', '토요일', '수요일', '일요일', '월요일', '토요일', '일요일', '월요일', '화요일', '수요일', '목요일', '금요일', '일요일', '토요일', '일요일', '수요일', '금요일', '토요일', '금요일']
# ...

# %%
<tr data-date="1609459200000" data-mask="1" id="tr1"><th class="nw">1월 1일</th><td class="nw">금요일</td><td><a href="/holidays/south-korea/new-year-day">New Year's Day</a></td><td>Public Holiday</td></tr><tr id="hol_feb"></tr>
<tr data-date="1613001600000" data-mask="1" id="tr3"><th class="nw">2월 11일</th><td class="nw">목요일</td><td><a href="/holidays/south-korea/seollal-holiday-1">Seollal Holiday</a></td><td>Public Holiday</td></tr>
<tr data-date="1613088000000" data-mask="1" id="tr4"><th class="nw">2월 12일</th><td class="nw">금요일</td><td><a href="/holidays/south-korea/seollal-holiday-2">Seollal</a></td><td>Public Holiday</td></tr><tr data-date="1613174400000" data-mask="1" id="tr5"><th class="nw">2월 13일</th><td class="nw">토요일</td><td><a href="/holidays/south-korea/seollal-holiday-3">Seollal Holiday</a></td><td>Public Holiday</td></tr><tr data-date="1613260800000" data-mask="32" id="tr6"><th class="nw">2월 14일</th><td class="nw">일요일</td><td><a href="/holidays/south-korea/valentines-day">Valentine's Day</a></td><td>Observance</td></tr><tr id="hol_mar"></tr><tr data-date="1614556800000" data-mask="1" id="tr8"><th class="nw">3월 1일</th><td class="nw">월요일</td><td><a href="/holidays/south-korea/independence-movement-day">Independence Movement Day</a></td><td>National holiday</td></tr><tr data-date="1616265451000" data-mask="256" id="tr9"><th class="nw">3월 20일</th><td class="nw">토요일</td><td><a href="/calendar/march-equinox.html">March Equinox</a></td><td>Season</td></tr><tr id="hol_apr"></tr><tr data-date="1617580800000" data-mask="16" id="tr11"><th class="nw">4월 5일</th><td class="nw">월요일</td><td><a href="/holidays/south-korea/arbor-day">Arbor Day</a></td><td>Observance</td></tr><tr id="hol_may"></tr><tr data-date="1619827200000" data-mask="4194304" id="tr13"><th class="nw">5월 1일</th><td class="nw">토요일</td><td><a href="/holidays/south-korea/labor-day">Labor Day</a></td><td>Bank Holiday</td></tr><tr data-date="1620172800000" data-mask="1" id="tr14"><th class="nw">5월 5일</th><td class="nw">수요일</td><td><a href="/holidays/south-korea/childrens-day">Children's Day</a></td><td>Public Holiday</td></tr><tr data-date="1620432000000" data-mask="16" id="tr15"><th class="nw">5월 8일</th><td class="nw">토요일</td><td><a href="/holidays/south-korea/parents-day">Parents' Day</a></td><td>Observance</td></tr><tr data-date="1621036800000" data-mask="16" id="tr16"><th class="nw">5월 15일</th><td class="nw">토요일</td><td><a href="/holidays/south-korea/teachers-day">Teacher's Day</a></td><td>Observance</td></tr><tr data-date="1621382400000" data-mask="1" id="tr17"><th class="nw">5월 19일</th><td class="nw">수요일</td><td><a href="/holidays/south-korea/buddha-birthday">Buddha's Birthday</a></td><td>Public Holiday</td></tr><tr id="hol_jun"></tr><tr data-date="1622937600000" data-mask="1" id="tr19"><th class="nw">6월 6일</th><td class="nw">일요일</td><td><a href="/holidays/south-korea/memorial-day">Memorial Day</a></td><td>Public Holiday</td></tr><tr data-date="1624278729000" data-mask="256" id="tr20"><th class="nw">6월 21일</th><td class="nw">월요일</td><td><a href="/calendar/june-solstice.html">June Solstice</a></td><td>Season</td></tr><tr id="hol_jul"></tr><tr data-date="1626480000000" data-mask="16" id="tr22"><th class="nw">7월 17일</th><td class="nw">토요일</td><td><a href="/holidays/south-korea/constitution-day">Constitution Day</a></td><td>Observance</td></tr><tr id="hol_aug"></tr><tr data-date="1628985600000" data-mask="1" id="tr24"><th class="nw">8월 15일</th><td class="nw">일요일</td><td><a href="/holidays/south-korea/liberation-day">Liberation Day</a></td><td>National holiday</td></tr><tr id="hol_sep"></tr><tr data-date="1632096000000" data-mask="1" id="tr26"><th class="nw">9월 20일</th><td class="nw">월요일</td><td><a href="/holidays/south-korea/mid-autumn-festival-day-1">Chuseok Holiday</a></td><td>Public Holiday</td></tr><tr data-date="1632182400000" data-mask="1" id="tr27"><th class="nw">9월 21일</th><td class="nw">화요일</td><td><a href="/holidays/south-korea/mid-autumn-festival-day-2">Chuseok</a></td><td>Public Holiday</td></tr><tr data-date="1632268800000" data-mask="1" id="tr28"><th class="nw">9월 22일</th><td class="nw">수요일</td><td><a href="/holidays/south-korea/mid-autumn-festival-day-3">Chuseok Holiday</a></td><td>Public Holiday</td></tr><tr data-date="1632370871000" data-mask="256" id="tr29"><th class="nw">9월 23일</th><td class="nw">목요일</td><td><a href="/calendar/september-equinox.html">September Equinox</a></td><td>Season</td></tr><tr id="hol_oct"></tr><tr data-date="1633046400000" data-mask="16" id="tr31"><th class="nw">10월 1일</th><td class="nw">금요일</td><td><a href="/holidays/south-korea/armed-forces-day">Armed Forces Day</a></td><td>Observance</td></tr><tr data-date="1633219200000" data-mask="1" id="tr32"><th class="nw">10월 3일</th><td class="nw">일요일</td><td><a href="/holidays/south-korea/national-foundation-day">National Foundation Day</a></td><td>National holiday</td></tr><tr data-date="1633737600000" data-mask="1" id="tr33"><th class="nw">10월 9일</th><td class="nw">토요일</td><td><a href="/holidays/south-korea/hangeul-day">Hangeul Proclamation Day</a></td><td>National holiday</td></tr><tr data-date="1635638400000" data-mask="32" id="tr34"><th class="nw">10월 31일</th><td class="nw">일요일</td><td><a href="/holidays/south-korea/halloween">Halloween</a></td><td>Observance</td></tr><tr id="hol_nov"></tr><tr id="hol_dec"></tr><tr data-date="1640134758000" data-mask="256" id="tr37"><th class="nw">12월 22일</th><td class="nw">수요일</td><td><a href="/calendar/december-solstice.html">December Solstice</a></td><td>Season</td></tr><tr data-date="1640304000000" data-mask="16" id="tr38"><th class="nw">12월 24일</th><td class="nw">금요일</td><td><a href="/holidays/south-korea/christmas-eve">Christmas Eve</a></td><td>Observance</td></tr><tr data-date="1640390400000" data-mask="1" id="tr39"><th class="nw">12월 25일</th><td class="nw">토요일</td><td><a href="/holidays/south-korea/christmas-day">Christmas Day</a></td><td>Public Holiday</td></tr><tr data-date="1640908800000" data-mask="16" id="tr40"><th class="nw">12월 31일</th><td class="nw">금요일</td><td><a href="/holidays/south-korea/new-year-eve">New Year's Eve</a></td><td>Observance</td></tr>
